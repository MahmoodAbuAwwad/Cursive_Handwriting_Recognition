# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/GraduationProject
# !unzip test.zip
# %cd /content/drive/MyDrive/GraduationProject/test
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/a01-000u-05-08_png.rf.49276bfcdc47f203675eb1aff8373ace.jpg
#   inflating: test/a01-000u-06-00_png.rf.dbb50ccd829a45a331c4effb172f4b90.jpg
#   inflating: test/a01-000u-06-02_png.rf.ba42d3c6bf57d07884beba2abd1cd816.jpg
#   inflating: test/a01-000u-06-05_png.rf.c394df9a493d99b10bd1f61e7a0b316b.jpg
#   inflating: test/a01-000x-00-00_png.rf.a0cff6d1799597eafdbaed73af37dd70.jpg
#   inflating: test/a01-000x-00-01_png.rf.f976dc58b6c1b1e6e77e1cbe63a89514.jpg
#   inflating: test/a01-000x-00-05_png.rf.3b432c8aad87a6253ab549fc54083346.jpg
#   inflating: test/a01-000x-00-06_png.rf.c0e96650e362a1f9b907094b7e3897ed.jpg
#   inflating: test/a01-000x-00-07_png.rf.d768e31347f3257bcb12801b999eaf4b.jpg
#   inflating: test/a01-000x-01-00_png.rf.7c4ab311e47b58d6b0cfd1e431b5a3ca.jpg
#   inflating: test/a01-000x-01-01_png.rf.653b6a9dc6605558411ae18b74665018.jpg
#   inflating: test/a01-000x-01-02_png.rf.8eca90d3ccaf31fbf33c22ab5433383f.jpg
#   inflating: test/a01-000x-01-05_png.rf.bcd0358a3eaa099fb13a7f253de04e74.jpg
#   inflating: test/a01-000x-01-06_png.rf.987053effd0e1eeca58b183c839151b2.jpg
#   inflating: test/a01-000x-01-07_png.rf.dbdfb9f1cde942ba8234761e6a56e292.jpg
#   inflating: test/a01-000x-01-08_png.rf.8cf02e93ab50b8c387f6dcda74c3ff0e.jpg
#   inflating: test/a01-000x-01-09_png.rf.732d20cd34e46124a045886155c1e1b1.jpg
#   inflating: test/a01-000x-01-10_png.rf.ff3a016e3577c48a6f2272a483b379ea.jpg
#   inflating: test/a01-000x-02-00_png.rf.a6bc37d46d82cdfb1b977c92158089f1.jpg
#   inflating: test/a01-000x-02-02_png.rf.31b9977dfd8602a14f002940562fc62e.jpg
#   inflating: test/a01-000x-02-03_png.rf.91048ba2f0a9e35631fff9d6bdac05a9.jpg
#   inflating: test/a01-000x-02-04_png.rf.613c4d17c50e3a1fe2acd40a7d74bf4d.jpg
#   inflating: test/a01-000x-02-07_png.rf.ef4a43ee8e5b649b9b932070a08056b2.jpg
#   inflating: test/a01-000x-03-01_png.rf.6b4e8e6fdcc5998da3ef4fa97982acec.jpg
#   inflating: test/a01-000x-03-02_png.rf.2bbb3c72cb0d9daa80bb5e3d56665378.jpg
#   inflating: test/a01-000x-03-03_png.rf.a7caf99276b0b5a35ead07dffc1c2c16.jpg
#   inflating: test/a01-000x-03-05_png.rf.80c7bf8e4f77072a01304747d149e719.jpg
#   inflating: test/a01-000x-03-08_png.rf.d3880f9852f24fb94165b702fec75150.jpg
#   inflating: test/a01-000x-04-00_png.rf.64a81942ba56636066f232e9c980370a.jpg
#   inflating: test/a01-000x-04-03_png.rf.f8816bc4dcb719a0cea069659ef2a217.jpg
#   inflating: test/a01-000x-04-06_png.rf.fbf408e54c1e7824353d149fe2304dcd.jpg
#   inflating: test/a01-000x-04-07_png.rf.2c4c5fa6851c2db97023ead97de9e03d.jpg
#   inflating: test/a01-000x-04-08_png.rf.37ceff5ca9b01b1a4af8011ab8a8236e.jpg
#   inflating: test/a01-000x-04-09_png.rf.920af40ec95787885d25c68fe53f7cd1.jpg
#   inflating: test/a01-000x-05-00_png.rf.4e63ca54a0839ab227b55a521591e940.jpg
#   inflating: test/a01-003u-00-01_png.rf.b384cd5f90798fc1e6a7b201fd245356.jpg
#   inflating: test/a01-003u-00-02_png.rf.9a18c675071a2594309f3fa06a891438.jpg
#   inflating: test/a01-003u-00-04_png.rf.4020381baea6334d98224bfa96ad8228.jpg
#   inflating: test/a01-003u-01-00_png.rf.abeee935eb5c35c0c7da3852f81dd76c.jpg
#   inflating: test/a01-003u-01-02_png.rf.6b29ec9c812b9425e167b7cfacca123c.jpg
#   inflating: test/a01-003u-01-03_png.rf.090c1e4df72ddd2122051ed44b6e2b03.jpg
#   inflating: test/a01-003u-01-04_png.rf.7f1caf13041d934d7837cced54eb3f7f.jpg
#   inflating: test/a01-003u-01-05_png.rf.fc54fa0943cbf9a38cff0a77bbdf3126.jpg
#   inflating: test/a01-003u-01-06_png.rf.b0fc8570b4aa2d3550b417a6c53573c3.jpg
#   inflating: test/a01-003u-02-00_png.rf.86525ec4b0587dbbf218cc638c08f397.jpg
#   inflating: test/a01-003u-02-01_png.rf.cd28283c9a82ca4ed5f96e0ba9f942e3.jpg
#   inflating: test/a01-003u-02-02_png.rf.8b87bbde7439e8cd0dd5922c9df2df58.jpg
#   inflating: test/a01-003u-02-03_png.rf.4702a21e9fb446e469d416d8256a926a.jpg
#   inflating: test/a01-003u-02-04_png.rf.bfb0921912075d5f037e1286b343a9a0.jpg
#   inflating: test/a01-003u-02-05_png.rf.fc2899beac44e152a20438803a980a04.jpg
#   inflating: test/a01-003u-02-06_png.rf.e5f7c4b380cbaa9f4a528eaa67326147.jpg
#   inflating: test/a01-003u-02-07_png.rf.b8872d67f94a2b99d44c5278ba40ee8a.jpg
#   inflating: test/a01-003u-03-01_png.rf.aa38965b7e75ee118398a094ffcb5b8a.jpg
#   inflating: test/a01-003u-03-03_png.rf.1e74849c8303cb78e18208f84e15f448.jpg
#   inflating: test/a01-003u-03-06_png.rf.558dd11124060a5063394b1d37bcbb0a.jpg
#   inflating: test/a01-003u-04-00_png.rf.bdd5e3976f08c71b6349cc9543e32d5a.jpg
#   inflating: test/a01-003u-04-01_png.rf.8d3bb99e60a0d918790ca4863f543377.jpg
#   inflating: test/a01-003u-04-03_png.rf.fb7b6fa8e8f8cde9e1d31d7f0d68d132.jpg
#   inflating: test/a01-003u-04-06_png.rf.70c603370370446fc6f008ff38b6fa0d.jpg
#   inflating: test/a01-003u-05-01_png.rf.6018ad26fa2791ca1085fd7f2b735551.jpg
#   inflating: test/a01-003u-05-02_png.rf.55a22532aa3df9306b5a6add51caf87c.jpg
#   inflating: test/a01-003u-05-03_png.rf.23e28df1e477f8fc490ac7da7ffddd08.jpg
#   inflating: test/a01-003u-05-04_png.rf.4c7778dd0b2557c9779a34e849a844fb.jpg
#   inflating: test/a01-003u-05-05_png.rf.2ee9dfb4884bbd1eda6359e2348e2678.jpg
#   inflating: test/a01-003u-06-00_png.rf.99b489aaa2ee048c6c0a6c6427e74f11.jpg
#   inflating: test/a01-003u-06-01_png.rf.900d22fe103e43628c23cfcfe059fa48.jpg
#   inflating: test/a01-003u-06-03_png.rf.17dfa51fe264dbb0f46df67810556126.jpg
#   inflating: test/a01-003u-06-04_png.rf.7e93156fff25c63e91c744976bb73194.jpg
#   inflating: test/a01-003u-06-05_png.rf.11cf6f06c1d3677b38a046fa91a75782.jpg
#   inflating: test/a01-003u-06-06_png.rf.42f747f514b69155e4c51605f2081958.jpg
#   inflating: test/a01-003u-07-01_png.rf.94fa3d56db8c13e73193c817a685b062.jpg
#   inflating: test/a01-003u-07-04_png.rf.da371cace6b492b4536dd8640f1acf18.jpg
#   inflating: test/a01-003u-07-05_png.rf.31ffcb4d71ec514b7ac07103d9eeb3c1.jpg
#   inflating: test/a01-003u-07-06_png.rf.d7e2a47fb12044b225f24f3684cd1bb0.jpg
#   inflating: test/a01-003u-08-00_png.rf.b7d17d2d880a256a3448b458047a6646.jpg
#   inflating: test/a01-003u-08-02_png.rf.3d7ccb2ed603a05a99fb88ac43a42b04.jpg
#   inflating: test/a01-003u-08-03_png.rf.d33437ca3cfb3dbb3e15cdcd355f3d38.jpg
#   inflating: test/a01-003u-08-04_png.rf.1018a2943c02e6066bf8b1b9183fac08.jpg
#   inflating: test/a01-003u-08-06_png.rf.6b3c1aa8a0bdbbb44ba958ab163bf67f.jpg
#   inflating: test/a01-003u-09-00_png.rf.b1f8d1dba2fe5b76e961b36e0e840670.jpg
#   inflating: test/a01-003u-09-02_png.rf.5c076c20a1620e88c085c46ab0d5dff6.jpg
#   inflating: test/a01-003u-09-04_png.rf.78fb8a1d4080c3588d22884f3e945a42.jpg
#   inflating: test/a01-003u-09-05_png.rf.c073a2e65f919b28ebec043d7b39afd9.jpg
#   inflating: test/a01-003u-09-06_png.rf.092fce9fbba81104fc8e6004be53cc60.jpg
#   inflating: test/a01-003u-10-00_png.rf.9a18989c08c4ba54872078b1fc29d2f1.jpg
#   inflating: test/a01-003u-10-03_png.rf.8521865de003d87fcd3d1fe589ce9a01.jpg
#   inflating: test/a01-003u-10-04_png.rf.3311ec4fe0575f14fcc5f6ac3de74b82.jpg
#   inflating: test/a01-003u-10-05_png.rf.0cd05f790bf2807fe38fd3ea4509c3a7.jpg
#   inflating: test/a01-003u-10-06_png.rf.c2e5a7430a158b71d2d583fd36d996a6.jpg
#   inflating: test/a01-003u-10-07_png.rf.1b52371b3792661caa58c69dcdcdf6ca.jpg
#   inflating: test/a01-003u-10-08_png.rf.c93572fb3eb44d9d679eb312f90c7321.jpg
#   inflating: test/a01-003u-10-09_png.rf.2d224a281ec3d0f3fcdf3a93ddb72391.jpg
#   inflating: test/a01-003x-00-00_png.rf.ffa428783b3756723ddd248987d319c9.jpg
#   inflating: test/a01-003x-00-01_png.rf.efed36b5535ae9b7a60c0870de952690.jpg
#   inflating: test/a01-003x-00-02_png.rf.303251bcedd87c0836c82480b73ddbd8.jpg
#   inflating: test/a01-003x-00-03_png.rf.f32c566071868724e17519f67c918c18.jpg
#   inflating: test/a01-003x-00-04_png.rf.16e41b95dbcf8698e4b422a3796598de.jpg
#   inflating: test/a01-003x-00-08_png.rf.9f497e098ed5faca5fb680c64712335b.jpg
#   inflating: test/a01-003x-01-00_png.rf.09c936c494f8a2a90d8ac866397ef214.jpg
#   inflating: test/a01-003x-01-02_png.rf.e31798b8d9835981678ee3c6b33855e9.jpg
#   inflating: test/a01-003x-01-03_png.rf.6db8b69027558389d299156b4f7fe67b.jpg
#   inflating: test/a01-003x-01-04_png.rf.0b10884249a652eb336f0ad9b9502eb5.jpg
#   inflating: test/a01-003x-01-05_png.rf.7f6636a7b709e728c2cd6844d9ef0f0c.jpg
#   inflating: test/a01-003x-01-06_png.rf.bc72f4b387f55b7cf4a3249624d81269.jpg
#   inflating: test/a01-003x-01-07_png.rf.5359b5625b556139b362e9ce3064ad85.jpg
#   inflating: test/a01-003x-01-08_png.rf.39a306fdd92ca6d09921f04d6b479557.jpg
#   inflating: test/a01-003x-02-01_png.rf.921461eefe66e1f723c8667f959a61ec.jpg
#   inflating: test/a01-003x-02-02_png.rf.2e83630147d1083eb00b1feff1ab6805.jpg
#   inflating: test/a01-003x-02-05_png.rf.3fe396bf736bc59bd93ba33bd604e614.jpg
#   inflating: test/a01-003x-02-06_png.rf.a8ffc334237b20a5b62864493b204dcd.jpg
#   inflating: test/a01-003x-02-07_png.rf.b9045a5a2dd13d400e7b90c81975f462.jpg
#   inflating: test/a01-003x-03-00_png.rf.5bb948bdd975a2f536cf75c4751e2cce.jpg
#   inflating: test/a01-003x-03-01_png.rf.dac5fd7a5f03863fbcb3c66331ac4fde.jpg
#   inflating: test/a01-003x-03-02_png.rf.f3b7cf309f468c29aedb8b0d9cd8d9d9.jpg
#   inflating: test/a01-003x-03-03_png.rf.baab536817b4fad7290d14d119fc4336.jpg
#   inflating: test/a01-003x-03-04_png.rf.9b74a2f097d747fa182e226803e629cc.jpg
#   inflating: test/a01-003x-03-07_png.rf.bc6c068fdb23a2d92fef76eb661ffd34.jpg
#   inflating: test/a01-003x-04-00_png.rf.f963aa0f6f8ccae9b851c2eee7b526fb.jpg
#   inflating: test/a01-003x-04-01_png.rf.92fcc33dd24bfd4caa5e4748feddb698.jpg
#   inflating: test/a01-003x-04-02_png.rf.6357f3505ff21bb43ad1b46b61898305.jpg
#   inflating: test/a01-003x-04-04_png.rf.157bf071faac435698163175de52775d.jpg
#   inflating: test/a01-003x-04-05_png.rf.d427c2f361c88852124365ad2a9a7c72.jpg
#   inflating: test/a01-003x-04-08_png.rf.0a4e3bfd8b3afbb591f664ae485f1d26.jpg
#   inflating: test/a01-003x-04-09_png.rf.e0de2ee3e80ebe754ce27d0c0bad1275.jpg
#   inflating: test/a01-003x-05-00_png.rf.bf8a22cf83ab5162a429e8e7e2b907eb.jpg
#   inflating: test/a01-003x-05-01_png.rf.08b657d643b54c1cc4290274d870fe9c.jpg
#   inflating: test/a01-003x-05-03_png.rf.eb914e1036a77ff13a8ae326bc17f2b1.jpg
#   inflating: test/a01-003x-05-05_png.rf.6af3e04501b5b6297ebdbed85ef510be.jpg
#   inflating: test/a01-003x-05-07_png.rf.5cb47183267ade5151cb58b8c13d0439.jpg
#   inflating: test/a01-003x-06-00_png.rf.34ecae5c2893afc285621e44cc625a90.jpg
#   inflating: test/a01-003x-06-01_png.rf.16072861e3caefa0ddc548575ceb4082.jpg
#   inflating: test/a01-003x-06-03_png.rf.30f4b04456d9c0cb6a198a0bd2467e66.jpg
#   inflating: test/a01-003x-06-04_png.rf.64898570904640d43d127b064542b9b3.jpg
#   inflating: test/a01-003x-06-06_png.rf.5549ee4c6f7f4bc8fb1227df36861feb.jpg
#   inflating: test/a01-003x-06-07_png.rf.a1f73af269b8000d5e0a5b0fbd9c075b.jpg
#   inflating: test/a01-003x-06-08_png.rf.f8ffdc0e4f297b814408b9857d6ac866.jpg
#   inflating: test/a01-003x-07-02_png.rf.a9d34b54bef46ab7bda505731a1d0e64.jpg
#   inflating: test/a01-003x-07-03_png.rf.911b04362756e4b722a557df6f0de945.jpg
#   inflating: test/a01-003x-07-05_png.rf.e06928da7d9b659dda3aa33c8d8184b2.jpg
#   inflating: test/a01-003x-07-06_png.rf.0591444348a9a9a54986bbdcd6c4e195.jpg
#   inflating: test/a01-003x-07-07_png.rf.78b55103439c8782054457844848eacb.jpg
#   inflating: test/a01-003x-07-08_png.rf.53559854ffb4821eec39927c8a1ebea7.jpg
#   inflating: test/a01-003x-08-00_png.rf.410632726c6c651b07344975c0138be9.jpg
#   inflating: test/a01-003x-08-06_png.rf.f742aea4ab2d8dca64eac96c35e244d4.jpg
#   inflating: test/a01-003x-08-07_png.rf.dea83aa1c0470e438faadc3102df890d.jpg
#   inflating: test/a01-007-00-00 - Copy_png.rf.d7433a6b4e1a87d943a075ab4efdeb40.jpg
#   inflating: test/a01-007-00-05_png.rf.c2be58528bb3302788f9fdedf7abdce8.jpg
#   inflating: test/a01-007-00-06_png.rf.e405386193ecda34452c336743b5c6f0.jpg
#   inflating: test/a01-007-01-02_png.rf.62123bee0e43381092625f11a4556b6a.jpg
#   inflating: test/a01-007-01-03_png.rf.a9a30ca9d1d088f02058bda050598760.jpg
#   inflating: test/a01-007-01-05_png.rf.0534b40026d83a15b4f94eb1ceffe1a4.jpg
#   inflating: test/a01-007-01-06_png.rf.031ac8acc0856eeb16903a82b470e114.jpg
#   inflating: test/a01-007-02-01_png.rf.406d97dce312d2fd44d9a0be7a652bb1.jpg
#   inflating: test/a01-007-02-03_png.rf.7d47ab7e8cd687da8d5f212fb91b6f6a.jpg
#   inflating: test/a01-007-02-04_png.rf.12f07ca4a8e65c9cf6f0fe368cefc89d.jpg
#   inflating: test/a01-007-02-06_png.rf.1fa8224e661212f17505ecc563848b83.jpg
#   inflating: test/a01-007-03-01_png.rf.9d0d6ffc3a7de4f884cb9562e25eb93a.jpg
#   inflating: test/a01-007-03-02_png.rf.613f565976d1129cd8cd0db0d3d94ca9.jpg
#   inflating: test/a01-007-03-03_png.rf.a45f51abf080d80baec480adbf0cbc73.jpg
#   inflating: test/a01-007-03-04_png.rf.57a2b2e98fbbc5c7342183719c6599e5.jpg
#   inflating: test/a01-007-03-06_png.rf.77b5e7efd1554324b6c0c2d7e5361c30.jpg
#   inflating: test/a01-007-03-08_png.rf.5e973ebfb4226876f7475840d7a329a2.jpg
#   inflating: test/a01-007-03-09_png.rf.e2bb96334537ce9b190187659bf3ddbd.jpg
#   inflating: test/a01-007-04-00_png.rf.5542d9b525a8411c58be52a02f600477.jpg
#   inflating: test/a01-007-04-01_png.rf.68e78923289c1ffb968f5c052e3cbb2d.jpg
#   inflating: test/a01-007-04-02_png.rf.5a6bcf70e9e8fa6e1f55759825dfbc05.jpg
#   inflating: test/a01-007-04-05_png.rf.65473d0d2967d142abf6383628430a16.jpg
#   inflating: test/a01-007-04-06_png.rf.1a86777440fe6a50f41895b02eec6758.jpg
#   inflating: test/a01-007-05-02_png.rf.b04ff68f993a2fdb75e076d15b412a11.jpg
#   inflating: test/a01-007-05-03_png.rf.5c49afa3d904560e4b36f78c44aa423a.jpg
#   inflating: test/a01-007-05-04_png.rf.6eeb4e844fb00299af83081cdc4590fa.jpg
#   inflating: test/a01-007-05-06_png.rf.02137c76e35537ef9f18f0309cc4ab1e.jpg
#   inflating: test/a01-007-06-00_png.rf.655b094964cee133f8159532d3586e24.jpg
#   inflating: test/a01-007-06-01_png.rf.d46d9347e7c63f3e4c37b790125766be.jpg
#   inflating: test/a01-007-06-06_png.rf.4c35dae1c213daf05d0eb93436960528.jpg
#   inflating: test/a01-007-07-01_png.rf.214b9eb86e220688e06222cfe97fa3cd.jpg
#   inflating: test/a01-007-07-02_png.rf.0298527c7f0c10002e9b4310269c2689.jpg
#   inflating: test/a01-007-07-04_png.rf.cc8ccda3de8a92c300d515af6ae58c66.jpg
#   inflating: test/a01-007-07-05_png.rf.af22c97e6e93dce6d37272e222c89003.jpg
#   inflating: test/a01-007-07-07_png.rf.6be0728dd5ccac5baa6ebc915e598fef.jpg
#   inflating: test/a01-007-08-03_png.rf.d6aa665b286cf1335310a05504af5aa5.jpg
#   inflating: test/a01-007-08-04_png.rf.811eb0e4dc84a0fd1afb711c51475fb6.jpg
#   inflating: test/a01-007-08-05_png.rf.ddfa12e66834f5fed96817e1af52ae9a.jpg
#   inflating: test/a01-007u-00-00_png.rf.6bf48cd49bb6c6050e13ba31d5dfb8e4.jpg
#   inflating: test/a01-007u-00-05_png.rf.b09007a232b90e6d3b4878d3f60cc8e6.jpg
#   inflating: test/a01-007u-00-07_png.rf.7d9ca3019258d4ab90f5170c3c2abfa1.jpg
#   inflating: test/a01-007u-01-02_png.rf.49733d61c28388417acfe3a2f13e6b0d.jpg
#   inflating: test/a01-007u-01-03_png.rf.47ec7b2ca990507fd0a74b65827cedbe.jpg
#   inflating: test/a01-007u-01-05_png.rf.f343fea752f0501cd0d2af5efbb58492.jpg
#   inflating: test/a01-007u-01-06_png.rf.dee8241917a89fde38db8b17860533bb.jpg
#   inflating: test/a01-007u-02-00_png.rf.433f6c48727abe91c69c70097198f0ee.jpg
#   inflating: test/a01-007u-02-01_png.rf.6af52063233b391371da234856628f86.jpg
#   inflating: test/a01-007u-02-02_png.rf.fe2dc15c4d6f38dcc85aca66966c3ce5.jpg
#   inflating: test/a01-007u-02-03_png.rf.3d91170d3599d70d4c4396e7c119ce3c.jpg
#   inflating: test/a01-007u-02-04_png.rf.394c5d58635786257e13fae9e5626800.jpg
#   inflating: test/a01-007u-03-00_png.rf.82907e071ea2e924a2a27806213bdc1c.jpg
#   inflating: test/a01-007u-03-01_png.rf.e11c483408cf22e37e488b73cb9e8d4c.jpg
#   inflating: test/a01-007u-03-02_png.rf.ac87737ada028ca488ee0277f279aec3.jpg
#   inflating: test/a01-007u-03-03_png.rf.9f3e7f5dd6ca989a514598e229313795.jpg
#   inflating: test/a01-007u-03-04_png.rf.e76638690e763096090ad3917c05ead6.jpg
#   inflating: test/a01-007u-03-06_png.rf.1d795abc47d344da84044414061ecee7.jpg
#   inflating: test/a01-007u-03-08_png.rf.9fe89e3673be4ac9f6adc08375865ed2.jpg
#   inflating: test/a01-007u-03-09_png.rf.62d6c28627660a718d8838f22359c9d9.jpg
#   inflating: test/a01-007u-04-01_png.rf.1003c2a853cf38c31a23210b5a1163f9.jpg
#   inflating: test/a01-007u-04-02_png.rf.8fbeedf0af8aef7f57875b8cd4feb06b.jpg
#   inflating: test/a01-007u-04-03_png.rf.76b0b1ea23ca6cc32a0a53b07ad74646.jpg
#   inflating: test/a01-007u-04-04_png.rf.fd7a6e6328c713d2c1ee833c88bb853d.jpg
#   inflating: test/a01-007u-04-05_png.rf.789e3f885dd8ad5952d451cfb7d068d3.jpg
#   inflating: test/a01-007u-04-06_png.rf.019b950dbb5032d0e4e9fd636d9e3b61.jpg
#   inflating: test/a01-007u-05-00_png.rf.223e6eb7a1f5d0ff3972dfb74e86bb28.jpg
#   inflating: test/a01-007u-05-01_png.rf.7fcb7568bb655f21c63d0d716ba98c8b.jpg
#   inflating: test/a01-007u-05-06_png.rf.41b52de519b1e1fd32d1285f99ca9972.jpg
#   inflating: test/a01-007u-06-00_png.rf.12871607bec1213b6f13df35d264e2ce.jpg
#   inflating: test/a01-007u-06-01_png.rf.bfcd974ff9f500cd5ab6d7f09d80a25b.jpg
#   inflating: test/a01-007u-06-02_png.rf.8bab31e181e8ba57d531320e804f32ce.jpg
#   inflating: test/a01-007u-06-03_png.rf.f1aadac75fe7d5b1bfdfffe99bc4faf5.jpg
#   inflating: test/a01-007u-07-00_png.rf.600aecf555979ac12731129e57236887.jpg
#   inflating: test/a01-007u-07-02_png.rf.5d9cca4c7774b873d6397d0ed3f9f713.jpg
#   inflating: test/a01-007u-07-03_png.rf.c8f3a74bcdb6661e99b76b1f85b2421b.jpg
#   inflating: test/a01-007u-07-04_png.rf.776d58700a7ee0b94d7da7f7daa29149.jpg
#   inflating: test/a01-007u-07-05_png.rf.98e7bdab902460e1367db65e640eee18.jpg
#   inflating: test/a01-007u-07-06_png.rf.1babd39799548832d1d720ca5b1b24c3.jpg
#   inflating: test/a01-007u-08-00_png.rf.8d71b738da2adabb9a3b69fdc69aabd5.jpg
#   inflating: test/a01-007u-08-02_png.rf.8df7242747676c1b087dcfeb152b72af.jpg
#   inflating: test/a01-007u-08-03_png.rf.bd03e67b1eddb89f6bee8950da8394a8.jpg
#   inflating: test/a01-007u-08-04_png.rf.b8b1163ef0573da23abac02a05c53b5c.jpg
#   inflating: test/a01-007u-08-05_png.rf.e2cce840fdde3ad36f73b4ec9e9dcb3f.jpg
#   inflating: test/a01-007u-09-00_png.rf.389d87bc19a59212a7837e936ffc76c9.jpg
#   inflating: test/a01-007u-09-01_png.rf.7d37bc5ab2b9ac20aa1094f01d36501f.jpg
#   inflating: test/a01-007u-09-02_png.rf.60da59ef51c30194bc516f91a3421022.jpg
#   inflating: test/a01-007x-00-00_png.rf.06008ce407f8bfe208bd1c26af7cac3d.jpg
#   inflating: test/a01-007x-00-04_png.rf.2b5d446767872953b9002f4e49d0b032.jpg
#   inflating: test/a01-007x-00-07_png.rf.e04ba5408fe6d3d67dd060d44d4d6e47.jpg
#   inflating: test/a01-007x-01-00_png.rf.85e853b8aa2a8cb140c565717c3c1aa8.jpg
#   inflating: test/a01-007x-01-02_png.rf.a7910b205eaec3750301ade29e0856e2.jpg
#   inflating: test/a01-007x-01-03_png.rf.e85a8701104c1178c66b31ff92fd6299.jpg
#   inflating: test/a01-007x-01-07_png.rf.a259393436de80d0b4bb82f141bcd81c.jpg
#   inflating: test/a01-007x-02-00_png.rf.ba27e8b80ec9b46ce8410d044376fe6e.jpg
#   inflating: test/a01-007x-02-01_png.rf.7db789c86889d44365ac6a1009bad437.jpg
#   inflating: test/a01-007x-02-02_png.rf.37136ce55ba5415ad4c5a3d7c4200231.jpg
#   inflating: test/a01-007x-02-05_png.rf.34bfd3d72156d9484832697e3d91ff91.jpg
#   inflating: test/a01-007x-02-06_png.rf.f0b776e8d35ca459f82ae87ca69251a7.jpg
#   inflating: test/a01-007x-03-00_png.rf.b09e9a1419bccf303a737bb6d3c8e078.jpg
#   inflating: test/a01-007x-03-01_png.rf.f38dc6ef942550eaae150977453f2910.jpg
#   inflating: test/a01-007x-03-04_png.rf.c5e17cf1ebe3d061c4feb368c0a474d2.jpg
#   inflating: test/a01-007x-03-05_png.rf.031be37b03e7528de3ad0f2527ed8506.jpg
#   inflating: test/a01-007x-03-06_png.rf.1fe6ae5574796f7c705a88e54ee0778c.jpg
#   inflating: test/a01-007x-03-08_png.rf.ebbc5e708faa3a607cce89fbc2ab27f2.jpg
#   inflating: test/a01-007x-04-00_png.rf.326ecbb766a9d218113d2ca23ad1b32b.jpg
#   inflating: test/a01-007x-04-01_png.rf.7f2a29d12b512ec7b4c527cf546c1a55.jpg
#   inflating: test/a01-007x-04-02_png.rf.eb9cdebd2e7ff9dcfa2d3250ac2eebc5.jpg
#   inflating: test/a01-007x-04-03_png.rf.d3b41233e5f41e7ef506230f531ce1e1.jpg
#   inflating: test/a01-007x-04-05_png.rf.7317dc59701c3321972010f9e0b9dd85.jpg
#   inflating: test/a01-007x-04-07_png.rf.ecf702b894db08a73e8eabbaffea0381.jpg
#   inflating: test/a01-007x-05-00_png.rf.25550067ecb22f7cd73eb3443009ae88.jpg
#   inflating: test/a01-007x-05-01_png.rf.039f7b5ea46b10e29f8cead58e85bf22.jpg
#   inflating: test/a01-007x-05-02_png.rf.9d1018d79a1ce07fc0f259fb03a9c9d1.jpg
#   inflating: test/a01-007x-05-03_png.rf.46f4444cac96ed23794d79ca49471bf9.jpg
#   inflating: test/a01-007x-05-04_png.rf.b8a6367a0a05eeba254c0a7027c26c97.jpg
#   inflating: test/a01-007x-05-06_png.rf.4860b621731c1b72afec1399066e5a6c.jpg
#   inflating: test/a01-007x-06-00_png.rf.7aaac6257bc261abbbdfe2f5caf51dc0.jpg
#   inflating: test/a01-007x-06-01_png.rf.bbb59ea67d4225251dd1d1d64ab47bb1.jpg
#   inflating: test/a01-007x-06-02_png.rf.5eb31157d8b559186cac95450bc058a9.jpg
#   inflating: test/a01-007x-06-03_png.rf.b65ada7c33a4f6061fcf6a8ddd56432e.jpg
#   inflating: test/a01-007x-06-04_png.rf.59bbd73830f0632ecf8f26e61e36cd5c.jpg
#   inflating: test/a01-007x-06-05_png.rf.c1f356bd12ec90fdebe00c7383fc0aff.jpg
#   inflating: test/a01-007x-06-06_png.rf.ba9fd574ea3e07a41bb8ddc7a9314c7c.jpg
#   inflating: test/a01-007x-06-07_png.rf.fcd7c3f7d0fd6b32eac803e44d27ba0d.jpg
#   inflating: test/a01-007x-07-01_png.rf.c102ac0208f55e19af08c0dbbe2c8567.jpg
#   inflating: test/a01-007x-07-02_png.rf.f2bdb1777183d487feaf1f8b3d655caf.jpg
#   inflating: test/a01-007x-07-03_png.rf.3ad658a03f4b562c446e22c9c06a1dce.jpg
#   inflating: test/a01-007x-07-04_png.rf.92aec9957be2c6ef7ace5489cb27b651.jpg
#   inflating: test/a01-007x-07-06_png.rf.a6f046d6417e9043cb438bd24d1bb84f.jpg
#   inflating: test/a01-007x-07-07_png.rf.fcd1eae5f8274f060a11538789d11f7b.jpg
#   inflating: test/a01-007x-07-08_png.rf.d631588a2146a72312c86bdfdfe7f686.jpg
#   inflating: test/a01-011-00-00_png.rf.90f998bf218c77bf5550da649ab1c773.jpg
#   inflating: test/a01-011-00-03_png.rf.ffbb4efdfb9da09d5a9a582992042322.jpg
#   inflating: test/a01-011-00-04_png.rf.a171f5e02082073c63c096553f911905.jpg
#   inflating: test/a01-011-00-05_png.rf.c12ece14f607ae1e5c037b0a7019e296.jpg
#   inflating: test/a01-011-00-06_png.rf.a8296201cd0ee146888f6bd1fd198974.jpg
#   inflating: test/a01-011-00-07_png.rf.674259db4dc40e49934eaacffade4a44.jpg
#   inflating: test/a01-011-01-00_png.rf.0cde8b23c4673e97194301b1e874e592.jpg
#   inflating: test/a01-011-01-03_png.rf.56400cafbcecfce4ea7e6ca175e75162.jpg
#   inflating: test/a01-011-01-05_png.rf.d74e423e8bc28bd2bd4733afa6475f8f.jpg
#   inflating: test/a01-011-01-06_png.rf.9239a7097bca0741b008389bfd16a07c.jpg
#   inflating: test/a01-011-01-08_png.rf.733a6d8ab3086f27e6ea5a9cd4841486.jpg
#   inflating: test/a01-011-02-00_png.rf.40a321754e9ee240c898b33e5dd14c2e.jpg
#   inflating: test/a01-011-02-01_png.rf.81cc7e78adbe471d0d4d77cf4d5615bb.jpg
#   inflating: test/a01-011-02-05_png.rf.4478c673930f7a78c1891b429a357e0e.jpg
#   inflating: test/a01-011-02-08_png.rf.92b47a08e1f531470edb8022f01af876.jpg
#   inflating: test/a01-011-03-00_png.rf.ca2d278e33492d56d579d7a54b4287cf.jpg
#   inflating: test/a01-011-03-01_png.rf.894f15935723cc2797dedb754cf8afdd.jpg
#   inflating: test/a01-011-03-02_png.rf.4f8bff98f6873cf496c3008b77f3f34c.jpg
#   inflating: test/a01-011-03-03_png.rf.4deb4f6a4c49073bc6add7c841ca44f4.jpg
#   inflating: test/a01-011-03-05_png.rf.b5a7ebe01f840cc9cea696b394fe7ab8.jpg
#   inflating: test/a01-011-03-06_png.rf.5835eb1fd75934700198033c1cc72da5.jpg
#   inflating: test/a01-011-03-08_png.rf.7e56ef893815c22fb6eb14c1f5b4691c.jpg
#   inflating: test/a01-011-03-09_png.rf.3a52480a2f2d9a911edf037bb355e2f6.jpg
#   inflating: test/a01-011-03-10_png.rf.1b746bdfe4f87c87b56474b87201442a.jpg
#   inflating: test/a01-011-04-00_png.rf.403386cf5ca30d336e36b7b1ff9868e3.jpg
#   inflating: test/a01-011-04-01_png.rf.6f7d5b4d27b3a4e048206ec72203fc4b.jpg
#   inflating: test/a01-011-04-02_png.rf.95a7d529edddff923b1b28119137bb61.jpg
#   inflating: test/a01-011-04-03_png.rf.900da95f588ce41e5fe5f291869f25a8.jpg
#   inflating: test/a01-011-04-05_png.rf.44cf5c7aed96622f368f0f4243a4fd44.jpg
#   inflating: test/a01-011-04-07_png.rf.023ee93db4eac09ab579d8f26692321a.jpg
#   inflating: test/a01-011-05-01_png.rf.62c1f3614d6c7bbece18fc4ccb11487a.jpg
#   inflating: test/a01-011-05-02_png.rf.4ce5c72964617ca308d1163956438cf3.jpg
#   inflating: test/a01-011-05-04_png.rf.46e26b221ad97c2694f59876dceab2c7.jpg
#   inflating: test/a01-011-05-05_png.rf.aebb2efbe1307c4d9c64a8a582e83481.jpg
#   inflating: test/a01-011-05-06_png.rf.7897814ec97983be282aaa3748c9dd47.jpg
#   inflating: test/a01-011-06-05_png.rf.dc97c32bc57b25fc9b9044ded152d249.jpg
#   inflating: test/a01-011-06-08_png.rf.2f8146d6a91edf0b4d1cb479725230c8.jpg
#   inflating: test/a01-011-06-09_png.rf.ea15e7969c77ae29e74cb8082093d882.jpg
#   inflating: test/a01-011-06-10_png.rf.b20237a7903f60576eb6efa8212ed6c9.jpg
#   inflating: test/a01-011u-01-00_png.rf.c387720735ed7145aa1fa37947e91451.jpg
#   inflating: test/a01-011u-01-02_png.rf.699d096a7330fa6caf6d6eeb22a06880.jpg
#   inflating: test/a01-011u-01-03_png.rf.5cbd725ba958d3b3edc0657bb174cdd1.jpg
#   inflating: test/a01-011u-02-04_png.rf.2d2193b32d3272178f7a563769df5198.jpg
#   inflating: test/a01-011u-02-05_png.rf.ab49b00df74484f27e6c3e2d7c165f28.jpg
#   inflating: test/a01-011u-02-06_png.rf.a2383b38b77dd2f29c4ba008584a056b.jpg
#   inflating: test/a01-011u-03-00_png.rf.58338bf784f0c00782f54873393d7662.jpg
#   inflating: test/a01-011u-03-01_png.rf.6b35134f3607c669bbb9e74a9a4fc1fc.jpg
#   inflating: test/a01-011u-04-00_png.rf.c407ebcb8a023364d971d1997c12f291.jpg
#   inflating: test/a01-011u-04-01_png.rf.dfa6e2e7267aa9705f701501f994fd37.jpg
#   inflating: test/a01-011u-04-02_png.rf.fe7d67242c16ba08530d0e684684c7d9.jpg
#   inflating: test/a01-011u-04-03_png.rf.f3b6459eaa0235ccdeecdc2a033a0c41.jpg
#   inflating: test/a01-011u-04-04_png.rf.b26e8ee20ce40d48d89d00abe19be008.jpg
#   inflating: test/a01-011u-04-05_png.rf.d0593b28a9e966e07fc5ee7b4b34dc97.jpg
#   inflating: test/a01-011u-04-06_png.rf.abdd41a628c0144b0019b89556956447.jpg
#   inflating: test/a01-011u-05-02_png.rf.5d313d13da0b56e624e0067bf11105f3.jpg
#   inflating: test/a01-011u-05-05_png.rf.5e676bed6f220ede70fdc02f578e1c57.jpg
#   inflating: test/a01-011u-05-06_png.rf.ef70048ab97b8c6cbfd70f2016ffb869.jpg
#   inflating: test/a01-011u-05-07_png.rf.af2dafc890ebf1e23b9a37757bf164e4.jpg
#   inflating: test/a01-011u-06-00_png.rf.c39bd90c9193a5f073a34775750a09bd.jpg
#   inflating: test/a01-011u-06-01_png.rf.246a472209abac385f5d503b1b7879c4.jpg
#   inflating: test/a01-011u-06-02_png.rf.a8662236d99336b851faecbb0419f875.jpg
#   inflating: test/a01-011u-06-04_png.rf.b07c956ff96ee0517d43fc8514580ca8.jpg
#   inflating: test/a01-011u-06-05_png.rf.52a0c9bfcfd2f5a5c03bf21863fc069d.jpg
#   inflating: test/a01-011u-07-00_png.rf.b9c0367eb95f39caf7261e1cbbfadd47.jpg
#   inflating: test/a01-011u-07-01_png.rf.b762feb6f2f510df3c365e687441c8b4.jpg
#   inflating: test/a01-011u-07-02_png.rf.f5c3707e9e147e465963302dc30526c7.jpg
#   inflating: test/a01-011u-07-03_png.rf.294341bdf8cf793f3a0a989145b27aaa.jpg
#   inflating: test/a01-011u-07-06_png.rf.5758a0d85219c075818bee39072a8bee.jpg
#   inflating: test/a01-011u-08-01_png.rf.8ad7735c030270136e23002b0594bac0.jpg
#   inflating: test/a01-011u-08-03_png.rf.85f96c69507f7a5efa053e0987afb89a.jpg
#   inflating: test/a01-011u-08-04_png.rf.fd80b15598428fbffc8c2d0f2fd6b7fc.jpg
#   inflating: test/a01-011u-08-05_png.rf.019fbc6a84671acd71612bca960c00fa.jpg
#   inflating: test/a01-011u-09-00_png.rf.d0a5057124c63542395680ba761d67eb.jpg
#   inflating: test/a01-011u-09-01_png.rf.e76addb07494aca12168c133b9cad2da.jpg
#   inflating: test/a01-011u-09-03_png.rf.8a74f40b53388683569576e7ccfc30ee.jpg
#   inflating: test/a01-011u-09-05_png.rf.4ac4e2dcd85941c43984b241421ec5f2.jpg
#   inflating: test/a01-011x-00-00_png.rf.1d7bc74a6628764616b671e75ab2858d.jpg
#   inflating: test/a01-011x-00-02_png.rf.5e10ac5baa4248e8f829c1426b177121.jpg
#   inflating: test/a01-011x-00-03_png.rf.5ce874614df5fefed4c1cdd9f63c813e.jpg
#   inflating: test/a01-011x-01-00_png.rf.90f23a92f2b32387e843cab9101fb675.jpg
#   inflating: test/a01-011x-01-02_png.rf.f427d126d91ee739e075d72d95c77388.jpg
#   inflating: test/a01-011x-02-00_png.rf.d06eaa80d2dc491e38931b2b64c4e8f3.jpg
#   inflating: test/a01-011x-02-02_png.rf.35e17be699da108f1309390e0abe708f.jpg
#   inflating: test/a01-011x-02-04_png.rf.82b12f7f74c762ceb75737fb7b58d3a4.jpg
#   inflating: test/a01-011x-02-05_png.rf.137a33b1d58d8ad4b1c6890965332fbb.jpg
#   inflating: test/a01-011x-03-03_png.rf.5b9003c01b74e8dc4004ccb38e389352.jpg
#   inflating: test/a01-011x-03-05_png.rf.b7af644e7e13cebecc3e412d107a2d45.jpg
#   inflating: test/a01-011x-03-06_png.rf.10f04f381245517cf40a543ae8e7008d.jpg
#   inflating: test/a01-011x-03-07_png.rf.9eafed5eaf04de77b3c5f619b041fe13.jpg
#   inflating: test/a01-011x-04-01_png.rf.6f1fad8343512aece8358a594ab70456.jpg
#   inflating: test/a01-011x-04-02_png.rf.a54318e46b517afbc49178e75d2a416f.jpg
#   inflating: test/a01-011x-04-03_png.rf.309764798b02917f16b8568a71299057.jpg
#   inflating: test/a01-011x-04-04_png.rf.36bc0e0fb20e142eeccfb1687b0b7b26.jpg
#   inflating: test/a01-011x-04-05_png.rf.95bdfffb9e0f97bed1b45fa5b4bf665a.jpg
#   inflating: test/a01-011x-05-00_png.rf.570630b012aee16f96cde89213b6da69.jpg
#   inflating: test/a01-011x-05-01_png.rf.0c66e409ecdde2a8e88262ceb901c360.jpg
#   inflating: test/a01-011x-05-02_png.rf.e286dc1cf25db90d466e1533311b62de.jpg
#   inflating: test/a01-011x-05-03_png.rf.eb2c29839367df29ec19aea3067c964e.jpg
#   inflating: test/a01-011x-05-04_png.rf.f8aa6179bc71024f70af288a026a01d3.jpg
#   inflating: test/a01-011x-05-05_png.rf.806aaea9ae7c05f01905d8200d570719.jpg
#   inflating: test/a01-011x-06-01_png.rf.fc739bf35a8ef41c4830a90719fb2d95.jpg
#   inflating: test/a01-011x-06-02_png.rf.3a49138009c4129ca835ac919d4008e7.jpg
#   inflating: test/a01-011x-06-04_png.rf.5dfb3a406cd8def78688230cd65455e4.jpg
#   inflating: test/a01-011x-06-05_png.rf.b99aec6a92a92cd264bc883bb431d4de.jpg
#   inflating: test/a01-011x-07-00_png.rf.ec29d11ae6ae10ac517618d74dbc6aed.jpg
#   inflating: test/a01-011x-07-02_png.rf.a1907a5ca47e29485dae93d196339468.jpg
#   inflating: test/a01-011x-07-03_png.rf.cb49fab46b45aee5b9d1f65fa007e841.jpg
#   inflating: test/a01-011x-07-04_png.rf.4ab958e3841196f63f2851c9f19a2830.jpg
#   inflating: test/a01-011x-07-05_png.rf.95a67ef61a7561248d068277671df07b.jpg
#   inflating: test/a01-011x-07-07_png.rf.0e8fa1bb73c685ba726423f90a03b1db.jpg
#   inflating: test/a01-011x-08-00_png.rf.b7725ee775ec236489a424464e6027fb.jpg
#   inflating: test/a01-011x-08-02_png.rf.d1df3dd4ae7583613fed83334ea78c76.jpg
#   inflating: test/a01-011x-08-04_png.rf.8163fb972e3a286b9683cf1e928b604f.jpg
#   inflating: test/a01-011x-08-06_png.rf.5ab71cd1b2f8f1c2bb3d85c28cf99ea3.jpg
#   inflating: test/a01-011x-08-08_png.rf.9acc8c30e3a6908b224851e9fbb91ca1.jpg
#   inflating: test/a01-014-00-02_png.rf.68934dd7b59cf1c2808e36c97549a92d.jpg
#   inflating: test/a01-014-00-03_png.rf.44c2127c917a683eb56ca054bac0e280.jpg
#   inflating: test/a01-014-00-04_png.rf.6e9fb912ff601afa91d05e41474bcb8d.jpg
#   inflating: test/a01-014-00-05_png.rf.670ddd5099e60c7befde3ac9f05ac2c9.jpg
#   inflating: test/a01-014-01-00_png.rf.60c710391cd50a653d9a5c5537468a9d.jpg
#   inflating: test/a01-014-01-01_png.rf.ae09e7677bc93d50c7297a42d33200c6.jpg
#   inflating: test/a01-014-01-02_png.rf.c257382eb4e6555751dda75e1b8ec4ff.jpg
#   inflating: test/a01-014-01-03_png.rf.cb78777bb4c5a49b772493fc5a80cc23.jpg
#   inflating: test/a01-014-01-05_png.rf.fde37294c093ba2282b8d1a522fa7cfe.jpg
#   inflating: test/a01-014-02-03_png.rf.32b6359131f84732b72f50bf36b7dd9c.jpg
#   inflating: test/a01-014-02-04_png.rf.3b40b747cae990c6c0023c37e29b80f3.jpg
#   inflating: test/a01-014-03-01_png.rf.2b8b2be6a5d0ff99c0f9feb577348dd0.jpg
#   inflating: test/a01-014-03-02_png.rf.c0a950bfae53a5e64cee1feeb2811a6a.jpg
#   inflating: test/a01-014-03-03_png.rf.557c830410ca67cdcb160ebdce64976b.jpg
#   inflating: test/a01-014-03-04_png.rf.131fd96f406b76ea21e98c872870c704.jpg
#   inflating: test/a01-014-03-05_png.rf.f984316ccf0e5e6e57fdf737d3dadbc8.jpg
#   inflating: test/a01-014-03-06_png.rf.4bac9b1f03d3dadf1c81974b4bb68ac9.jpg
#   inflating: test/a01-014-03-07_png.rf.905001819ecb7bd47e073b9af58d445a.jpg
#   inflating: test/a01-014-03-08_png.rf.9610bf8eed9ff92e84548917df1cdd10.jpg
#   inflating: test/a01-014-04-01_png.rf.7dc5260e15be10126a260da2b3f40434.jpg
#   inflating: test/a01-014-04-02_png.rf.8fefa18904f87422f993f048673d4afa.jpg
#   inflating: test/a01-014-04-03_png.rf.9ad333c4b55de8fa61422cc84be3ba3e.jpg
#   inflating: test/a01-014-04-04_png.rf.9429782f83713c10432cf5ffe3050b7e.jpg
#   inflating: test/a01-014-04-05_png.rf.8f03aba3784cbe997b4fef1287e57775.jpg
#   inflating: test/a01-014-05-01_png.rf.af0cb13b9bfbd8880973fd8279cb4a3c.jpg
#   inflating: test/a01-014-05-02_png.rf.43bf158a8dff318e33570d406aa01c68.jpg
#   inflating: test/a01-014-05-05_png.rf.1fc4b22b15243b070dc116e296580383.jpg
#   inflating: test/a01-014-06-00_png.rf.da1e9fc3eae4bc044b18c3ae94ef3c91.jpg
#   inflating: test/a01-014-06-02_png.rf.3576a3b758daa6e4598248c0cfda30bf.jpg
#   inflating: test/a01-014-06-05_png.rf.6b90be5f8c29b97398429a8c80923add.jpg
#   inflating: test/a01-014-06-07_png.rf.9be9d8d472f20acd634d9a0832332357.jpg
#   inflating: test/a01-014-07-00_png.rf.4f11dd9ce5a9441e9c38f16d9aaa52c7.jpg
#   inflating: test/a01-014-07-05_png.rf.4abe1a0269ea23c5ec6051cd548eadf4.jpg
#   inflating: test/a01-014-07-07_png.rf.cf18c19a119ed2af0037ed5009509027.jpg
#   inflating: test/a01-014-08-00_png.rf.6a775377f4ea4b18c0cdbae943c1d411.jpg
#   inflating: test/a01-014-08-01_png.rf.625ff033c81f846f5bbf5e77856d843a.jpg
#   inflating: test/a01-014-08-02_png.rf.135c89ba6f0fa36c78a71e38ee6888a6.jpg
#   inflating: test/a01-014-08-04_png.rf.96f5616c74c80527a6b9c43d6f8f2f85.jpg
#   inflating: test/a01-014-08-05_png.rf.b83c6277abc186aac4128f731c521c81.jpg
#   inflating: test/a01-014-08-06_png.rf.979538c099152886bd2fe4ed49635ef7.jpg
#   inflating: test/a01-014-08-07_png.rf.18172bee38bad181338e37479fdb5981.jpg
#   inflating: test/a01-014-09-02_png.rf.8a5a780789ab88d758035e3b2d600964.jpg
#   inflating: test/a01-014u-00-00_png.rf.435477222cd40fa8c73b0010a72692ad.jpg
#   inflating: test/a01-014u-00-02_png.rf.3e1e16fa8fae64556a9bd959fdd11739.jpg
#   inflating: test/a01-014u-00-03_png.rf.0235e8935b5d5027573fecaa29aab29e.jpg
#   inflating: test/a01-014u-00-04_png.rf.7557291d53f62189f2eec22623f16d46.jpg
#   inflating: test/a01-014u-00-05_png.rf.c35766ed7617166913fc4e6abdd41647.jpg
#   inflating: test/a01-014u-01-00_png.rf.132681056ea012d2c0253f37e95b963c.jpg
#   inflating: test/a01-014u-01-02_png.rf.058019f8199a6ab77d5f94a0da426d9c.jpg
#   inflating: test/a01-014u-01-03_png.rf.b39412efe007d365c5ab63280f92194f.jpg
#   inflating: test/a01-014u-01-04_png.rf.264ea82afbc4aa4d9b95441ab307bf54.jpg
#   inflating: test/a01-014u-01-05_png.rf.8b5cf5dff751a49234b21db25d282460.jpg
#   inflating: test/a01-014u-02-00_png.rf.5516d303d75004fbf948d9150b9e2891.jpg
#   inflating: test/a01-014u-02-03_png.rf.043d5f866d95875b214fc33c30f33a7d.jpg
#   inflating: test/a01-014u-02-04_png.rf.79b374400dbf4350cd665f49a7e8fd19.jpg
#   inflating: test/a01-014u-02-05_png.rf.1cfae121ead093b544f9a8acb4273c6d.jpg
#   inflating: test/a01-014u-03-00_png.rf.901e090720464fac0623ddd07d333412.jpg
#   inflating: test/a01-014u-03-01_png.rf.5763ded06f08474ed0fc806b32fb89d6.jpg
#   inflating: test/a01-014u-03-04_png.rf.89bae38eabba12cb8b5ad050a063141f.jpg
#   inflating: test/a01-014u-03-06_png.rf.4e83eb1953cb704d412860d3c9642f75.jpg
#   inflating: test/a01-014u-03-07_png.rf.ce679ab962038b6e9fcff0a0c3e9817d.jpg
#   inflating: test/a01-014u-03-09_png.rf.465ef0faf20a3c7e6c864d5885283bad.jpg
#   inflating: test/a01-014u-04-01_png.rf.69c1d92f84a67b84024fb46f6ff8f603.jpg
#   inflating: test/a01-014u-04-04_png.rf.113faef96e5378dd65662c6278c2c8e5.jpg
#   inflating: test/a01-014u-05-00_png.rf.2611e610d948d14585157205e8baa92d.jpg
#   inflating: test/a01-014u-05-01_png.rf.fa5ecbe9d9a779b54aeb50d69c7e0849.jpg
#   inflating: test/a01-014u-05-03_png.rf.35d093270cc6dc621f8bac20f4dbd7a0.jpg
#   inflating: test/a01-014u-05-04_png.rf.e5795472dbfa00c3b1ed92d84283c74e.jpg
#   inflating: test/a01-014u-05-06_png.rf.a8f14aa26c9e39906caf7da41de684fd.jpg
#   inflating: test/a01-014u-06-00_png.rf.b237a9e9a1e0f82e65fda1de89f98b82.jpg
#   inflating: test/a01-014u-06-03_png.rf.ea26f0ee0cd1568a4ab12252d40c2bda.jpg
#   inflating: test/a01-014u-06-04_png.rf.0211ae5f7a2c390effb091cda51ccc4d.jpg
#   inflating: test/a01-014u-06-05_png.rf.6314a17e431fc8985f30ea01eb740a58.jpg
#   inflating: test/a01-014u-07-01_png.rf.7b4eee66fac1508ffc3e6dd11abff5cb.jpg
#   inflating: test/a01-014u-07-02_png.rf.7d994c70e5f904d5888aa39414291a53.jpg
#   inflating: test/a01-014u-07-03_png.rf.423f298cb703509d6c13f0fa7b3f2b63.jpg
#   inflating: test/a01-014u-07-05_png.rf.a716f3ce22d8cddae1a05a2393d8d4c9.jpg
#   inflating: test/a01-014u-07-06_png.rf.7474f05bfab7b2603aef69a7a691b2ac.jpg
#   inflating: test/a01-014x-00-02_png.rf.c69a02be4196a42a070b0e53bf18d864.jpg
#   inflating: test/a01-014x-00-03_png.rf.a2d10bdb1a37e744885132db0cfcc553.jpg
#   inflating: test/a01-014x-00-04_png.rf.25d06bfe799d1497cda8cf9b25bbdf0c.jpg
#   inflating: test/a01-014x-00-06_png.rf.2a65fff78d742a11c46dc8b95f402d24.jpg
#   inflating: test/a01-014x-01-01_png.rf.6cf435f91bde466f013380738b3ffe02.jpg
#   inflating: test/a01-014x-01-02_png.rf.c511a3d81ffe9cf474a0e1a9b10f950a.jpg
#   inflating: test/a01-014x-01-03_png.rf.10e334f2456d244ee79a490fac66162c.jpg
#   inflating: test/a01-014x-02-00_png.rf.5be93e79ea295e97b9e26903cd2c38db.jpg
#   inflating: test/a01-014x-02-02_png.rf.36b4b7448e4c355170c1a0726c22b0dc.jpg
#   inflating: test/a01-014x-02-05_png.rf.206b2fb4067bff2659e556fba582a21b.jpg
#   inflating: test/a01-014x-02-06_png.rf.73e8888c6dbe18e2c545d00db9fdf8f8.jpg
#   inflating: test/a01-014x-03-01_png.rf.80bb90aa5cad258cf452b45822a81f89.jpg
#   inflating: test/a01-014x-03-02_png.rf.4100e33f2f8ed7b0200554edc5f62035.jpg
#   inflating: test/a01-014x-03-03_png.rf.45c1bb2546f4697dbfd70c72b7c023b1.jpg
#   inflating: test/a01-014x-03-04_png.rf.79046e9f47487d18b8cff28658554ab4.jpg
#   inflating: test/a01-014x-03-05_png.rf.fe65c9e9b35be56a4f4b1aa5f0d46afa.jpg
#   inflating: test/a01-014x-03-06_png.rf.e49a5cff21eaab9fee32cb88ef02e13c.jpg
#   inflating: test/a01-014x-03-07_png.rf.2cd8739a5c352a87829eb86e48c23a67.jpg
#   inflating: test/a01-014x-03-09_png.rf.36c3e77cce87bb89ebbda16b3c618aca.jpg
#   inflating: test/a01-014x-04-01_png.rf.fb9b165aa48a2b78780a12039c6b49b1.jpg
#   inflating: test/a01-014x-04-02_png.rf.92bedefd97258bff4cc0deeb0968b242.jpg
#   inflating: test/a01-014x-04-03_png.rf.89605b0c2532886a0a276ec3df9a1e89.jpg
#   inflating: test/a01-014x-04-05_png.rf.5dccd122b10dabffd3c276b6d708de64.jpg
#   inflating: test/a01-014x-04-06_png.rf.88d54842f4a92591c6674d6d64b26604.jpg
#   inflating: test/a01-014x-05-01_png.rf.875009bdb98e0f4fb33064d12542dd20.jpg
#   inflating: test/a01-014x-05-02_png.rf.bd978d3af82e46625ac889dec7578f5e.jpg
#   inflating: test/a01-014x-05-03_png.rf.d8ce7e542e56ff560086d0bbbe4f9869.jpg
#   inflating: test/a01-014x-05-04_png.rf.52c03ff346c4796e3d5a9f783d71450d.jpg
#   inflating: test/a01-014x-05-06_png.rf.c76a61572104389eb46428f3b8c37ad9.jpg
#   inflating: test/a01-014x-05-07_png.rf.b6eb86ddf521a84d6f151291f4ffa606.jpg
#   inflating: test/a01-014x-05-08_png.rf.ab271c7eec7e263a5e28c4faa2fa4dd0.jpg
#   inflating: test/a01-014x-06-06_png.rf.cef3c9bba67c241313061afa053b3350.jpg
#   inflating: test/a01-014x-06-07_png.rf.39110cae2ca0771098e6e93c6c1fe802.jpg
#   inflating: test/a01-014x-07-00_png.rf.47e6799ea5a89a2d8acb81c4965938ff.jpg
#   inflating: test/a01-014x-07-03_png.rf.7c907ae6b9ec87359ce28ee0c98a0727.jpg
#   inflating: test/a01-014x-07-04_png.rf.af243f5baff5d018f2e32bd29ba71531.jpg
#   inflating: test/a01-014x-07-05_png.rf.9612d8772532ad51bc9c6c70318b91a1.jpg
#   inflating: test/a01-014x-07-06_png.rf.b596363b40cbcd947fa046228e46b890.jpg
#   inflating: test/a01-014x-07-07_png.rf.b0f6bc85863481f15595ca993acffb1d.jpg
#   inflating: test/a01-014x-08-01_png.rf.df39ba8ce25005a6f213aa4c853f46ba.jpg
#   inflating: test/a01-014x-08-03_png.rf.a41748de4474b06e84083ef0c0f87324.jpg
#   inflating: test/a01-014x-08-04_png.rf.f874b1c99f839309899160d57c9575ed.jpg
#   inflating: test/a01-014x-08-05_png.rf.609c9e15e6bcf6509f76e6f2c2d529d9.jpg
#   inflating: test/a01-014x-08-06_png.rf.5d1eaf9583c4aadd4e6866c83e1703e7.jpg
#   inflating: test/a01-014x-08-07_png.rf.6e9fe62070ef026deaaebc2e937feacb.jpg
#   inflating: test/a01-014x-09-01_png.rf.8f6827c5e6ff7c2f487027794a9e6a93.jpg
#   inflating: test/a01-014x-09-02_png.rf.2f0893057c54ec88ed78537bbe529ec2.jpg
#   inflating: test/a01-020-00-00_png.rf.63e6d6c17b5f80517445ee70c13dff0b.jpg
#   inflating: test/a01-020-00-01_png.rf.3cb8347d3a7f42822dc02689875d104b.jpg
#   inflating: test/a01-020-00-02_png.rf.d6665970ac281fcf126491847f647294.jpg
#   inflating: test/a01-020-00-03_png.rf.d6c782f0152833c46df99533e0accb67.jpg
#   inflating: test/a01-020-00-04_png.rf.27d0c9bd1238f28cf4944043f4f29176.jpg
#   inflating: test/a01-020-00-05_png.rf.4751f27d0161c5a9ec57aabef7888e63.jpg
#   inflating: test/a01-020-00-07_png.rf.a05ebfced6552c70c4dfd6e9e493d728.jpg
#   inflating: test/a01-020-01-00_png.rf.8e8917cc15f71d77978a1690aa676902.jpg
#   inflating: test/a01-020-01-01_png.rf.a636ec02ff1c6d72b33f7f43ff35fd90.jpg
#   inflating: test/a01-020-01-05_png.rf.0f6352d460ed891c0f02003e12f8dbf2.jpg
#   inflating: test/a01-020-01-06_png.rf.25787f38e2f91eae8df2d5b4f3d356e8.jpg
#   inflating: test/a01-020-02-06_png.rf.81478a63a1e5239241d45af8d3e04f8b.jpg
#   inflating: test/a01-020-02-07_png.rf.b46c90acb1e27928113263f1b8375e3b.jpg
#   inflating: test/a01-020-03-00_png.rf.9155a8907d6d0b4ddf659c6b2ec0ee43.jpg
#   inflating: test/a01-020-03-01_png.rf.00353a9d31d65bc5a25c4e3db2bc5df5.jpg
#   inflating: test/a01-020-03-02_png.rf.60db6b3119f58c7b0a2d0aed8f4036b0.jpg
#   inflating: test/a01-020-03-07_png.rf.a3ee6365d9c876d00834746028b05640.jpg
#   inflating: test/a01-020-04-00_png.rf.b9658225058270c491d3733bb3a96da2.jpg
#   inflating: test/a01-020-04-02_png.rf.f33e357cf5d5c78569ea45e65f7503d3.jpg
#   inflating: test/a01-020-04-03_png.rf.b3fa854a00a39f2227a602e3494c879e.jpg
#   inflating: test/a01-020-04-04_png.rf.b7ec65a66ada390be130ecb5dd830688.jpg
#   inflating: test/a01-020-04-05_png.rf.39c299bf6882b7fc3b1f0e0c3a8cf82c.jpg
#   inflating: test/a01-020-04-06_png.rf.50bb4c31aac0bc39a1f57ebf63a2dc87.jpg
#   inflating: test/a01-020-04-07_png.rf.93e2ed2ff37c08fa209152ceff494aeb.jpg
#   inflating: test/a01-020-05-01_png.rf.664bb8f55d039ad03d55e0b437fc3bc8.jpg
#   inflating: test/a01-020-05-05_png.rf.1f4bf2df1a9bb683432fbd1d2080bd66.jpg
#   inflating: test/a01-020-05-06_png.rf.2d1e19da5c3af942511afb6bdd2649b9.jpg
#   inflating: test/a01-020-06-00_png.rf.943246a0c02a21c4abf85ed0baf7f169.jpg
#   inflating: test/a01-020-06-01_png.rf.8c4552522aed182a3cf217da5d992b57.jpg
#   inflating: test/a01-020-06-02_png.rf.42fada0350daad64c8343c30775cf9ed.jpg
#   inflating: test/a01-020-06-03_png.rf.64938f18d6507f910d5ac883231f3d01.jpg
#   inflating: test/a01-020-06-06_png.rf.4ed2dbe74265859977c97a9b89915523.jpg
#   inflating: test/a01-020-07-00_png.rf.3872141938f6b7c99eaf5064f282a3ed.jpg
#   inflating: test/a01-020-07-01_png.rf.6208b914c62431a547ba0e3e14113cf5.jpg
#   inflating: test/a01-020-07-02_png.rf.5bcf1035ef0b1192071539014426cc4d.jpg
#   inflating: test/a01-020-07-03_png.rf.be3b97efa386939af62adc07183e825d.jpg
#   inflating: test/a01-020-07-05_png.rf.e70f9337d8f1a2e1997835f0561c6784.jpg
#   inflating: test/a01-020-07-06_png.rf.23d8037a6a2f670ca8845e98ad515486.jpg
#   inflating: test/a01-020-07-07_png.rf.a3b84fc79966ab269c1a1f4fd14e26b5.jpg
#   inflating: test/a01-020-08-00_png.rf.fa711c8f073e12d7663aa3a7635e4f75.jpg
#   inflating: test/a01-020-08-03_png.rf.4e04136080636f09d0d7c12fbdc1b135.jpg
#   inflating: test/a01-020u-00-00_png.rf.352348a7545122f1ae36c5ce3b3c01d1.jpg
#   inflating: test/a01-020u-00-01_png.rf.82dc39d05e544c8dbfcd9c14756019e8.jpg
#   inflating: test/a01-020u-00-03_png.rf.820114f463c3b576617699c16ec4f623.jpg
#   inflating: test/a01-020u-00-04_png.rf.c703b72b35aac5f2f39181e99aff9d84.jpg
#   inflating: test/a01-020u-00-06_png.rf.0cd58c99d1b34ded70a22ced1ffda9ef.jpg
#   inflating: test/a01-020u-01-00_png.rf.ded0afb204cc69e107d927eaaa023653.jpg
#   inflating: test/a01-020u-01-01_png.rf.c29b393270a42a3f971b8257abe1d491.jpg
#   inflating: test/a01-020u-01-02_png.rf.d4c99d9e21ec22e2c88853d74616fb85.jpg
#   inflating: test/a01-020u-01-04_png.rf.6258391f4a7a1d4d8cac6f3bfdc63930.jpg
#   inflating: test/a01-020u-01-05_png.rf.6044056f3dcaa6bce54fb4abd62db87f.jpg
#   inflating: test/a01-020u-02-02_png.rf.848d5e76b7ff7d72b832b58ca560dca6.jpg
#   inflating: test/a01-020u-02-03_png.rf.7d5d6f4e50d07cab6946bcb878200049.jpg
#   inflating: test/a01-020u-02-06_png.rf.956f7e47ca233accc449ffffbf11a637.jpg
#   inflating: test/a01-020u-02-07_png.rf.6bf52ea3db6be39d1747ddbd7e6203b7.jpg
#   inflating: test/a01-020u-02-08_png.rf.d0721c449ed449e5949b039247ca9a9d.jpg
#   inflating: test/a01-020u-03-00_png.rf.8ccbfd7990bbbe7158c502f23c0c86a4.jpg
#   inflating: test/a01-020u-03-01_png.rf.472bb34fcf9a929ebb4e3c0da1939a52.jpg
#   inflating: test/a01-020u-03-04_png.rf.79e6c0efc8517f41e43fc6ba673dc2cd.jpg
#   inflating: test/a01-020u-03-05_png.rf.ac5cd394c66ba71a8f30853116455693.jpg
#   inflating: test/a01-020u-03-07_png.rf.b85242adb9a973377059a6b76562c3f7.jpg
#   inflating: test/a01-020u-04-00_png.rf.2cd61ea59b4fc4d49b8b809265bd54f2.jpg
#   inflating: test/a01-020u-04-04_png.rf.e472c5bce67bfc85a940a650d53f71a4.jpg
#   inflating: test/a01-020u-04-06_png.rf.818d5968f17a64f055a44c685fcf7356.jpg
#   inflating: test/a01-020u-04-07_png.rf.5dee0e0e3a2f379a141cbe1d549d849e.jpg
#   inflating: test/a01-020u-05-00_png.rf.471aa5eb4b019c96ea3fc7ef398fff0d.jpg
#   inflating: test/a01-020u-05-01_png.rf.16ace79b4fdb75fa4550bd10706eb1ff.jpg
#   inflating: test/a01-020u-05-02_png.rf.3d0e2d4509af881aa363bb96ec9970c7.jpg
#   inflating: test/a01-020u-05-03_png.rf.319f11b53bbf6ed816e3287f927e8436.jpg
#   inflating: test/a01-020u-05-05_png.rf.4d0c18546fcc412f5f2729ceaf1e4be8.jpg
#   inflating: test/a01-020u-06-02_png.rf.86c57c7fa4b653005f53227e0f67dc69.jpg
#   inflating: test/a01-020u-06-03_png.rf.c9e4509afd73e1f486a2e2132d9a42de.jpg
#   inflating: test/a01-020u-06-04_png.rf.0bcff6d0d38e683f02a2871dfefb590c.jpg
#   inflating: test/a01-020u-07-01_png.rf.7ca49ecc4588bc5fe82d9014044b89b6.jpg
#   inflating: test/a01-020u-07-04_png.rf.c030307ec326d78b29f85a780cf6158e.jpg
#   inflating: test/a01-020u-08-00_png.rf.8487652a28f609708ff6403579155f87.jpg
#   inflating: test/a01-020u-08-02_png.rf.37434283a0bc52fa30c493189b51a180.jpg
#   inflating: test/a01-020u-08-03_png.rf.c06cfa34775f135ca578468546939934.jpg
#   inflating: test/a01-020u-08-04_png.rf.159a189a9ef4d8da3dda1fef56c16983.jpg
#   inflating: test/a01-020u-08-05_png.rf.10458d697cf8cd8a3aeb174e86e97120.jpg
#   inflating: test/a01-020u-09-00_png.rf.b9438c7fe8106c40bf1f91e9f241d2cf.jpg
#   inflating: test/a01-020u-09-01_png.rf.84837e784004c728d1a689f37dda229f.jpg
#   inflating: test/a01-020u-09-02_png.rf.c18db6c5665bd7732014642dba1b6fc3.jpg
#   inflating: test/a01-020x-00-00_png.rf.764e02d440331f6bbf7bcbdf3f94dad5.jpg
#   inflating: test/a01-020x-00-01_png.rf.da182cfda618143ae37262ccb2ee3195.jpg
#   inflating: test/a01-020x-00-02_png.rf.fea13eb3a4fa5540a19d742520f1930c.jpg
#   inflating: test/a01-020x-00-03_png.rf.e562a88803c5b39aa041686e508162ea.jpg
#   inflating: test/a01-020x-00-04_png.rf.b065324ea51037cb7ddad9adfca664de.jpg
#   inflating: test/a01-020x-00-05_png.rf.7cae6a7b3f64bdb02cf903ed6ac4a52d.jpg
#   inflating: test/a01-020x-00-06_png.rf.cb593386b29f49b9d3e06d21e4d07dee.jpg
#   inflating: test/a01-020x-01-01_png.rf.94b7624d3ecd093d492774a456b69b2e.jpg
#   inflating: test/a01-020x-01-02_png.rf.3d2bd8eea1bb3ea164456c1ace5e95ee.jpg
#   inflating: test/a01-020x-01-03_png.rf.073ca177a5e2f8604bbd0c3bbb2ce145.jpg
# ...
#   inflating: test/a02-017-07-00_png.rf.d385e8c93cd5208c2d11532b71986e68.jpg
#   inflating: test/a02-017-07-02_png.rf.d1b3c6269a91c4ac6329432cf800584b.jpg
#   inflating: test/a02-020-00-00_png.rf.303bd178a9779be60cf037852ccef034.jpg
#   inflating: test/a02-020-01-03_png.rf.8c5122894621e3dcea3e13754b1899a0.jpg
#   inflating: test/a02-020-01-04_png.rf.f0fbedc6e7b56aa6b07f93bdde54dc1d.jpg
#   inflating: test/a02-020-01-05_png.rf.c4b2e9246035789327f460eebe76f0a4.jpg
#   inflating: test/a02-020-02-00_png.rf.9262eb622da35b9af6449ba3dc491328.jpg
#   inflating: test/a02-020-02-03_png.rf.0ac4ababaa7b9a7d407f6c44ae1a0e6b.jpg
#   inflating: test/a02-020-02-04_png.rf.78adff3cdb4a1ec6189c6f9500e6bd98.jpg
#   inflating: test/a02-020-02-05_png.rf.26186de780148a291dc2851caeadb2d5.jpg
#   inflating: test/a02-020-02-07_png.rf.a441647122135012aaf94168acb3ab64.jpg
#   inflating: test/a02-020-03-01_png.rf.774b6ccc77ae9f4b1bae149532d2b705.jpg
#   inflating: test/a02-020-03-06_png.rf.ea87d5df6e6e51cc79fea58e192493eb.jpg
#   inflating: test/a02-020-04-03_png.rf.62355d3c10ea88a971bf0b510e002585.jpg
#   inflating: test/a02-020-04-04_png.rf.04f0bb52ba90f6c0bbe404fa688d7799.jpg
#   inflating: test/a02-020-04-08_png.rf.78bbd1d58b2379ebe058c3d0e20fab69.jpg
#   inflating: test/a02-020-05-00_png.rf.336b2b6e0a84eda9ae8d1b7fbedfd7bf.jpg
#   inflating: test/a02-020-05-01_png.rf.b6e83a14a0ea23f7bea499f9dfbe8d72.jpg
#   inflating: test/a02-020-05-08_png.rf.e58b4ae6b6f91144295a6f840adb5cf5.jpg
#   inflating: test/a02-020-06-00_png.rf.ecee7fc043d1cda8005b829b0c263f06.jpg
#   inflating: test/a02-020-06-01_png.rf.44ac345c6a146d1158e26f5b0730805a.jpg
#   inflating: test/a02-024-01-00_png.rf.979ea9aa5d934a0a772f2ec37e8dfeb3.jpg
#   inflating: test/a02-024-01-04_png.rf.5c4106fd2b7844790c7a1af998f38572.jpg
#   inflating: test/a02-024-01-05_png.rf.4ca618f9a887f50eb4e16385e871c2f8.jpg
#   inflating: test/a02-024-02-05_png.rf.2587811ace34cc068b7906343d6563c4.jpg
#   inflating: test/a02-024-03-00_png.rf.240713a4ddf51a76e335e9cdc73cbe0d.jpg
#   inflating: test/a02-024-03-01_png.rf.7ff3b4e522b76e38ff081a400fd04eee.jpg
#   inflating: test/a02-024-03-11_png.rf.00e9b8fc9353df08709aefb723d00872.jpg
#   inflating: test/a02-024-04-01_png.rf.a4ac16630652d6fe371df023aa918c42.jpg
#   inflating: test/a02-024-04-03_png.rf.015ee5127d1ce939d8af9aaf2136fbd8.jpg
#   inflating: test/a02-024-04-05_png.rf.e60862e6deb18fd54ec6570ac55fec7d.jpg
#   inflating: test/a02-024-04-07_png.rf.9ee8dc44d502a6a00909527a1c806cc7.jpg
#   inflating: test/a02-024-05-03_png.rf.1203aeaae7e718e6622c41c6b1b249b5.jpg
#   inflating: test/a02-024-05-06_png.rf.d903c18651a96f61d6596c68f3f293b5.jpg
#   inflating: test/a02-024-07-00_png.rf.5c8e94b1c2624831644b1b9630aeb01e.jpg
#   inflating: test/a02-024-07-02_png.rf.2b562ad4eaef967b62b6e92028940034.jpg
#   inflating: test/a02-024-07-03_png.rf.aced224ec04dba26d637003fa8cfa64a.jpg
#   inflating: test/a02-027-00-00_png.rf.2a16ea9724c9dd964f1d6e841337343a.jpg
#   inflating: test/a02-027-00-02_png.rf.1fe7002fd2c510e5c35f49bfe5c672bb.jpg
#   inflating: test/a02-027-00-06_png.rf.4fad2b4ead105884c52d05e44aaf7378.jpg
#   inflating: test/a02-027-01-01_png.rf.252e461bd2ced47df2451782ca7cb717.jpg
#   inflating: test/a02-027-01-07_png.rf.3656605afb91e6e6358ce569ce079d35.jpg
#   inflating: test/a02-027-01-08_png.rf.246aac52a19a1ee3f862676ebc06990c.jpg
#   inflating: test/a02-027-02-00_png.rf.d6a7620ddb0a0bd18986147c4d7634c3.jpg
#   inflating: test/a02-027-02-03_png.rf.3435ec03139de65f62012a51fac265c1.jpg
#   inflating: test/a02-027-02-04_png.rf.69b5c2a36dcc0167b16cf726d6384f9f.jpg
#   inflating: test/a02-027-02-07_png.rf.75e751a44cf89698348dfb3980b14f71.jpg
#   inflating: test/a02-027-02-08_png.rf.f0c206a56a16ef580af18f7d9c1815cb.jpg
#   inflating: test/a02-027-03-00_png.rf.cd365306a6f37a3354a9e291331d7258.jpg
#   inflating: test/a02-027-03-01_png.rf.b07ef1d822c97e50c063ebfdc8fb3370.jpg
#   inflating: test/a02-027-03-02_png.rf.435a96376255495450d8120078f58d52.jpg
#   inflating: test/a02-027-03-04_png.rf.91949316b4323ddc7afcadcf2396ac07.jpg
#   inflating: test/a02-027-03-05_png.rf.c0c8fccf3310f751a96cb740cc93a0bc.jpg
#   inflating: test/a02-027-03-06_png.rf.29ff033b25ba81aeb6a20b5563347d6d.jpg
#   inflating: test/a02-027-04-03_png.rf.cf7525fc98fe3a9be75689a80ad524a3.jpg
#   inflating: test/a02-027-04-06_png.rf.9decd24641b02acb985ff94d96e477f9.jpg
#   inflating: test/a02-027-05-00_png.rf.d7382f8a2d30f1e969c95cdfeef70ce0.jpg
#   inflating: test/a02-027-05-06_png.rf.59cf55a747a48d0686db5e28a217fc3d.jpg
#   inflating: test/a02-027-05-09_png.rf.e6315e25e75a25bf59f469acce74acf0.jpg
#   inflating: test/a02-027-05-11_png.rf.2f83bc9ed97d4b57e16647938c18024c.jpg
#   inflating: test/a02-027-06-01_png.rf.59154ce80314cc9d720631ac83d9aabe.jpg
#   inflating: test/a02-027-07-01_png.rf.92af3608535fda519199e7b1ff6725fd.jpg
#   inflating: test/a02-027-07-04_png.rf.abebd118f458e04cb3bd6fcc572ce47f.jpg
#   inflating: test/a02-027-07-07_png.rf.df0a7bd8aa7936ff5330ad3d529999d1.jpg
#   inflating: test/a02-027-08-01_png.rf.4d1b37a27fffb0fc3f13a14d6da727f2.jpg
#   inflating: test/a02-027-08-02_png.rf.70598efbef972b6f2dac4db6833f713a.jpg
#   inflating: test/a02-027-08-09_png.rf.d93558c560e41ab1db435b03dfcfe76a.jpg
#   inflating: test/a02-027-09-01_png.rf.750036f033faa0d9425011de1dd55f07.jpg
#   inflating: test/a02-032-00-07_png.rf.acff49a84c840786e8777fe89bca0ef1.jpg
#   inflating: test/a02-032-01-05_png.rf.22bf072ea28812722fc88034ed22cca5.jpg
#   inflating: test/a02-032-02-03_png.rf.11ffd6eb5aad01467cf09df25ffd40e1.jpg
#   inflating: test/a02-032-02-06_png.rf.36f220bef6ed19b30356da64054b5898.jpg
#   inflating: test/a02-032-02-07_png.rf.48e23275f03689fcea0af61cac9fcbdd.jpg
#   inflating: test/a02-032-02-08_png.rf.ab4bf9d729b25e143b13798038d233a8.jpg
#   inflating: test/a02-032-03-04_png.rf.d37226b231ec74538fa6f851abdcd504.jpg
#   inflating: test/a02-032-03-06_png.rf.f7bb662af18be2bcb4169ebc06dac96c.jpg
#   inflating: test/a02-032-03-07_png.rf.205b3cc062fae24e4b86cbae6ca57965.jpg
#   inflating: test/a02-032-03-08_png.rf.088af327ce6afdf11dd93c3559543ac9.jpg
#   inflating: test/a02-032-04-03_png.rf.16d3a3c9bfb847c6b9272eb5b99af394.jpg
#   inflating: test/a02-032-04-05_png.rf.ca55cf8ca74ad9615a699ab5fffeb866.jpg
#   inflating: test/a02-032-04-07_png.rf.5f72e90ed8ab2d5d7c80924f25504e4d.jpg
#   inflating: test/a02-032-04-12_png.rf.33c4fce3de2fdf13af5d95ee003d3480.jpg
#   inflating: test/a02-032-05-00_png.rf.e2acd43e97e959091a3688058cb025f5.jpg
#   inflating: test/a02-032-05-02_png.rf.dfa4a8b7963d21860a6e7a8255823db0.jpg
#   inflating: test/a02-032-05-05_png.rf.a092f86b0805dabe919768e94cb8211d.jpg
#   inflating: test/a02-032-06-00_png.rf.84fb82de30cafd4f02b71b929b5562cf.jpg
#   inflating: test/a02-032-06-03_png.rf.a3e36b9fff23b7078fe0b17bb2237ffc.jpg
#   inflating: test/a02-032-06-04_png.rf.1b2a60a3e206d0a584831458b716149b.jpg
#   inflating: test/a02-037-00-02_png.rf.4807fb11334c9791a065035fcc54cdb7.jpg
#   inflating: test/a02-037-00-05_png.rf.07e5c54b351a03337d1142d64d4ae197.jpg
#   inflating: test/a02-037-00-08_png.rf.d814140ea642a3e1a06ff35a53e195e5.jpg
#   inflating: test/a02-037-01-03_png.rf.7e2130b158f35f14ad23091ce7113e4b.jpg
#   inflating: test/a02-037-02-05_png.rf.f7fa9be6999bb16ddc44011bb97aadbd.jpg
#   inflating: test/a02-037-03-00_png.rf.52f6447568fc7446635b40cdf86c0126.jpg
#   inflating: test/a02-037-03-03_png.rf.d061572778de81bbc196c2add1dba227.jpg
#   inflating: test/a02-037-03-05_png.rf.e228cd863776e6b67422d8c08f440eba.jpg
#   inflating: test/a02-037-04-01_png.rf.54d61036d7a780137cd45e0ce191412c.jpg
#   inflating: test/a02-037-04-02_png.rf.fe8ab9402b1794ffc74c4ebf2744696e.jpg
#   inflating: test/a02-037-04-04_png.rf.76c7956a4254299a0df3e24bf35fc1ec.jpg
#   inflating: test/a02-037-04-06_png.rf.fe5576b614d18232afbda42b4d1b7274.jpg
#   inflating: test/a02-037-04-09_png.rf.5181428d48ab0f34af49916f2732bb0c.jpg
#   inflating: test/a02-037-04-10_png.rf.9baeb969c5c4980d34fe841a1c41586a.jpg
#   inflating: test/a02-037-05-00_png.rf.baf0369ba21179239c40e0c6c4e53c96.jpg
#   inflating: test/a02-037-05-01_png.rf.529eadb5e8713d28137b2471b70351c9.jpg
#   inflating: test/a02-037-05-06_png.rf.2523a5b105182a8b1734d5e0faa1207b.jpg
#   inflating: test/a02-037-06-00_png.rf.d74e6400ab68cac3811f3fffa6cfbaf6.jpg
#   inflating: test/a02-037-06-01_png.rf.4475ae10cdbcea99294835294a30de2c.jpg
#   inflating: test/a02-037-06-08_png.rf.957f18811747ae09d6926a5a2086e47e.jpg
#   inflating: test/a02-037-08-04_png.rf.cdc42dc06946fd9da3b0bc412690131c.jpg
#   inflating: test/a02-037-08-09_png.rf.26f3f833861fee2013ba2520c8406b9a.jpg
#   inflating: test/a02-037-09-06_png.rf.7a81cf79b42d0ec469cb380d1067eb01.jpg
#   inflating: test/a02-042-00-00_png.rf.b78344cf5426479761f2eb07b52f2664.jpg
#   inflating: test/a02-042-00-01_png.rf.ed6b30571d3f8f8048bca13b171733b5.jpg
#   inflating: test/a02-042-00-02_png.rf.be4e0b3b06afa5ca12977e06c676467a.jpg
#   inflating: test/a02-042-00-06_png.rf.c8c8cc0e1890f96e238adac56a4104e9.jpg
#   inflating: test/a02-042-00-08_png.rf.0d22247e31fc812157d9ab3de2195f04.jpg
#   inflating: test/a02-042-01-01_png.rf.687eb9d0659ea994534d76d8d31868e1.jpg
#   inflating: test/a02-042-01-03_png.rf.102f1ff90e62da6e7511335797c0a8cd.jpg
#   inflating: test/a02-042-02-01_png.rf.2e808d34d5a91d5a76f652a94c8af936.jpg
#   inflating: test/a02-042-02-02_png.rf.b4ec1b64ed204e5a2d84dd0b3f4b9258.jpg
#   inflating: test/a02-042-02-08_png.rf.5c13d04e0c351b7acac34e1698a50160.jpg
#   inflating: test/a02-042-03-02_png.rf.6399c277d090240215b74361f5294136.jpg
#   inflating: test/a02-042-04-00_png.rf.a7bb8ef0aba8b046f4860effdfa04d70.jpg
#   inflating: test/a02-042-04-05_png.rf.97843b1a3813473cfce8424bb525b7d5.jpg
#   inflating: test/a02-042-04-06_png.rf.db4fe1b707a5df6470032a7d4fba1b56.jpg
#   inflating: test/a02-042-04-08_png.rf.6bc9b6694c575ff818e492fe536ba641.jpg
#   inflating: test/a02-042-05-01_png.rf.1ec850bd9a78b938dc46a176b9a28ac8.jpg
#   inflating: test/a02-042-05-04_png.rf.940dd530f0630ee18edb202704b01adc.jpg
#   inflating: test/a02-042-05-06_png.rf.406a6aa41d05a89eb153669171c75506.jpg
#   inflating: test/a02-042-05-09_png.rf.1bb6916592ab442fe15c2a51b312d05a.jpg
#   inflating: test/a02-042-06-01_png.rf.ccd3a82ebadbae93085d4d6660b6f1cc.jpg
#   inflating: test/a02-042-06-02_png.rf.da0ee138c65a70941d6a00c50996145c.jpg
#   inflating: test/a02-042-06-03_png.rf.eb27a5221278441bd8ed306506bab3a4.jpg
#   inflating: test/a02-042-06-04_png.rf.09bd48dec113edd34be3e8032073bfda.jpg
#   inflating: test/a02-042-06-06_png.rf.b9dc186ca602e3065aeaced04773e148.jpg
#   inflating: test/a02-046-00-00_png.rf.85dfdd628f01502aba44276a4b598c36.jpg
#   inflating: test/a02-046-00-03_png.rf.e45220f997aeeb5009d31034c53dc86e.jpg
#   inflating: test/a02-046-00-09_png.rf.ece52d12dd64dd372061f647b4e5869f.jpg
#   inflating: test/a02-046-01-01_png.rf.dbb1cd52b92eca99e6137da09d82dfd9.jpg
#   inflating: test/a02-046-01-03_png.rf.5b0511a513cd4eb63306ba16186db68a.jpg
#   inflating: test/a02-046-01-05_png.rf.e1202a38c5e0204c9389f01904c67e3f.jpg
#   inflating: test/a02-046-02-00_png.rf.0c93c63511132490f9a3c4eda8255896.jpg
#   inflating: test/a02-046-02-01_png.rf.421f755a26b0cf1e60d521c83283364e.jpg
#   inflating: test/a02-046-02-04_png.rf.e6e9ff70b173facab3c71c1567f2857c.jpg
#   inflating: test/a02-046-02-05_png.rf.77d332946485b54c3788d97d303bcfb5.jpg
#   inflating: test/a02-046-03-00_png.rf.800aea153de1580bec570e8f825b3492.jpg
#   inflating: test/a02-046-03-01 - Copy_png.rf.0fbc8a040bcc325ad41bedd66a2a8d5b.jpg
#   inflating: test/a02-046-03-04_png.rf.8b5d7e1d5cca112db599b4e5925fc65c.jpg
#   inflating: test/a02-046-04-02_png.rf.c10d5bb1311136d2768984cb52ac6efe.jpg
#   inflating: test/a02-046-04-07_png.rf.31e6d52b0666ccdb30f2bb14ed9d9467.jpg
#   inflating: test/a02-046-05-07_png.rf.9a2997b11188ec58184919363ffb2c28.jpg
#   inflating: test/a02-046-05-11_png.rf.ada6bd61f907fdcb4348ffe1d8f20528.jpg
#   inflating: test/a02-046-05-12_png.rf.791e566842439075618bdc6bb50580ca.jpg
#   inflating: test/a02-046-06-00_png.rf.e8366705e99c38f0a38316747df77448.jpg
#   inflating: test/a02-046-06-04_png.rf.6c6dc303db5ee7614c23904912c0fb77.jpg
#   inflating: test/a02-046-06-06_png.rf.ce25aaf8fb257ad2b08d532a89a86e7b.jpg
#   inflating: test/a02-046-07-05_png.rf.bb82c38fa238d2a50ba1152c24d077f1.jpg
#   inflating: test/a02-050-00-01_png.rf.b9b09de405f96493cf7b1da489244405.jpg
#   inflating: test/a02-050-00-02_png.rf.28c24ca2738e2dd95b3e80f9c96a923d.jpg
#   inflating: test/a02-050-00-06_png.rf.be37b384459103ba40483b8856dc9ffa.jpg
#   inflating: test/a02-050-01-00_png.rf.b610049ab24cd69db811f54f274b5a6d.jpg
#   inflating: test/a02-050-01-04_png.rf.ed0f077a766ae66af7fea66e943bab59.jpg
#   inflating: test/a02-050-01-06_png.rf.f78c36092122d22ebbe72fb500cf59a9.jpg
#   inflating: test/a02-050-02-00_png.rf.58ec15af08ace0a57c50d1868278888f.jpg
#   inflating: test/a02-050-02-03_png.rf.9553fa8bd1bf137005507830cca1e414.jpg
#   inflating: test/a02-050-02-07_png.rf.dba80079b837f094ffd8e18a6bef5b14.jpg
#   inflating: test/a02-050-02-08_png.rf.8ae74ceb67eadabaa90dbd7a1c53ff38.jpg
#   inflating: test/a02-050-03-01_png.rf.39ed663a99c63b3c4600c85f7f122fdb.jpg
#   inflating: test/a02-050-04-03_png.rf.15b908a28b0a9c1a89bd65f9686543c5.jpg
#   inflating: test/a02-050-05-02_png.rf.46e9ec379dd1a7353793419f3c6365d0.jpg
#   inflating: test/a02-053-00-01_png.rf.8ba049938f6e11f8ca068cb9ae460afd.jpg
#   inflating: test/a02-053-00-02_png.rf.0bdeb2b2cde1f20afb907993ee33ef20.jpg
#   inflating: test/a02-053-00-07_png.rf.efc531214c0f90ded1b982aa63680d43.jpg
#   inflating: test/a02-053-01-03_png.rf.13e811267db9f48be48f8b2503cc1527.jpg
#   inflating: test/a02-053-01-05_png.rf.ceda2223955e2a3b81b12d7cbb98a48a.jpg
#   inflating: test/a02-053-01-11_png.rf.5331c5cfedfc1fefdf0675c1474d2f53.jpg
#   inflating: test/a02-053-02-00_png.rf.272d7275690662e7b9b6256e5bfef9dc.jpg
#   inflating: test/a02-053-02-04_png.rf.61f76c8a5d2a911225fdc4c00d194b3b.jpg
#   inflating: test/a02-053-02-05_png.rf.9b2d75318d315888b58b5f57b9717445.jpg
#   inflating: test/a02-053-03-00_png.rf.9a7d541ad571ca1a809a1e1ce3634bde.jpg
#   inflating: test/a02-053-03-02_png.rf.f4a618e2fd5aed1168d6e51e41d5f879.jpg
#   inflating: test/a02-053-03-04_png.rf.5fca4df5d11a1b5399b0464cab2d7534.jpg
#   inflating: test/a02-053-03-05_png.rf.479413431a18676eef1826d3e1cb80f2.jpg
#   inflating: test/a02-053-04-01_png.rf.872cebbf60f5b254c415ec3073ac9d4e.jpg
#   inflating: test/a02-053-04-02_png.rf.a9483f95152dde298c5572d5f6d38616.jpg
#   inflating: test/a02-053-04-03_png.rf.6d4c6953df274b64ec45a64e2099bdac.jpg
#   inflating: test/a02-053-04-04_png.rf.585dd0ad3c93cb11d2a2c4bfb4aa110c.jpg
#   inflating: test/a02-053-04-05_png.rf.59a2c6291d8889e3b76416954d75642b.jpg
#   inflating: test/a02-053-04-06_png.rf.d28311526e7a615cb93eed0f968506fe.jpg
#   inflating: test/a02-053-06-00_png.rf.8e16d438b7c3f8ec059240b24c4167f9.jpg
#   inflating: test/a02-053-06-04_png.rf.ecba23aa75c1a6f2318d60cb17ccfc93.jpg
#   inflating: test/a02-053-06-06_png.rf.a115cf3bb5a204f34fc677ec8a42c411.jpg
#   inflating: test/a02-057-02-03_png.rf.4a4efcc9fa5b1d674e5b901f6550289b.jpg
#   inflating: test/a02-057-03-00_png.rf.6b05629a09e9b3497917b2985507dbe4.jpg
#   inflating: test/a02-057-03-04_png.rf.b007b886a3dbb6469519dc1f41badeca.jpg
#   inflating: test/a02-057-05-04_png.rf.2983ac93bbad8303c5cb3c03f7a0e358.jpg
#   inflating: test/a02-057-06-00_png.rf.29e3da05110bb4993cd7143576e9e461.jpg
#   inflating: test/a02-057-07-00_png.rf.0df9f9b3ef7b83bd99adb64db15a4cc8.jpg
#   inflating: test/a02-057-07-07_png.rf.060e400be32c4a1dbeb8eb80e5c65ed2.jpg
#   inflating: test/a02-057-08-00_png.rf.23303591c71b582612e026af7ecabb8b.jpg
#   inflating: test/a02-062-00-01_png.rf.50e83d3c7cfcaf287acd3deb36b62672.jpg
#   inflating: test/a02-062-00-02_png.rf.6ec9f6790d4bdec33786f0d581b0548d.jpg
#   inflating: test/a02-062-00-03_png.rf.1762cd4e1acfaf5a8a05f51d218b7cbf.jpg
#   inflating: test/annotations.txt
# /content/drive/MyDrive/GraduationProject/test

# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import math
import cv2
import copy
from matplotlib import pyplot as plt
import tensorflow as tf
import pandas as pd
import os

from sklearn.metrics import average_precision_score

from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D, Dropout
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, TimeDistributed
from keras.engine.topology import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.objectives import categorical_crossentropy

from keras.models import Model
from keras.utils import generic_utils
from keras.engine import Layer, InputSpec
from keras import initializers, regularizers

# %%
class Config:

	def __init__(self):

		# Print the process or not
		self.verbose = True

		# Name of base network
		self.network = 'vgg'

		# Setting for data augmentation
		self.use_horizontal_flips = False
		self.use_vertical_flips = False
		self.rot_90 = False

		# Anchor box scales
    # Note that if im_size is smaller, anchor_box_scales should be scaled
    # Original anchor_box_scales in the paper is [128, 256, 512]
		self.anchor_box_scales = [64, 128, 256] 

		# Anchor box ratios
		self.anchor_box_ratios = [[1, 1], [1./math.sqrt(2), 2./math.sqrt(2)], [2./math.sqrt(2), 1./math.sqrt(2)]]

		# Size to resize the smallest side of the image
		# Original setting in paper is 600. Set to 300 in here to save training time
		self.im_size = 300

		# image channel-wise mean to subtract
		self.img_channel_mean = [103.939, 116.779, 123.68]
		self.img_scaling_factor = 1.0

		# number of ROIs at once
		self.num_rois = 4

		# stride at the RPN (this depends on the network configuration)
		self.rpn_stride = 16

		self.balanced_classes = False

		# scaling the stdev
		self.std_scaling = 4.0
		self.classifier_regr_std = [8.0, 8.0, 4.0, 4.0]

		# overlaps for RPN
		self.rpn_min_overlap = 0.3
		self.rpn_max_overlap = 0.7

		# overlaps for classifier ROIs
		self.classifier_min_overlap = 0.1
		self.classifier_max_overlap = 0.5

		# placeholder for the class mapping, automatically generated by the parser
		self.class_mapping = None

		self.model_path = None

# %%
def get_data(input_path):
	"""Parser the data from annotation file
	
	Args:
		input_path: annotation file path

	Returns:
		all_data: list(filepath, width, height, list(bboxes))
		classes_count: dict{key:class_name, value:count_num} 
			e.g. {'Car': 2383, 'Mobile phone': 1108, 'Person': 3745}
		class_mapping: dict{key:class_name, value: idx}
			e.g. {'Car': 0, 'Mobile phone': 1, 'Person': 2}
	"""
	found_bg = False
	all_imgs = {}

	classes_count = {}

	class_mapping = {}

	visualise = True

	i = 1
	
	with open(input_path,'r') as f:

		print('Parsing annotation files')

		for line in f:

			# Print process
			sys.stdout.write('\r'+'idx=' + str(i))
			i += 1

			line_split = line.strip().split(',')

			# Make sure the info saved in annotation file matching the format (path_filename, x1, y1, x2, y2, class_name)
			# Note:
			#	One path_filename might has several classes (class_name)
			#	x1, y1, x2, y2 are the pixel value of the origial image, not the ratio value
			#	(x1, y1) top left coordinates; (x2, y2) bottom right coordinates
			#   x1,y1-------------------
			#	|						|
			#	|						|
			#	|						|
			#	|						|
			#	---------------------x2,y2

			(filename,x1,y1,x2,y2,class_name) = line_split

			if class_name not in classes_count:
				classes_count[class_name] = 1
			else:
				classes_count[class_name] += 1

			if class_name not in class_mapping:
				if class_name == 'bg' and found_bg == False:
					print('Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).')
					found_bg = True
				class_mapping[class_name] = len(class_mapping)

			if filename not in all_imgs:
				all_imgs[filename] = {}
				# %cd /content/drive/MyDrive/GraduationProject/test/
				img = cv2.imread(filename)
				if hasattr(img, 'shape'):
					(rows,cols,_) = img.shape
					all_imgs[filename]['filepath'] = filename
					all_imgs[filename]['width'] = cols
					all_imgs[filename]['height'] = rows
					all_imgs[filename]['bboxes'] = []
				# if np.random.randint(0,6) > 0:
				# 	all_imgs[filename]['imageset'] = 'trainval'
				# else:
				# 	all_imgs[filename]['imageset'] = 'test'

			all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})


		all_data = []
		for key in all_imgs:
			all_data.append(all_imgs[key])
		
		# make sure the bg class is last in the list
		# if found_bg:
		# 	if class_mapping['bg'] != len(class_mapping) - 1:
		# 		key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
		# 		val_to_switch = class_mapping['bg']
		# 		class_mapping['bg'] = len(class_mapping) - 1
		# 		class_mapping[key_to_switch] = val_to_switch
		
		return all_data, classes_count, class_mapping

# %%
class RoiPoolingConv(Layer):
    '''ROI pooling layer for 2D inputs.
    See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
    K. He, X. Zhang, S. Ren, J. Sun
    # Arguments
        pool_size: int
            Size of pooling region to use. pool_size = 7 will result in a 7x7 region.
        num_rois: number of regions of interest to be used
    # Input shape
        list of two 4D tensors [X_img,X_roi] with shape:
        X_img:
        `(1, rows, cols, channels)`
        X_roi:
        `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
    # Output shape
        3D tensor with shape:
        `(1, num_rois, channels, pool_size, pool_size)`
    '''
    def __init__(self, pool_size, num_rois, **kwargs):

        self.dim_ordering = K.image_data_format()
        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        self.nb_channels = input_shape[0][3]   

    def compute_output_shape(self, input_shape):
        return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        # x[0] is image with shape (rows, cols, channels)
        img = x[0]

        # x[1] is roi with shape (num_rois,4) with ordering (x,y,w,h)
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]

            x = K.cast(x, 'int32')
            y = K.cast(y, 'int32')
            w = K.cast(w, 'int32')
            h = K.cast(h, 'int32')

            # Resized roi of the image to pooling size (7x7)
            rs = tf.image.resize(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
            outputs.append(rs)
                

        final_output = K.concatenate(outputs, axis=0)

        # Reshape to (1, num_rois, pool_size, pool_size, nb_channels)
        # Might be (1, 4, 7, 7, 3)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        # permute_dimensions is similar to transpose
        final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output
    
    
    def get_config(self):
        config = {'pool_size': self.pool_size,
                  'num_rois': self.num_rois}
        base_config = super(RoiPoolingConv, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def get_img_output_length(width, height):
    def get_output_length(input_length):
        return input_length//16

    return get_output_length(width), get_output_length(height)    

def nn_base(input_tensor=None, trainable=False):


    input_shape = (None, None, 3)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    bn_axis = 3

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    # x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    return x

# %%
def rpn_layer(base_layers, num_anchors):
    """Create a rpn layer
        Step1: Pass through the feature map from base layer to a 3x3 512 channels convolutional layer
                Keep the padding 'same' to preserve the feature map's size
        Step2: Pass the step1 to two (1,1) convolutional layer to replace the fully connected layer
                classification layer: num_anchors (9 in here) channels for 0, 1 sigmoid activation output
                regression layer: num_anchors*4 (36 in here) channels for computing the regression of bboxes with linear activation
    Args:
        base_layers: vgg in here
        num_anchors: 9 in here

    Returns:
        [x_class, x_regr, base_layers]
        x_class: classification for whether it's an object
        x_regr: bboxes regression
        base_layers: vgg in here
    """
    x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)

    x_class = Conv2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
    x_regr = Conv2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

    return [x_class, x_regr, base_layers]

# %%
def classifier_layer(base_layers, input_rois, num_rois, nb_classes = 4):
    """Create a classifier layer
    
    Args:
        base_layers: vgg
        input_rois: `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
        num_rois: number of rois to be processed in one time (4 in here)

    Returns:
        list(out_class, out_regr)
        out_class: classifier layer output
        out_regr: regression layer output
    """

    input_shape = (num_rois,7,7,512)

    pooling_regions = 7

    # out_roi_pool.shape = (1, num_rois, channels, pool_size, pool_size)
    # num_rois (4) 7x7 roi pooling
    out_roi_pool = RoiPoolingConv(pooling_regions, num_rois)([base_layers, input_rois])

    # Flatten the convlutional layer and connected to 2 FC and 2 dropout
    out = TimeDistributed(Flatten(name='flatten'))(out_roi_pool)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc1'))(out)
    out = TimeDistributed(Dropout(0.5))(out)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc2'))(out)
    out = TimeDistributed(Dropout(0.5))(out)

    # There are two output layer
    # out_class: softmax acivation function for classify the class name of the object
    # out_regr: linear activation function for bboxes coordinates regression
    out_class = TimeDistributed(Dense(nb_classes, activation='softmax', kernel_initializer='zero'), name='dense_class_{}'.format(nb_classes))(out)
    # note: no regression target for bg class
    out_regr = TimeDistributed(Dense(4 * (nb_classes-1), activation='linear', kernel_initializer='zero'), name='dense_regress_{}'.format(nb_classes))(out)

    return [out_class, out_regr]

# %%
def union(au, bu, area_intersection):
	area_a = (au[2] - au[0]) * (au[3] - au[1])
	area_b = (bu[2] - bu[0]) * (bu[3] - bu[1])
	area_union = area_a + area_b - area_intersection
	return area_union


def intersection(ai, bi):
	x = max(ai[0], bi[0])
	y = max(ai[1], bi[1])
	w = min(ai[2], bi[2]) - x
	h = min(ai[3], bi[3]) - y
	if w < 0 or h < 0:
		return 0
	return w*h


def iou(a, b):
	# a and b should be (x1,y1,x2,y2)

	if a[0] >= a[2] or a[1] >= a[3] or b[0] >= b[2] or b[1] >= b[3]:
		return 0.0

	area_i = intersection(a, b)
	area_u = union(a, b, area_i)

	return float(area_i) / float(area_u + 1e-6)

# %%
def calc_rpn(C, img_data, width, height, resized_width, resized_height, img_length_calc_function):
	"""(Important part!) Calculate the rpn for all anchors 
		If feature map has shape 38x50=1900, there are 1900x9=17100 potential anchors
	
	Args:
		C: config
		img_data: augmented image data
		width: original image width (e.g. 600)
		height: original image height (e.g. 800)
		resized_width: resized image width according to C.im_size (e.g. 300)
		resized_height: resized image height according to C.im_size (e.g. 400)
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size

	Returns:
		y_rpn_cls: list(num_bboxes, y_is_box_valid + y_rpn_overlap)
			y_is_box_valid: 0 or 1 (0 means the box is invalid, 1 means the box is valid)
			y_rpn_overlap: 0 or 1 (0 means the box is not an object, 1 means the box is an object)
		y_rpn_regr: list(num_bboxes, 4*y_rpn_overlap + y_rpn_regr)
			y_rpn_regr: x1,y1,x2,y2 bunding boxes coordinates
	"""
	downscale = float(C.rpn_stride) 
	anchor_sizes = C.anchor_box_scales   # 128, 256, 512
	anchor_ratios = C.anchor_box_ratios  # 1:1, 1:2*sqrt(2), 2*sqrt(2):1
	num_anchors = len(anchor_sizes) * len(anchor_ratios) # 3x3=9

	# calculate the output map size based on the network architecture
	(output_width, output_height) = img_length_calc_function(resized_width, resized_height)

	n_anchratios = len(anchor_ratios)    # 3
	
	# initialise empty output objectives
	y_rpn_overlap = np.zeros((output_height, output_width, num_anchors))
	y_is_box_valid = np.zeros((output_height, output_width, num_anchors))
	y_rpn_regr = np.zeros((output_height, output_width, num_anchors * 4))

	num_bboxes = len(img_data['bboxes'])

	num_anchors_for_bbox = np.zeros(num_bboxes).astype(int)
	best_anchor_for_bbox = -1*np.ones((num_bboxes, 4)).astype(int)
	best_iou_for_bbox = np.zeros(num_bboxes).astype(np.float32)
	best_x_for_bbox = np.zeros((num_bboxes, 4)).astype(int)
	best_dx_for_bbox = np.zeros((num_bboxes, 4)).astype(np.float32)

	# get the GT box coordinates, and resize to account for image resizing
	gta = np.zeros((num_bboxes, 4))
	for bbox_num, bbox in enumerate(img_data['bboxes']):
		# get the GT box coordinates, and resize to account for image resizing
		gta[bbox_num, 0] = bbox['x1'] * (resized_width / float(width))
		gta[bbox_num, 1] = bbox['x2'] * (resized_width / float(width))
		gta[bbox_num, 2] = bbox['y1'] * (resized_height / float(height))
		gta[bbox_num, 3] = bbox['y2'] * (resized_height / float(height))
	
	# rpn ground truth

	for anchor_size_idx in range(len(anchor_sizes)):
		for anchor_ratio_idx in range(n_anchratios):
			anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
			anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]	
			
			for ix in range(output_width):					
				# x-coordinates of the current anchor box	
				x1_anc = downscale * (ix + 0.5) - anchor_x / 2
				x2_anc = downscale * (ix + 0.5) + anchor_x / 2	
				
				# ignore boxes that go across image boundaries					
				if x1_anc < 0 or x2_anc > resized_width:
					continue
					
				for jy in range(output_height):

					# y-coordinates of the current anchor box
					y1_anc = downscale * (jy + 0.5) - anchor_y / 2
					y2_anc = downscale * (jy + 0.5) + anchor_y / 2

					# ignore boxes that go across image boundaries
					if y1_anc < 0 or y2_anc > resized_height:
						continue

					# bbox_type indicates whether an anchor should be a target
					# Initialize with 'negative'
					bbox_type = 'neg'

					# this is the best IOU for the (x,y) coord and the current anchor
					# note that this is different from the best IOU for a GT bbox
					best_iou_for_loc = 0.0

					for bbox_num in range(num_bboxes):
						
						# get IOU of the current GT box and the current anchor box
						curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1_anc, y1_anc, x2_anc, y2_anc])
						# calculate the regression targets if they will be needed
						if curr_iou > best_iou_for_bbox[bbox_num] or curr_iou > C.rpn_max_overlap:
							cx = (gta[bbox_num, 0] + gta[bbox_num, 1]) / 2.0
							cy = (gta[bbox_num, 2] + gta[bbox_num, 3]) / 2.0
							cxa = (x1_anc + x2_anc)/2.0
							cya = (y1_anc + y2_anc)/2.0

							# x,y are the center point of ground-truth bbox
							# xa,ya are the center point of anchor bbox (xa=downscale * (ix + 0.5); ya=downscale * (iy+0.5))
							# w,h are the width and height of ground-truth bbox
							# wa,ha are the width and height of anchor bboxe
							# tx = (x - xa) / wa
							# ty = (y - ya) / ha
							# tw = log(w / wa)
							# th = log(h / ha)
							tx = (cx - cxa) / (x2_anc - x1_anc)
							ty = (cy - cya) / (y2_anc - y1_anc)
							tw = np.log((gta[bbox_num, 1] - gta[bbox_num, 0]) / (x2_anc - x1_anc))
							th = np.log((gta[bbox_num, 3] - gta[bbox_num, 2]) / (y2_anc - y1_anc))
						
						if img_data['bboxes'][bbox_num]['class'] != 'bg':

							# all GT boxes should be mapped to an anchor box, so we keep track of which anchor box was best
							if curr_iou > best_iou_for_bbox[bbox_num]:
								best_anchor_for_bbox[bbox_num] = [jy, ix, anchor_ratio_idx, anchor_size_idx]
								best_iou_for_bbox[bbox_num] = curr_iou
								best_x_for_bbox[bbox_num,:] = [x1_anc, x2_anc, y1_anc, y2_anc]
								best_dx_for_bbox[bbox_num,:] = [tx, ty, tw, th]

							# we set the anchor to positive if the IOU is >0.7 (it does not matter if there was another better box, it just indicates overlap)
							if curr_iou > C.rpn_max_overlap:
								bbox_type = 'pos'
								num_anchors_for_bbox[bbox_num] += 1
								# we update the regression layer target if this IOU is the best for the current (x,y) and anchor position
								if curr_iou > best_iou_for_loc:
									best_iou_for_loc = curr_iou
									best_regr = (tx, ty, tw, th)

							# if the IOU is >0.3 and <0.7, it is ambiguous and no included in the objective
							if C.rpn_min_overlap < curr_iou < C.rpn_max_overlap:
								# gray zone between neg and pos
								if bbox_type != 'pos':
									bbox_type = 'neutral'

					# turn on or off outputs depending on IOUs
					if bbox_type == 'neg':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'neutral':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'pos':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						start = 4 * (anchor_ratio_idx + n_anchratios * anchor_size_idx)
						y_rpn_regr[jy, ix, start:start+4] = best_regr

	# we ensure that every bbox has at least one positive RPN region

	for idx in range(num_anchors_for_bbox.shape[0]):
		if num_anchors_for_bbox[idx] == 0:
			# no box with an IOU greater than zero ...
			if best_anchor_for_bbox[idx, 0] == -1:
				continue
			y_is_box_valid[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			y_rpn_overlap[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			start = 4 * (best_anchor_for_bbox[idx,2] + n_anchratios * best_anchor_for_bbox[idx,3])
			y_rpn_regr[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], start:start+4] = best_dx_for_bbox[idx, :]

	y_rpn_overlap = np.transpose(y_rpn_overlap, (2, 0, 1))
	y_rpn_overlap = np.expand_dims(y_rpn_overlap, axis=0)

	y_is_box_valid = np.transpose(y_is_box_valid, (2, 0, 1))
	y_is_box_valid = np.expand_dims(y_is_box_valid, axis=0)

	y_rpn_regr = np.transpose(y_rpn_regr, (2, 0, 1))
	y_rpn_regr = np.expand_dims(y_rpn_regr, axis=0)

	pos_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 1, y_is_box_valid[0, :, :, :] == 1))
	neg_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 0, y_is_box_valid[0, :, :, :] == 1))

	num_pos = len(pos_locs[0])

	# one issue is that the RPN has many more negative than positive regions, so we turn off some of the negative
	# regions. We also limit it to 256 regions.
	num_regions = 256

	if len(pos_locs[0]) > num_regions/2:
		val_locs = random.sample(range(len(pos_locs[0])), len(pos_locs[0]) - num_regions/2)
		y_is_box_valid[0, pos_locs[0][val_locs], pos_locs[1][val_locs], pos_locs[2][val_locs]] = 0
		num_pos = num_regions/2

	if len(neg_locs[0]) + num_pos > num_regions:
		val_locs = random.sample(range(len(neg_locs[0])), len(neg_locs[0]) - num_pos)
		y_is_box_valid[0, neg_locs[0][val_locs], neg_locs[1][val_locs], neg_locs[2][val_locs]] = 0

	y_rpn_cls = np.concatenate([y_is_box_valid, y_rpn_overlap], axis=1)
	y_rpn_regr = np.concatenate([np.repeat(y_rpn_overlap, 4, axis=1), y_rpn_regr], axis=1)

	return np.copy(y_rpn_cls), np.copy(y_rpn_regr), num_pos

# %%
def get_new_img_size(width, height, img_min_side=300):
	if width <= height:
		f = float(img_min_side) / width
		resized_height = int(f * height)
		resized_width = img_min_side
	else:
		f = float(img_min_side) / height
		resized_width = int(f * width)
		resized_height = img_min_side

	return resized_width, resized_height

def augment(img_data, config, augment=True):
	assert 'filepath' in img_data
	assert 'bboxes' in img_data
	assert 'width' in img_data
	assert 'height' in img_data

	# %cd /content/drive/MyDrive/GraduationProject/test/
	img_data_aug = copy.deepcopy(img_data)
	img = cv2.imread(img_data_aug['filepath'])

	if augment:
		rows, cols = img.shape[:2]

		if config.use_horizontal_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 1)
			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				bbox['x2'] = cols - x1
				bbox['x1'] = cols - x2

		if config.use_vertical_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 0)
			for bbox in img_data_aug['bboxes']:
				y1 = bbox['y1']
				y2 = bbox['y2']
				bbox['y2'] = rows - y1
				bbox['y1'] = rows - y2

		if config.rot_90:
			angle = np.random.choice([0,90,180,270],1)[0]
			if angle == 270:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 0)
			elif angle == 180:
				img = cv2.flip(img, -1)
			elif angle == 90:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 1)
			elif angle == 0:
				pass

			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				y1 = bbox['y1']
				y2 = bbox['y2']
				if angle == 270:
					bbox['x1'] = y1
					bbox['x2'] = y2
					bbox['y1'] = cols - x2
					bbox['y2'] = cols - x1
				elif angle == 180:
					bbox['x2'] = cols - x1
					bbox['x1'] = cols - x2
					bbox['y2'] = rows - y1
					bbox['y1'] = rows - y2
				elif angle == 90:
					bbox['x1'] = rows - y2
					bbox['x2'] = rows - y1
					bbox['y1'] = x1
					bbox['y2'] = x2        
				elif angle == 0:
					pass

	img_data_aug['width'] = img.shape[1]
	img_data_aug['height'] = img.shape[0]
	return img_data_aug, img

# %%
def get_anchor_gt(all_img_data, C, img_length_calc_function, mode='train'):
	""" Yield the ground-truth anchors as Y (labels)
		
	Args:
		all_img_data: list(filepath, width, height, list(bboxes))
		C: config
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size
		mode: 'train' or 'test'; 'train' mode need augmentation

	Returns:
		x_img: image data after resized and scaling (smallest size = 300px)
		Y: [y_rpn_cls, y_rpn_regr]
		img_data_aug: augmented image data (original image with augmentation)
		debug_img: show image for debug
		num_pos: show number of positive anchors for debug
	"""
	while True:

		for img_data in all_img_data:
			try:

				# read in image, and optionally add augmentation

				if mode == 'train':
					img_data_aug, x_img = augment(img_data, C, augment=True)
				else:
					img_data_aug, x_img = augment(img_data, C, augment=False)

				(width, height) = (img_data_aug['width'], img_data_aug['height'])
				(rows, cols, _) = x_img.shape

				assert cols == width
				assert rows == height

				# get image dimensions for resizing
				(resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

				# resize the image so that smalles side is length = 300px
				x_img = cv2.resize(x_img, (resized_width, resized_height), interpolation=cv2.INTER_CUBIC)
				debug_img = x_img.copy()

				try:
					y_rpn_cls, y_rpn_regr, num_pos = calc_rpn(C, img_data_aug, width, height, resized_width, resized_height, img_length_calc_function)
				except:
					continue

				# Zero-center by mean pixel, and preprocess image

				x_img = x_img[:,:, (2, 1, 0)]  # BGR -> RGB
				x_img = x_img.astype(np.float32)
				x_img[:, :, 0] -= C.img_channel_mean[0]
				x_img[:, :, 1] -= C.img_channel_mean[1]
				x_img[:, :, 2] -= C.img_channel_mean[2]
				x_img /= C.img_scaling_factor

				x_img = np.transpose(x_img, (2, 0, 1))
				x_img = np.expand_dims(x_img, axis=0)

				y_rpn_regr[:, y_rpn_regr.shape[1]//2:, :, :] *= C.std_scaling

				x_img = np.transpose(x_img, (0, 2, 3, 1))
				y_rpn_cls = np.transpose(y_rpn_cls, (0, 2, 3, 1))
				y_rpn_regr = np.transpose(y_rpn_regr, (0, 2, 3, 1))

				yield np.copy(x_img), [np.copy(y_rpn_cls), np.copy(y_rpn_regr)], img_data_aug, debug_img, num_pos

			except Exception as e:
				print(e)
				continue

# %%
def non_max_suppression_fast(boxes, probs, overlap_thresh=0.9, max_boxes=300):
	# code used from here: http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
	# if there are no boxes, return an empty list
  
    # Process explanation:
    #   Step 1: Sort the probs list
    #   Step 2: Find the larget prob 'Last' in the list and save it to the pick list
    #   Step 3: Calculate the IoU with 'Last' box and other boxes in the list. If the IoU is larger than overlap_threshold, delete the box from list
    #   Step 4: Repeat step 2 and step 3 until there is no item in the probs list 
	if len(boxes) == 0:
		return []

	# grab the coordinates of the bounding boxes
	x1 = boxes[:, 0]
	y1 = boxes[:, 1]
	x2 = boxes[:, 2]
	y2 = boxes[:, 3]

	np.testing.assert_array_less(x1, x2)
	np.testing.assert_array_less(y1, y2)

	# if the bounding boxes integers, convert them to floats --
	# this is important since we'll be doing a bunch of divisions
	if boxes.dtype.kind == "i":
		boxes = boxes.astype("float")

	# initialize the list of picked indexes	
	pick = []

	# calculate the areas
	area = (x2 - x1) * (y2 - y1)

	# sort the bounding boxes 
	idxs = np.argsort(probs)

	# keep looping while some indexes still remain in the indexes
	# list
	while len(idxs) > 0:
		# grab the last index in the indexes list and add the
		# index value to the list of picked indexes
		last = len(idxs) - 1
		i = idxs[last]
		pick.append(i)

		# find the intersection

		xx1_int = np.maximum(x1[i], x1[idxs[:last]])
		yy1_int = np.maximum(y1[i], y1[idxs[:last]])
		xx2_int = np.minimum(x2[i], x2[idxs[:last]])
		yy2_int = np.minimum(y2[i], y2[idxs[:last]])

		ww_int = np.maximum(0, xx2_int - xx1_int)
		hh_int = np.maximum(0, yy2_int - yy1_int)

		area_int = ww_int * hh_int

		# find the union
		area_union = area[i] + area[idxs[:last]] - area_int

		# compute the ratio of overlap
		overlap = area_int/(area_union + 1e-6)

		# delete all indexes from the index list that have
		idxs = np.delete(idxs, np.concatenate(([last],
			np.where(overlap > overlap_thresh)[0])))

		if len(pick) >= max_boxes:
			break

	# return only the bounding boxes that were picked using the integer data type
	boxes = boxes[pick].astype("int")
	probs = probs[pick]
	return boxes, probs

def apply_regr_np(X, T):
	"""Apply regression layer to all anchors in one feature map

	Args:
		X: shape=(4, 18, 25) the current anchor type for all points in the feature map
		T: regression layer shape=(4, 18, 25)

	Returns:
		X: regressed position and size for current anchor
	"""
	try:
		x = X[0, :, :]
		y = X[1, :, :]
		w = X[2, :, :]
		h = X[3, :, :]

		tx = T[0, :, :]
		ty = T[1, :, :]
		tw = T[2, :, :]
		th = T[3, :, :]

		cx = x + w/2.
		cy = y + h/2.
		cx1 = tx * w + cx
		cy1 = ty * h + cy

		w1 = np.exp(tw.astype(np.float64)) * w
		h1 = np.exp(th.astype(np.float64)) * h
		x1 = cx1 - w1/2.
		y1 = cy1 - h1/2.

		x1 = np.round(x1)
		y1 = np.round(y1)
		w1 = np.round(w1)
		h1 = np.round(h1)
		return np.stack([x1, y1, w1, h1])
	except Exception as e:
		print(e)
		return X
    
def apply_regr(x, y, w, h, tx, ty, tw, th):
    # Apply regression to x, y, w and h
	try:
		cx = x + w/2.
		cy = y + h/2.
		cx1 = tx * w + cx
		cy1 = ty * h + cy
		w1 = math.exp(tw) * w
		h1 = math.exp(th) * h
		x1 = cx1 - w1/2.
		y1 = cy1 - h1/2.
		x1 = int(round(x1))
		y1 = int(round(y1))
		w1 = int(round(w1))
		h1 = int(round(h1))

		return x1, y1, w1, h1

	except ValueError:
		return x, y, w, h
	except OverflowError:
		return x, y, w, h
	except Exception as e:
		print(e)
		return x, y, w, h

# %%
def rpn_to_roi(rpn_layer, regr_layer, C, dim_ordering, use_regr=True, max_boxes=300,overlap_thresh=0.9):
	"""Convert rpn layer to roi bboxes

	Args: (num_anchors = 9)
		rpn_layer: output layer for rpn classification 
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 9) if resized image is 400 width and 300
		regr_layer: output layer for rpn regression
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 36) if resized image is 400 width and 300
		C: config
		use_regr: Wether to use bboxes regression in rpn
		max_boxes: max bboxes number for non-max-suppression (NMS)
		overlap_thresh: If iou in NMS is larger than this threshold, drop the box

	Returns:
		result: boxes from non-max-suppression (shape=(300, 4))
			boxes: coordinates for bboxes (on the feature map)
	"""
	regr_layer = regr_layer / C.std_scaling

	anchor_sizes = C.anchor_box_scales   # (3 in here)
	anchor_ratios = C.anchor_box_ratios  # (3 in here)

	assert rpn_layer.shape[0] == 1

	(rows, cols) = rpn_layer.shape[1:3]

	curr_layer = 0

	# A.shape = (4, feature_map.height, feature_map.width, num_anchors) 
	# Might be (4, 18, 25, 9) if resized image is 400 width and 300
	# A is the coordinates for 9 anchors for every point in the feature map 
	# => all 18x25x9=4050 anchors cooridnates
	A = np.zeros((4, rpn_layer.shape[1], rpn_layer.shape[2], rpn_layer.shape[3]))

	for anchor_size in anchor_sizes:
		for anchor_ratio in anchor_ratios:
			# anchor_x = (128 * 1) / 16 = 8  => width of current anchor
			# anchor_y = (128 * 2) / 16 = 16 => height of current anchor
			anchor_x = (anchor_size * anchor_ratio[0])/C.rpn_stride
			anchor_y = (anchor_size * anchor_ratio[1])/C.rpn_stride
			
			# curr_layer: 0~8 (9 anchors)
			# the Kth anchor of all position in the feature map (9th in total)
			regr = regr_layer[0, :, :, 4 * curr_layer:4 * curr_layer + 4] # shape => (18, 25, 4)
			regr = np.transpose(regr, (2, 0, 1)) # shape => (4, 18, 25)

			# Create 18x25 mesh grid
			# For every point in x, there are all the y points and vice versa
			# X.shape = (18, 25)
			# Y.shape = (18, 25)
			X, Y = np.meshgrid(np.arange(cols),np. arange(rows))

			# Calculate anchor position and size for each feature map point
			A[0, :, :, curr_layer] = X - anchor_x/2 # Top left x coordinate
			A[1, :, :, curr_layer] = Y - anchor_y/2 # Top left y coordinate
			A[2, :, :, curr_layer] = anchor_x       # width of current anchor
			A[3, :, :, curr_layer] = anchor_y       # height of current anchor

			# Apply regression to x, y, w and h if there is rpn regression layer
			if use_regr:
				A[:, :, :, curr_layer] = apply_regr_np(A[:, :, :, curr_layer], regr)

			# Avoid width and height exceeding 1
			A[2, :, :, curr_layer] = np.maximum(1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.maximum(1, A[3, :, :, curr_layer])

			# Convert (x, y , w, h) to (x1, y1, x2, y2)
			# x1, y1 is top left coordinate
			# x2, y2 is bottom right coordinate
			A[2, :, :, curr_layer] += A[0, :, :, curr_layer]
			A[3, :, :, curr_layer] += A[1, :, :, curr_layer]

			# Avoid bboxes drawn outside the feature map
			A[0, :, :, curr_layer] = np.maximum(0, A[0, :, :, curr_layer])
			A[1, :, :, curr_layer] = np.maximum(0, A[1, :, :, curr_layer])
			A[2, :, :, curr_layer] = np.minimum(cols-1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.minimum(rows-1, A[3, :, :, curr_layer])

			curr_layer += 1

	all_boxes = np.reshape(A.transpose((0, 3, 1, 2)), (4, -1)).transpose((1, 0))  # shape=(4050, 4)
	all_probs = rpn_layer.transpose((0, 3, 1, 2)).reshape((-1))                   # shape=(4050,)

	x1 = all_boxes[:, 0]
	y1 = all_boxes[:, 1]
	x2 = all_boxes[:, 2]
	y2 = all_boxes[:, 3]

	# Find out the bboxes which is illegal and delete them from bboxes list
	idxs = np.where((x1 - x2 >= 0) | (y1 - y2 >= 0))

	all_boxes = np.delete(all_boxes, idxs, 0)
	all_probs = np.delete(all_probs, idxs, 0)

	# Apply non_max_suppression
	# Only extract the bboxes. Don't need rpn probs in the later process
	result = non_max_suppression_fast(all_boxes, all_probs, overlap_thresh=overlap_thresh, max_boxes=max_boxes)[0]

	return result

# %%
base_path = '/content/drive/MyDrive/AI/Faster_RCNN/'

test_path = '/content/drive/MyDrive/GraduationProject/test/Testannotations.txt' # Test data (annotation file)

test_base_path = '/content/drive/MyDrive/GraduationProject/test/' # Directory to save the test images

config_output_filename = os.path.join(base_path, 'model_vgg_config.pickle')

# %%
with open(config_output_filename, 'rb') as f_in:
	C = pickle.load(f_in)

# turn off any data augmentation at test time
C.use_horizontal_flips = False
C.use_vertical_flips = False
C.rot_90 = False
print(C.record_path)
print(C.model_path)
# Out:
# /content/drive/MyDrive/AI/Faster_RCNN/record.csv
# /content/drive/MyDrive/AI/Faster_RCNN/model_frcnn_vgg.hdf5

# %%
# Load the records
record_df = pd.read_csv(C.record_path)

r_epochs = len(record_df)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['mean_overlapping_bboxes'], 'r')
plt.title('mean_overlapping_bboxes')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['class_acc'], 'r')
plt.title('class_acc')

plt.show()

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_cls'], 'r')
plt.title('loss_rpn_cls')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_regr'], 'r')
plt.title('loss_rpn_regr')
plt.show()
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_cls'], 'r')
plt.title('loss_class_cls')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_regr'], 'r')
plt.title('loss_class_regr')
plt.show()
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['curr_loss'], 'r')
plt.title('total_loss')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['elapsed_time'], 'r')
plt.title('elapsed_time')

plt.show()

# %%
def format_img_size(img, C):
	""" formats the image size based on config """
	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
		
	if width <= height:
		ratio = img_min_side/width
		new_height = int(ratio * height)
		new_width = int(img_min_side)
	else:
		ratio = img_min_side/height
		new_width = int(ratio * width)
		new_height = int(img_min_side)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	return img, ratio	

def format_img_channels(img, C):
	""" formats the image channels based on config """
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	img = np.transpose(img, (2, 0, 1))
	img = np.expand_dims(img, axis=0)
	return img

def format_img(img, C):
	""" formats an image for model prediction based on config """
	img, ratio = format_img_size(img, C)
	img = format_img_channels(img, C)
	return img, ratio

# Method to transform the coordinates of the bounding box to its original size
def get_real_coordinates(ratio, x1, y1, x2, y2):

	real_x1 = int(round(x1 // ratio))
	real_y1 = int(round(y1 // ratio))
	real_x2 = int(round(x2 // ratio))
	real_y2 = int(round(y2 // ratio))

	return (real_x1, real_y1, real_x2 ,real_y2)

# %%
num_features = 512

input_shape_img = (None, None, 3)
input_shape_features = (None, None, num_features)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(C.num_rois, 4))
feature_map_input = Input(shape=input_shape_features)

# define the base network (VGG here, can be Resnet50, Inception, etc)
shared_layers = nn_base(img_input, trainable=True)

# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn_layers = rpn_layer(shared_layers, num_anchors)

classifier = classifier_layer(feature_map_input, roi_input, C.num_rois, nb_classes=len(C.class_mapping))

model_rpn = Model(img_input, rpn_layers)
model_classifier_only = Model([feature_map_input, roi_input], classifier)

model_classifier = Model([feature_map_input, roi_input], classifier)

print('Loading weights from {}'.format(C.model_path))
model_rpn.load_weights(C.model_path, by_name=True)
print(model_rpn.weights)
print("-------------------------------------------------------------------------------------------------------")
model_classifier.load_weights(C.model_path, by_name=True)
print(model_classifier.weights)
print("-------------------------------------------------------------------------------------------------------")
model_rpn.compile(optimizer='sgd', loss='mse')
model_classifier.compile(optimizer='sgd', loss='mse')
# Out:
# Loading weights from /content/drive/MyDrive/AI/Faster_RCNN/model_frcnn_vgg.hdf5
# [<tf.Variable 'block1_conv1/kernel:0' shape=(3, 3, 3, 64) dtype=float32, numpy=
# array([[[[ 4.29657698e-01,  1.17206156e-01,  3.08251418e-02, ...,
#           -1.27915397e-01, -5.24103977e-02,  5.77623630e-03],
#          [ 5.50644696e-01,  1.97738335e-02,  9.56681669e-02, ...,
#           -8.07713792e-02, -5.00529520e-02,  3.57621908e-02],
#          [ 4.80320543e-01, -1.74371943e-01,  3.44043970e-02, ...,
#           -1.23164304e-01, -4.91241515e-02,  3.32080983e-02]],
#
#         [[ 3.73719573e-01,  1.61937937e-01, -1.37205981e-03, ...,
#           -1.43987730e-01, -2.34340712e-01, -6.48170114e-02],
#          [ 4.40397769e-01,  4.62923087e-02,  4.83208038e-02, ...,
#           -9.48956534e-02, -2.95104533e-01, -7.21709058e-02],
#          [ 4.08915192e-01, -1.71953321e-01, -8.01077578e-03, ...,
#           -1.18476987e-01, -2.75275707e-01, -4.07865345e-02]],
#
#         [[-6.10569045e-02,  1.35565311e-01, -1.18689992e-01, ...,
#           -1.36059329e-01, -3.76621693e-01, -3.02203983e-01],
#          [-8.10070485e-02,  4.08097580e-02, -1.04730979e-01, ...,
#           -9.04521048e-02, -5.04482210e-01, -3.85335118e-01],
#          [-6.47189841e-02, -1.55920997e-01, -1.40988633e-01, ...,
#           -1.25604570e-01, -4.60979283e-01, -3.25594693e-01]]],
#
#
#        [[[ 2.75011092e-01,  1.48389757e-01,  1.58396438e-01, ...,
#           -1.10559486e-01,  3.66386145e-01,  3.38129312e-01],
#          [ 3.46050113e-01,  3.00637875e-02,  2.37616137e-01, ...,
#           -6.57302290e-02,  4.38168168e-01,  4.11434084e-01],
#          [ 3.10829550e-01, -1.89164355e-01,  1.63473159e-01, ...,
#           -9.52485651e-02,  4.05192345e-01,  3.90870154e-01]],
#
#         [[ 3.89673673e-02,  2.02324897e-01,  1.53331295e-01, ...,
#           -4.83386144e-02,  2.58047968e-01,  3.69877070e-01],
#          [ 4.09945026e-02,  6.48964569e-02,  2.17248857e-01, ...,
#           -2.37533197e-04,  2.70444572e-01,  4.07744348e-01],
#          [ 5.05958647e-02, -1.79018199e-01,  1.48140088e-01, ...,
#           -1.05277458e-02,  2.60415554e-01,  4.22032654e-01]],
#
#         [[-3.66887748e-01,  1.61713779e-01, -9.29625705e-02, ...,
#           -1.42343074e-01, -2.70863175e-01, -2.41457358e-01],
#          [-4.53086376e-01,  4.53453138e-02, -6.97424337e-02, ...,
#           -9.99991298e-02, -3.44692975e-01, -2.94170737e-01],
#          [-4.02933657e-01, -1.75840631e-01, -1.12829126e-01, ...,
#           -1.22194469e-01, -3.12847793e-01, -2.34491661e-01]]],
#
#
#        [[[-5.72054163e-02,  1.29302636e-01,  9.79746878e-03, ...,
#           -1.38097659e-01,  2.42043763e-01,  4.38759588e-02],
#          [-5.82898781e-02,  3.05730104e-02,  7.28763044e-02, ...,
#           -1.01711698e-01,  3.40652376e-01,  9.70197096e-02],
#          [-5.04907258e-02, -1.67695090e-01,  1.25537887e-02, ...,
#           -1.46422088e-01,  3.07995021e-01,  8.66920501e-02]],
#
#         [[-2.61938721e-01,  1.71524838e-01, -2.98465462e-03, ...,
#           -1.19420037e-01,  2.45621458e-01,  5.16016670e-02],
#          [-3.30277920e-01,  5.36953732e-02,  4.56547588e-02, ...,
#           -7.96395466e-02,  2.96540409e-01,  7.27952495e-02],
#          [-2.84798354e-01, -1.68240279e-01, -1.09814033e-02, ...,
#           -1.06480211e-01,  2.80355990e-01,  9.30244997e-02]],
#
#         [[-3.49724591e-01,  1.38632819e-01, -1.28327370e-01, ...,
#           -1.49827614e-01, -1.38942599e-01, -2.66708672e-01],
#          [-4.84564751e-01,  4.12843972e-02, -1.15044646e-01, ...,
#           -1.15044199e-01, -1.65946126e-01, -3.23830456e-01],
#          [-4.18016195e-01, -1.58619821e-01, -1.52089670e-01, ...,
#           -1.53555006e-01, -1.41679078e-01, -2.71257937e-01]]]],
#       dtype=float32)>, <tf.Variable 'block1_conv1/bias:0' shape=(64,) dtype=float32, numpy=
# array([ 0.7343018 ,  0.09727526,  0.06459558,  0.88535804,  0.2586957 ,
#         0.66883737, -0.01599269,  0.32438135,  0.6865577 ,  0.06188054,
#         0.5808601 ,  0.236182  ,  0.6939074 ,  0.19436958,  0.4849167 ,
#         0.44994697,  0.50985974,  0.20694815,  0.58143777,  0.32699078,
#         0.5000855 ,  0.71046585,  0.31027868,  0.70790553,  0.04507665,
#         0.7499037 ,  0.29624543,  0.48241693,  0.815712  ,  0.6260504 ,
#         0.37652892,  2.0688634 ,  0.7670574 ,  0.3436635 ,  0.61191654,
#         0.6543665 ,  0.38994747,  0.5072956 ,  0.26289377,  0.23487921,
#         0.08147585,  1.1183378 ,  0.26178616,  0.8687387 ,  0.21325895,
#         0.7804884 ,  0.36876634,  0.47994825,  0.42992285,  0.51005423,
#         0.23426953,  0.76448756,  0.35250276,  0.4558822 ,  0.46446225,
#         0.09880021,  0.38120788,  0.6668021 ,  0.401554  ,  0.8996063 ,
#         0.4315966 ,  1.298255  ,  0.5305861 ,  0.48781008], dtype=float32)>, <tf.Variable 'block1_conv2/kernel:0' shape=(3, 3, 64, 64) dtype=float32, numpy=
# array([[[[ 1.67491227e-01,  1.45094484e-01, -5.84416883e-03, ...,
#            6.66699037e-02, -1.77009404e-02, -3.11574787e-02],
#          [ 9.66484845e-03,  4.63536195e-03,  5.71568422e-02, ...,
#           -2.33892128e-02, -1.03782408e-03,  7.35025911e-04],
#          [ 6.42836317e-02,  2.23364737e-02, -1.28709394e-02, ...,
#            6.01203693e-03,  4.46434226e-03, -5.09271864e-03],
#          ...,
#          [ 3.22148437e-03,  8.13794658e-02, -4.06366438e-02, ...,
#           -1.28143374e-02, -1.12911109e-02,  8.04714020e-03],
#          [ 5.95678724e-02,  5.00111766e-02, -4.96304827e-03, ...,
#            1.36643331e-02,  2.90238298e-02, -4.21750546e-02],
#          [ 1.34107754e-01,  5.21701723e-02, -1.93494130e-02, ...,
#            2.42037065e-02,  2.91688610e-02, -2.16484312e-02]],
#
#         [[ 2.13355675e-01,  2.34270841e-02, -1.58125944e-02, ...,
#            2.68455986e-02,  1.15501648e-02, -3.21068317e-02],
#          [-3.00335628e-03,  7.98059534e-03,  7.34806806e-02, ...,
#           -2.60862485e-02, -8.29663884e-04, -2.16421834e-03],
#          [ 2.36738212e-02, -1.00557478e-02, -9.37358011e-03, ...,
#           -6.93821535e-03,  3.86878215e-02, -5.62788919e-03],
#          ...,
#          [-3.28485109e-03,  7.09741265e-02, -3.36695239e-02, ...,
#           -1.19724283e-02,  1.05803413e-02,  1.00066494e-02],
#          [-3.18316258e-02, -2.35793758e-02, -4.53084847e-03, ...,
#           -7.81794917e-03,  2.00828016e-01, -5.05974032e-02],
#          [ 1.74619015e-02, -2.12413967e-02, -1.39748547e-02, ...,
#           -8.00331216e-03,  1.27389461e-01, -2.58116294e-02]],
#
#         [[-4.71467618e-03, -2.09066141e-02,  3.36868921e-03, ...,
#            3.92979942e-03, -5.00934795e-02,  1.49319088e-03],
#          [-4.37863264e-03,  9.52628534e-03,  5.97499944e-02, ...,
#           -2.09966153e-02, -6.75484352e-03, -4.04768018e-03],
#          [-3.03981844e-02, -1.04992418e-02, -6.69871806e-05, ...,
#           -7.75223039e-03, -1.74087659e-02,  5.05458796e-03],
#          ...,
#          [ 5.10642258e-03,  2.66516376e-02, -3.62342373e-02, ...,
#           -1.08420663e-02,  2.26474297e-03,  1.62233529e-03],
#          [-7.79322162e-02, -1.96977835e-02,  2.13271715e-02, ...,
#            5.70348231e-03,  5.25166653e-02, -2.29491014e-02],
#          [-7.78683946e-02, -2.38088705e-02,  1.34580480e-02, ...,
#           -7.70845823e-03, -2.74815988e-02,  5.23503125e-03]]],
#
#
#        [[[ 2.00457990e-01,  5.30182980e-02, -2.06282567e-02, ...,
#            2.07510311e-02, -1.24443732e-02,  9.03619104e-04],
#          [-1.35141425e-03,  5.16426982e-03,  7.26978555e-02, ...,
#           -2.56691463e-02, -2.66821054e-03, -7.09640747e-03],
#          [ 2.21534166e-02,  2.66523706e-03, -1.41387805e-02, ...,
#           -1.00808928e-03, -3.43767777e-02, -4.80853999e-03],
#          ...,
#          [-1.50568262e-02,  7.46184960e-02, -2.66479608e-02, ...,
#           -9.19632148e-03, -1.52209820e-02, -2.50327663e-04],
#          [-1.45084327e-02,  1.61666702e-02, -1.53432125e-02, ...,
#            1.45162363e-02, -8.30257758e-02, -4.47355956e-02],
#          [ 2.56827828e-02,  8.50195251e-03, -3.03333085e-02, ...,
#            1.55021595e-02, -7.29388669e-02, -2.05379538e-02]],
#
#         [[-2.48724539e-02, -4.74010073e-02, -2.44496670e-02, ...,
#           -2.04438828e-02,  1.97955221e-02,  1.61543563e-02],
#          [-5.29811764e-03,  1.08693400e-02,  8.91389996e-02, ...,
#           -2.73654740e-02,  7.73510896e-04, -9.84396506e-03],
#          [-3.75522673e-02, -1.79818347e-02, -1.05865104e-02, ...,
#           -9.63234529e-03,  2.84686424e-02,  2.62894493e-04],
#          ...,
#          [-1.85749978e-02,  6.88346550e-02, -2.04768721e-02, ...,
#           -6.57930551e-03,  1.30125210e-02, -2.80992338e-03],
#          [-8.95482302e-02, -4.74199690e-02, -1.50868418e-02, ...,
#           -7.59665482e-03,  6.19824305e-02, -4.49731611e-02],
#          [-1.00134432e-01, -3.47032249e-02, -2.48659179e-02, ...,
#           -5.60390716e-03,  9.16980058e-02, -1.05659477e-02]],
#
#         [[-9.75806043e-02, -5.63406162e-02, -5.04512666e-03, ...,
#           -1.88180152e-02, -1.09784799e-02,  5.60279898e-02],
#          [ 4.15257411e-03,  1.22144977e-02,  7.45614618e-02, ...,
#           -2.16779914e-02, -5.44707151e-03, -1.10048195e-02],
#          [-2.30710320e-02, -7.47296587e-03, -6.14678208e-03, ...,
#           -8.11142009e-03,  3.97378355e-02,  9.10355896e-03],
#          ...,
#          [-6.91562658e-04,  1.35341734e-02, -2.60884780e-02, ...,
#           -8.34593363e-03,  6.12996751e-03, -1.24473507e-02],
#          [-4.80136788e-03, -3.99521403e-02, -1.21446606e-03, ...,
#            7.40963951e-05,  2.06769496e-01, -1.78191960e-02],
#          [-3.83212119e-02, -1.85648501e-02, -6.92992331e-03, ...,
#            3.70015565e-04,  1.40014559e-01,  1.21880919e-02]]],
#
#
#        [[[-1.01399850e-02, -2.11668969e-03, -8.97535495e-03, ...,
#            7.04345014e-03, -6.60137758e-02,  8.38322267e-02],
#          [-6.14383724e-03,  5.41868201e-03,  5.77355623e-02, ...,
#           -1.82189923e-02, -3.93681694e-03, -1.38479881e-02],
#          [-9.16905794e-03, -7.79511349e-04, -8.03083181e-03, ...,
#            9.21731524e-04, -4.22446318e-02,  7.12982286e-03],
#          ...,
#          [-1.70691125e-02,  4.89545427e-02, -2.64268983e-02, ...,
#           -2.76173837e-03,  9.44293628e-04, -3.97608951e-02],
#          [-1.32196750e-02,  5.73534425e-03, -1.13077322e-02, ...,
#            6.89651212e-03, -2.87250485e-02,  3.70210111e-02],
#          [-2.80580297e-02, -2.22996320e-03, -1.65126454e-02, ...,
#            1.49734775e-02, -7.48726130e-02,  1.64675023e-02]],
#
#         [[-1.01318806e-01, -5.11422902e-02, -1.13265067e-02, ...,
#           -1.07806781e-02, -5.00172749e-02,  1.23755559e-01],
#          [ 2.12738570e-03,  1.07958075e-02,  7.33574033e-02, ...,
#           -1.93918683e-02, -2.13724445e-03, -1.58889815e-02],
#          [-1.43724270e-02, -1.23896692e-02, -5.13147376e-03, ...,
#           -5.81527362e-03, -5.05571030e-02,  9.14584566e-03],
#          ...,
#          [-5.94386132e-03,  3.09267137e-02, -2.16152798e-02, ...,
#           -3.95536888e-03, -1.38507625e-02, -4.85826544e-02],
#          [-2.19327044e-02, -4.95191962e-02, -1.59861632e-02, ...,
#           -1.20792007e-02, -9.20212269e-02,  5.57667315e-02],
#          [-2.54564751e-02, -3.36203612e-02, -1.55185210e-02, ...,
#           -8.69717041e-04, -1.00205928e-01,  1.90710761e-02]],
#
#         [[ 2.79572681e-02, -3.45893502e-02, -1.79565308e-04, ...,
#            3.48272943e-03,  4.42100242e-02,  1.22335330e-01],
#          [ 8.93136766e-03,  1.15868943e-02,  5.93489856e-02, ...,
#           -1.36905769e-02, -3.97471478e-03, -1.60616376e-02],
#          [ 3.72828320e-02, -7.68346945e-03, -2.35367217e-03, ...,
#           -4.04611696e-03,  1.22410497e-02,  4.90295980e-03],
#          ...,
#          [-2.66833138e-02, -2.78385449e-02, -2.88611632e-02, ...,
#           -6.58733537e-03, -1.07354289e-02, -5.14224842e-02],
#          [ 2.67363936e-02, -4.82283533e-02, -4.33029374e-03, ...,
#           -4.40329686e-03,  4.22352031e-02,  7.06109628e-02],
#          [ 8.02538544e-02, -2.84175947e-02,  3.19344370e-04, ...,
#            2.75246566e-03,  4.27123755e-02,  1.65064167e-02]]]],
#       dtype=float32)>, <tf.Variable 'block1_conv2/bias:0' shape=(64,) dtype=float32, numpy=
# array([-0.30978692,  0.36393854,  0.1436287 ,  0.0778122 ,  0.90466815,
#         0.08962873,  0.10970413, -0.22496542, -0.6338092 ,  0.1807692 ,
#        -0.33422625,  0.19370326,  0.43728733,  0.19285274,  0.10505448,
#         0.10219211, -1.0303077 ,  0.05273329,  0.13367395,  0.22634828,
#        -0.71503466,  0.21574561, -0.70331144,  0.04326072,  0.13919048,
#         0.2848329 ,  0.35418138,  0.3947799 ,  0.43458596, -0.48401225,
#         0.02443913,  0.08689547,  0.05144973,  0.5504965 ,  0.3220425 ,
#         0.07216785, -0.17730379,  0.376114  ,  0.39153612,  0.17356305,
#        -0.15737806,  0.25850007,  0.08105867,  0.0871385 , -0.09193554,
#         0.22382827,  0.29817754,  0.13265756, -0.38824892,  0.10740134,
#        -0.5343173 ,  0.47108963, -0.07221874,  0.30019292,  0.1267926 ,
#         0.16363716,  0.2417778 ,  0.23046161, -0.19374771,  0.01451897,
#         0.27053386,  0.03802172,  0.05871974, -0.58597404], dtype=float32)>, <tf.Variable 'block2_conv1/kernel:0' shape=(3, 3, 64, 128) dtype=float32, numpy=
# array([[[[-1.01414220e-02,  3.69869433e-02,  1.57993473e-02, ...,
#           -6.45453557e-02,  2.71851066e-02, -5.78053258e-02],
#          [-6.33851718e-03, -1.18720008e-03, -2.00594608e-02, ...,
#           -5.00676106e-04,  2.41900720e-02, -3.25657949e-02],
#          [-1.11037130e-02, -6.40918780e-03, -1.01866899e-02, ...,
#            1.34124346e-02, -4.92419122e-06, -2.97896676e-02],
#          ...,
#          [-5.06668165e-03,  4.63936059e-03, -1.05443252e-02, ...,
#            3.92401183e-04,  1.31779816e-02, -1.49273369e-02],
#          [-1.38515485e-02,  3.57808894e-03,  3.23022455e-02, ...,
#            1.49347335e-02, -4.24149893e-02, -4.00504246e-02],
#          [-4.32506530e-03,  2.86427792e-02,  3.24426382e-03, ...,
#           -2.78317910e-02, -2.14047800e-03, -5.76656610e-02]],
#
#         [[-1.13872197e-02,  3.61403599e-02,  8.09514523e-03, ...,
#           -6.11589067e-02,  3.66945006e-02,  3.37038301e-02],
#          [ 4.21160925e-03,  3.97364935e-03, -1.39508126e-02, ...,
#           -2.54600998e-02,  1.78260021e-02, -8.41157045e-03],
#          [-8.57339054e-03, -3.37239099e-03, -9.25276615e-03, ...,
#            2.09000669e-02, -1.96211133e-02, -2.81933183e-03],
#          ...,
#          [-4.47424920e-03,  7.16742361e-03, -1.24174794e-02, ...,
#           -7.62257120e-03,  1.52372280e-02,  1.41849695e-03],
#          [-1.80171542e-02,  1.23670371e-02,  9.66045167e-03, ...,
#            1.03858590e-01,  2.36241557e-02, -2.22947299e-02],
#          [-3.11686518e-03,  3.01599894e-02, -6.39854325e-03, ...,
#           -3.38303819e-02, -7.46327592e-03,  1.15569206e-02]],
#
#         [[-1.11938957e-02,  1.05005922e-02,  1.28840888e-02, ...,
#            2.55359728e-02, -2.47439370e-02,  5.93082421e-02],
#          [ 1.16867805e-02,  5.53547312e-03, -7.34208850e-04, ...,
#           -1.59642510e-02, -2.38013901e-02,  7.41300080e-03],
#          [-1.03702163e-02, -7.70600233e-03, -7.92937260e-03, ...,
#            2.65919680e-05, -2.21675448e-02, -4.81830258e-03],
#          ...,
#          [-3.75637389e-03,  1.34671014e-03, -4.52298764e-03, ...,
#           -2.04247385e-02, -8.20826087e-03,  3.64536681e-04],
#          [-1.78754348e-02, -1.42972767e-02,  2.30224594e-03, ...,
#            5.12144193e-02, -6.39999881e-02, -2.42208038e-02],
#          [-3.40160681e-03,  1.98364481e-02, -2.42157578e-02, ...,
#           -6.77696988e-02, -1.75522473e-02,  4.31288108e-02]]],
#
#
#        [[[-1.38166277e-02, -2.02529356e-02,  1.49409175e-02, ...,
#            4.13343720e-02,  1.12460116e-02, -6.27019331e-02],
#          [-2.05689692e-03, -1.01001449e-02, -1.56024424e-02, ...,
#            2.90803742e-02,  2.29117237e-02, -4.42060009e-02],
#          [-7.52286939e-03, -8.90964549e-03, -1.12696523e-02, ...,
#            2.31409278e-02,  1.31042618e-02, -2.54717190e-02],
#          ...,
#          [-5.83582278e-03, -2.12155865e-03, -6.88488921e-03, ...,
#            1.73429400e-02,  1.62384007e-02, -2.16247290e-02],
#          [-1.75393559e-02, -3.79421189e-02,  6.15364797e-02, ...,
#           -2.23547500e-02, -5.47864772e-02, -4.53480408e-02],
#          [-5.23626804e-03, -1.33635569e-02, -4.28146869e-03, ...,
#            1.66082811e-02, -1.54025229e-02, -4.53032367e-02]],
#
#         [[-1.53795155e-02, -3.84505019e-02,  3.67859751e-02, ...,
#            1.95502420e-03, -8.36236477e-02,  9.88266915e-02],
#          [ 7.03723542e-03, -1.73149873e-02, -6.47397665e-03, ...,
#           -3.71744744e-02, -9.80481319e-03, -9.70997475e-03],
#          [-5.02522057e-03, -7.10768392e-03, -1.16691617e-02, ...,
#            2.05512065e-02, -6.74390281e-03, -6.58325385e-04],
#          ...,
#          [-4.62796120e-03, -5.81725221e-03, -7.10024638e-03, ...,
#           -2.13313987e-03, -3.38115217e-03,  7.19772000e-03],
#          [-1.86906364e-02, -1.46019543e-02,  4.36117165e-02, ...,
#            1.15430512e-01, -2.32385620e-02,  4.81550470e-02],
#          [-3.75997042e-03, -1.81226954e-02, -1.71872601e-02, ...,
#            2.54733656e-02, -1.02616418e-02,  1.39005752e-02]],
#
#         [[-1.29403444e-02, -2.60670111e-02,  2.36307941e-02, ...,
#            1.51971251e-01, -1.20033566e-02,  8.07540938e-02],
#          [ 1.49251437e-02, -1.83216482e-02,  1.58067688e-03, ...,
#            3.59173976e-02, -4.20044586e-02,  2.41606068e-02],
#          [-6.92035817e-03, -1.14960195e-02, -7.52053177e-03, ...,
#            6.58089062e-04, -1.66032240e-02, -6.06053567e-04],
#          ...,
#          [-4.99106990e-03, -1.24031929e-02, -4.44500335e-03, ...,
#            2.47122813e-03, -2.34710444e-02,  9.25894734e-03],
#          [-1.84761733e-02, -1.05872862e-02, -6.10041153e-03, ...,
#           -1.59269050e-02, -1.78986061e-02,  5.42707220e-02],
#          [-2.44738185e-03, -1.09881852e-02, -1.47354463e-02, ...,
#           -5.31265847e-02, -1.10834828e-02,  3.38394381e-02]]],
#
#
#        [[[-9.96980257e-03, -1.68983284e-02,  5.85589139e-03, ...,
#            7.89292976e-02,  1.41468206e-02, -4.02919501e-02],
#          [ 2.93431222e-03, -5.63214254e-03, -7.56553281e-03, ...,
#            1.79513022e-02,  1.00453217e-02, -3.45465988e-02],
#          [-8.38769041e-03, -5.26381237e-03, -1.48851098e-02, ...,
#           -5.96444879e-04,  2.54481323e-02, -2.95654628e-02],
#          ...,
#          [-6.16539689e-03, -5.94602386e-03, -1.57844531e-03, ...,
#            1.25510627e-02,  1.32356957e-02, -2.04815231e-02],
#          [-1.67842377e-02, -3.24696228e-02,  7.01209251e-03, ...,
#            4.07563150e-03,  2.83166822e-02, -4.37535942e-02],
#          [ 5.48103545e-03,  2.91766468e-02, -7.75870727e-03, ...,
#            8.68958421e-03,  8.96310806e-03, -2.33012121e-02]],
#
#         [[-9.74097475e-03, -7.84252957e-03,  3.23801003e-02, ...,
#            1.97367415e-01, -8.22075829e-03,  9.68372729e-03],
#          [ 1.28727984e-02, -5.06093772e-03, -8.11944623e-03, ...,
#            5.20754121e-02,  5.53133292e-03, -2.90027377e-03],
#          [-5.93118696e-03, -1.55510881e-03, -1.63867455e-02, ...,
#            7.59239215e-03,  1.17163155e-02, -5.53943077e-03],
#          ...,
#          [-4.83198650e-03, -8.95360205e-03, -2.54962733e-03, ...,
#            2.71421876e-02,  1.33728271e-03,  3.50910472e-03],
#          [-1.82215441e-02, -5.40840849e-02,  1.99545790e-02, ...,
#           -9.49282944e-02, -3.10497470e-02,  5.41593917e-02],
#          [ 7.24245841e-03,  3.52418795e-02, -1.82386767e-02, ...,
#            8.67759436e-03,  2.25603618e-02, -2.65942626e-02]],
#
#         [[-9.03812144e-03,  5.31508867e-03,  1.93326063e-02, ...,
#            4.13513891e-02,  1.48642976e-02, -1.40332049e-02],
#          [ 1.89762656e-02, -5.43108303e-03, -9.99709684e-03, ...,
#            1.23626683e-04, -7.45136151e-03, -3.80225573e-03],
#          [-7.37456232e-03, -5.95433731e-03, -1.12261567e-02, ...,
#           -1.12029836e-02,  1.37765775e-03, -9.92031861e-03],
#          ...,
#          [-4.89151804e-03, -1.14096375e-02, -3.65528511e-03, ...,
#           -1.06364619e-02, -6.85869763e-03, -9.13915597e-03],
#          [-1.53259905e-02, -3.40283103e-02,  3.56271164e-03, ...,
#           -1.29744057e-02, -3.49182263e-02,  7.50225410e-02],
#          [ 7.39992550e-03,  3.22481208e-02, -1.27051855e-02, ...,
#           -2.77830735e-02,  1.35734072e-02, -1.19610419e-02]]]],
#       dtype=float32)>, <tf.Variable 'block2_conv1/bias:0' shape=(128,) dtype=float32, numpy=
# array([-0.04837531,  0.06229509, -0.02992396,  0.08396146,  0.12856957,
#         0.2439881 ,  0.16541947,  0.23835361,  0.22084029,  0.14067729,
#         0.03227366,  0.14848852,  0.00960904, -0.00192379,  0.27068746,
#         0.24197567,  0.27173236,  0.26801383,  0.26924115,  0.26946032,
#         0.22071946,  0.18699075,  0.00244094,  0.05912102,  0.36593503,
#         0.22062309,  0.14186245,  0.02190734, -0.01943441,  0.06524027,
#         0.31438908, -0.07668731,  0.10264135,  0.21086296, -0.07491725,
#        -0.08690485,  0.13681573,  0.2366894 ,  0.02775683, -0.0051623 ,
#         0.00606681,  0.30545393,  0.13106205,  0.00420329,  0.27082482,
#         0.25066972,  0.2905127 ,  0.12678508,  0.27911186, -0.0424143 ,
#        -0.04499029,  0.06145468,  0.09698018, -0.10274215,  0.10241536,
#         0.2355289 ,  0.07800988,  0.12485806,  0.11525775, -0.01694759,
#        -0.10351368,  0.22653383,  0.09040253,  0.06239903,  0.1954472 ,
#         0.07079789,  0.26097664, -0.06651807,  0.04613192, -0.06243384,
#         0.13008665,  0.08966239,  0.10550325,  0.22589158, -0.0355419 ,
#        -0.17973182,  0.20100297,  0.0495044 ,  0.17623979,  0.21694897,
#         0.12444108,  0.15996651,  0.16132371,  0.3571096 , -0.05324265,
#         0.21209913,  0.14440945,  0.10075273,  0.23591806, -0.01699435,
#         0.14032097, -0.1602058 ,  0.05326375,  0.17828988,  0.19328493,
#         0.04762083,  0.14638267,  0.15247047,  0.04948208,  0.22278392,
#         0.02474874,  0.04382031,  0.04997051,  0.3194868 , -0.02450104,
#         0.00528712,  0.01970183,  0.19577907, -0.01304583,  0.25767812,
#         0.13683781,  0.28869936, -0.00137693, -0.01098264,  0.06942806,
#         0.02032766,  0.2545536 , -0.04006743,  0.02848855,  0.2639108 ,
#        -0.10653137,  0.00116762,  0.2803122 , -0.08979525,  0.06601503,
#         0.31657735,  0.09481623,  0.1276997 ], dtype=float32)>, <tf.Variable 'block2_conv2/kernel:0' shape=(3, 3, 128, 128) dtype=float32, numpy=
# array([[[[-4.47531510e-03, -5.01017226e-03,  6.82439748e-03, ...,
#            4.87090182e-03,  1.52006093e-03,  6.40401896e-03],
#          [ 3.39264260e-03,  3.25895729e-04,  1.76765919e-02, ...,
#           -3.16258334e-02, -4.04155161e-03, -1.92659497e-02],
#          [-1.21273855e-02, -6.86832424e-03, -6.36380306e-03, ...,
#            1.73982349e-03, -4.90562022e-02, -7.28116604e-03],
#          ...,
#          [-1.33942976e-03, -2.96911765e-02,  2.84130238e-02, ...,
#            4.69582970e-04, -2.72818003e-02, -3.55473324e-03],
#          [ 1.24689387e-02, -6.13681390e-04, -4.06689057e-03, ...,
#           -2.20532585e-02, -1.67432614e-02,  2.35765632e-02],
#          [ 1.70043912e-02, -3.14987302e-02, -2.60351337e-02, ...,
#            4.03982215e-02,  5.78578375e-02, -2.25071628e-02]],
#
#         [[-2.62835785e-03, -4.64781327e-03,  1.74236705e-03, ...,
#            5.49311051e-03, -3.18840379e-03,  1.41872568e-02],
#          [ 3.77466599e-03, -1.58810304e-04,  2.07014736e-02, ...,
#           -3.53901051e-02, -2.74992106e-03, -7.77128106e-03],
#          [-1.32751726e-02, -9.26894229e-03,  1.10918432e-02, ...,
#           -2.41098041e-03, -4.17711176e-02,  8.53663217e-03],
#          ...,
#          [-5.13587659e-03,  4.17107679e-02,  5.67852594e-02, ...,
#            3.09375338e-02, -1.09208254e-02, -2.36725938e-02],
#          [ 1.36254914e-02,  1.86994094e-02, -3.57893929e-02, ...,
#           -2.21981257e-02, -1.98796187e-02,  7.91260321e-03],
#          [-6.92594936e-03,  1.19703850e-02,  2.72307731e-02, ...,
#            1.07891671e-02,  8.46962035e-02, -6.68990836e-02]],
#
#         [[-1.63385086e-03,  1.96955516e-03, -6.90983422e-03, ...,
#            7.46559398e-03, -7.90278893e-03,  1.67254116e-02],
#          [ 8.11985228e-03, -4.03887453e-03,  2.38216687e-02, ...,
#           -1.57978404e-02,  9.09295306e-03, -5.66618377e-03],
#          [ 3.12749646e-03,  1.26771023e-02,  1.20406942e-02, ...,
#           -1.35726342e-02, -2.57061241e-04,  1.13446005e-02],
#          ...,
#          [ 1.20661734e-03,  4.22979742e-02,  2.67398544e-02, ...,
#            8.11382569e-03,  3.00854966e-02, -5.04293293e-03],
#          [ 6.65336661e-03, -1.76302362e-02,  1.14238188e-02, ...,
#           -9.16065741e-03,  6.78631430e-03, -6.86156284e-03],
#          [-2.37237546e-03,  6.72679394e-02,  8.35599005e-03, ...,
#            1.61130093e-02,  9.92608890e-02, -6.03344338e-03]]],
#
#
#        [[[-9.23159812e-03, -5.14768297e-03,  4.16196324e-03, ...,
#           -2.12377706e-03,  3.04410327e-03,  6.79512834e-03],
#          [-4.88369493e-03,  1.26698753e-03,  6.23761164e-03, ...,
#           -6.71495050e-02, -1.24250231e-02,  1.22698219e-02],
#          [-2.42971834e-02, -1.01363389e-02,  3.31849721e-03, ...,
#           -5.25285664e-04, -5.36121093e-02, -1.35652879e-02],
#          ...,
#          [-3.09630483e-03, -4.56007160e-02,  4.36755307e-02, ...,
#           -1.67154633e-02, -3.61971371e-02, -2.61262879e-02],
#          [ 9.98469722e-03, -4.85952664e-03, -2.33513005e-02, ...,
#           -8.76576677e-02, -2.29986273e-02,  5.24566099e-02],
#          [ 2.21364871e-02, -2.82159653e-02, -1.24585107e-02, ...,
#            4.77417000e-02,  3.59802954e-02, -2.96183378e-02]],
#
#         [[-6.33573299e-03, -3.75118479e-03, -5.57250343e-03, ...,
#           -2.26788037e-03, -8.74881167e-04,  1.39132123e-02],
#          [-7.53337154e-05,  4.58927313e-03,  1.05669126e-02, ...,
#           -7.30483830e-02,  3.49809881e-04,  4.57226718e-03],
#          [-3.08187269e-02, -4.37667128e-03,  1.20118139e-02, ...,
#           -9.00196144e-04, -4.75852899e-02,  1.01199560e-02],
#          ...,
#          [-5.58863766e-03,  7.03827813e-02,  4.53611650e-02, ...,
#           -2.76022200e-02, -2.66806409e-02, -3.66044715e-02],
#          [ 8.83155037e-03,  1.56995691e-02,  6.85662543e-03, ...,
#           -7.62697384e-02, -2.08563227e-02,  6.05068542e-03],
#          [-2.03718594e-03,  5.19541167e-02,  1.91732533e-02, ...,
#            4.64089913e-03,  4.57834713e-02, -7.72600695e-02]],
#
#         [[-4.02144110e-03,  9.32555355e-04, -7.03197857e-03, ...,
#            2.08641542e-03, -5.88551955e-03,  1.78787801e-02],
#          [ 4.59778635e-03,  2.34820833e-03,  1.96373612e-02, ...,
#           -4.40665707e-02,  2.14821901e-02, -8.69894773e-03],
#          [-1.66197140e-02,  2.29039285e-02, -5.56218345e-03, ...,
#           -7.21787428e-03, -1.63231790e-02,  1.01024406e-02],
#          ...,
#          [-4.24599537e-04,  4.02828529e-02, -3.12451720e-02, ...,
#           -4.01965855e-03, -6.64502988e-03, -3.26061127e-04],
#          [ 4.06068237e-03, -1.44893629e-02,  2.66333148e-02, ...,
#           -2.88698263e-02,  7.34462519e-04, -7.42625492e-03],
#          [ 4.93197190e-03,  7.99638182e-02,  7.85413105e-03, ...,
#            1.24734379e-02,  7.94159472e-02, -1.10969357e-02]]],
#
#
#        [[[-1.37348352e-02, -6.45883149e-03, -2.32256274e-03, ...,
#           -3.11672156e-05,  5.50785474e-03,  3.86411441e-03],
#          [-1.16386637e-02, -1.88004803e-02, -1.19781783e-02, ...,
#           -4.74431552e-02, -4.09652805e-03,  1.45938562e-03],
#          [-2.54926234e-02, -1.36297969e-02,  1.62002239e-02, ...,
#           -2.25366605e-03, -3.21264379e-02, -2.09875945e-02],
#          ...,
#          [ 1.25891250e-02, -2.88620237e-02,  1.79045331e-02, ...,
#           -1.68197658e-02, -3.68978567e-02, -2.60683075e-02],
#          [ 3.47683113e-03, -1.29441749e-02, -6.19374169e-03, ...,
#           -4.54917699e-02, -1.25361113e-02,  3.54200453e-02],
#          [ 1.87708046e-02, -3.73664638e-03,  2.94612278e-03, ...,
#            4.08364981e-02,  2.61776336e-02, -1.16477013e-02]],
#
#         [[-1.05003566e-02, -5.48687996e-03, -8.85346625e-03, ...,
#            1.23599160e-03,  2.16257269e-03,  1.13856979e-02],
#          [-7.93395471e-03, -1.57285500e-02, -4.46368754e-03, ...,
#           -5.64840473e-02,  2.23232619e-03, -5.77499205e-03],
#          [-3.22172605e-02, -3.10970214e-03, -2.55558616e-03, ...,
#           -1.32770902e-02, -3.40738632e-02, -7.72134517e-04],
#          ...,
#          [ 1.93767133e-03,  8.52887630e-02, -2.90114712e-02, ...,
#            3.10712326e-02, -3.34790982e-02, -1.77966766e-02],
#          [ 1.75777322e-03,  1.16689671e-02,  2.93224156e-02, ...,
#           -5.66314496e-02, -1.19021330e-02, -1.05581386e-03],
#          [-1.23183178e-02,  7.31125176e-02,  1.44435223e-02, ...,
#            3.10640759e-03,  9.98979993e-03, -4.34620604e-02]],
#
#         [[-7.41800433e-03,  1.92868290e-03, -3.00729019e-03, ...,
#            5.41306287e-03, -1.12469669e-03,  1.57276914e-02],
#          [-6.39730191e-04, -5.10921609e-03,  2.49170209e-03, ...,
#           -4.13902067e-02,  1.52049176e-02, -8.57801456e-03],
#          [-2.60044821e-02,  2.31843907e-02, -2.25766525e-02, ...,
#           -1.36576798e-02, -3.20593715e-02,  7.46063842e-03],
#          ...,
#          [ 3.85060487e-03,  2.39624213e-02, -3.44744809e-02, ...,
#            3.90948392e-02, -1.83128826e-02,  4.42595163e-04],
#          [ 9.01682768e-04, -1.24052260e-02,  9.31241643e-03, ...,
#           -3.49911712e-02, -2.83692003e-04, -8.20396375e-03],
#          [ 3.21553927e-03,  6.67835549e-02,  1.13790743e-02, ...,
#            8.88735708e-03,  4.69213612e-02,  1.62025040e-03]]]],
#       dtype=float32)>, <tf.Variable 'block2_conv2/bias:0' shape=(128,) dtype=float32, numpy=
# array([-0.06358463, -0.11619917, -0.13203497,  0.06041638,  0.26830924,
#        -0.10265807,  0.05537793, -0.02653151,  0.02511058, -0.16939104,
#         0.12981968, -0.01395851, -0.28213602, -0.01933072,  0.14451702,
#        -0.21041802,  0.09781059, -0.01421438, -0.10562301,  0.11758621,
#        -0.2105509 , -0.22847477,  0.44315174,  0.03927073, -0.3116334 ,
#        -0.03879532, -0.26362154,  0.05015037,  0.14623258, -0.09937703,
#        -0.16269821, -0.08452745,  0.257498  ,  0.08978545,  0.0343609 ,
#         0.23615262, -0.5986512 ,  0.2797805 ,  0.0224078 ,  0.15350574,
#         0.10885727,  0.15375663, -0.2795585 ,  0.14514524, -0.07329232,
#         0.00628144, -0.08087526,  0.16088274, -0.17337663, -0.00771709,
#        -0.257614  ,  0.0932889 ,  0.35847083, -0.09445935,  0.08110686,
#        -0.2422698 , -0.12989528, -0.01785847, -0.11886676, -0.11688007,
#        -0.18177755,  0.16512811, -0.0488662 , -0.0451234 ,  0.14331968,
#         0.27121767,  0.35708582,  0.03518255, -0.18194741,  0.04902291,
#         0.635715  , -0.21160758, -0.06284034,  0.12349804, -0.0893742 ,
#        -0.30466887,  0.28382766,  0.10554448,  0.14336003, -0.04807401,
#        -0.08806173,  0.1336299 ,  0.16854551,  0.06872611, -0.10877664,
#         0.45128193, -0.07748225, -0.04620698,  0.181104  , -0.01950123,
#        -0.02106551,  0.37676156,  0.07484005, -0.0947985 ,  0.30571607,
#         0.01592063,  0.15687163, -0.18455483,  0.07553931, -0.28940842,
#         0.20914496, -0.23112315,  0.17285545,  0.20318   , -0.44322124,
#         0.04630876, -0.14852609, -0.02482352,  0.14842416,  0.00379603,
#         0.0045768 , -0.17618395, -0.00792637, -0.26059505, -0.01335111,
#         0.04803601,  0.17411898, -0.01999248, -0.11055173,  0.01844126,
#        -0.08424346,  0.06602081,  0.01045883,  0.38280836,  0.11657921,
#         0.2066799 ,  0.24012093,  0.27673063], dtype=float32)>, <tf.Variable 'block3_conv1/kernel:0' shape=(3, 3, 128, 256) dtype=float32, numpy=
# array([[[[ 1.74697873e-03,  3.90031165e-03, -3.08467969e-02, ...,
#            6.78232405e-03,  7.72772590e-04,  9.42567084e-03],
#          [ 1.41309574e-02,  2.08759890e-03, -3.82454433e-02, ...,
#            8.60340986e-03,  3.25900433e-03, -2.42217048e-03],
#          [-1.00660017e-02,  1.08325277e-02, -1.20330937e-02, ...,
#            1.20841283e-02,  1.94719038e-03,  8.50983430e-03],
#          ...,
#          [ 2.67412630e-03,  6.51967665e-03, -4.56829369e-02, ...,
#           -6.56854222e-03,  2.15127636e-02, -1.89372413e-02],
#          [ 1.66366138e-02, -1.66872470e-03, -4.05302681e-02, ...,
#           -3.13375192e-03,  8.83374177e-03, -4.53983259e-04],
#          [-4.69728466e-03,  1.26012797e-02, -2.34606098e-02, ...,
#            2.09028218e-02,  2.79779290e-03, -1.76665299e-02]],
#
#         [[ 4.66697896e-03,  6.02417486e-03,  2.09119525e-02, ...,
#            5.54185268e-03,  1.69843296e-03,  1.12583311e-02],
#          [-3.05434875e-02,  1.25527475e-02,  1.60541423e-02, ...,
#            1.31760938e-02,  1.48165468e-02, -6.17001671e-04],
#          [-2.39327382e-02,  2.13529058e-02,  1.16805509e-02, ...,
#            2.55854148e-02,  9.78127588e-03,  1.57245074e-03],
#          ...,
#          [ 5.47423586e-03,  1.02567980e-02,  1.29812863e-02, ...,
#           -1.39297370e-03,  3.07266247e-02, -1.73997879e-02],
#          [ 4.91597168e-02,  1.09971678e-02,  3.76604646e-02, ...,
#            1.07462443e-02,  5.29982243e-03,  8.06378108e-03],
#          [-2.05044448e-02,  3.57163465e-03, -2.43783481e-02, ...,
#            3.44482660e-02,  2.09178645e-02, -3.15922946e-02]],
#
#         [[ 8.85604694e-03,  9.26546101e-03, -3.10844779e-02, ...,
#            8.99205974e-04, -6.59315521e-03,  1.04009975e-02],
#          [-3.01301926e-02,  1.59199107e-02,  1.41737598e-03, ...,
#           -1.36632065e-03,  1.61599088e-02,  5.03524439e-03],
#          [ 2.41236971e-03,  1.50018344e-02, -1.63455158e-02, ...,
#            1.68089569e-02,  2.87260883e-03,  2.43999320e-03],
#          ...,
#          [ 2.94872769e-03,  2.46649166e-03, -5.06950878e-02, ...,
#           -6.06754050e-03,  2.40879739e-03, -1.70862339e-02],
#          [ 2.72962619e-02,  1.51974661e-02,  1.75607279e-02, ...,
#            9.72536579e-03,  4.00652597e-03,  8.19030870e-03],
#          [-1.76479667e-02,  1.19753024e-02, -3.86288092e-02, ...,
#            2.87749451e-02,  1.89280119e-02, -1.91272069e-02]]],
#
#
#        [[[ 4.23622178e-03, -3.40360403e-03,  1.78975686e-02, ...,
#            1.04602585e-02,  8.71870943e-05,  3.62988515e-03],
#          [-3.19849607e-03, -2.32310612e-02, -1.36456760e-02, ...,
#           -1.44603113e-02,  4.54819296e-03, -3.76112317e-03],
#          [-1.58882998e-02, -4.60421341e-03,  3.15258815e-03, ...,
#            6.49587018e-03,  2.72673275e-03,  2.45591672e-03],
#          ...,
#          [ 1.77260500e-03, -3.95619823e-03,  2.15345640e-02, ...,
#            1.66655835e-02,  1.44622428e-02, -2.93027218e-02],
#          [ 1.13867864e-03, -8.69957078e-03,  5.83891384e-03, ...,
#            6.42431015e-03,  7.29028427e-04, -3.90803115e-03],
#          [ 1.36356358e-03, -1.22439712e-02,  3.32937762e-02, ...,
#           -6.60937699e-03,  4.27408097e-03, -2.61121392e-02]],
#
#         [[ 5.36226993e-03, -4.73735156e-03,  7.11042583e-02, ...,
#            5.71530545e-03,  1.48641213e-03,  5.92751428e-03],
#          [-5.17779812e-02, -1.90088395e-02,  3.76397967e-02, ...,
#           -2.53506042e-02,  7.08303740e-03,  1.11675952e-02],
#          [-6.51028706e-03, -1.34831732e-02,  3.99090424e-02, ...,
#            2.00473238e-03,  2.79614702e-03, -2.22925737e-04],
#          ...,
#          [ 1.48049765e-03, -1.94963126e-03,  8.83524492e-02, ...,
#            2.91463621e-02,  4.88908887e-02, -3.45770158e-02],
#          [ 4.98877056e-02,  1.19263784e-03,  8.26333165e-02, ...,
#            2.24103983e-02,  1.36369765e-02,  6.99523953e-04],
#          [-2.37062853e-02, -2.77733635e-02,  3.80136855e-02, ...,
#           -7.72072515e-03,  6.47919765e-03, -3.96717004e-02]],
#
#         [[ 4.34895791e-03,  1.22500584e-03,  1.36239883e-02, ...,
#            1.13588048e-03, -1.85968261e-03,  5.54579729e-03],
#          [-3.81155945e-02,  6.06390787e-03,  1.57564860e-02, ...,
#           -3.25249066e-03,  3.01174703e-04,  1.05974339e-02],
#          [ 1.19504612e-02, -1.12677151e-02,  3.21217882e-03, ...,
#           -6.05048612e-03, -4.98435413e-03,  5.47387637e-03],
#          ...,
#          [ 1.11390697e-03, -2.88915285e-03,  8.87317304e-03, ...,
#            2.03068275e-02,  3.56303975e-02, -3.30327563e-02],
#          [ 3.84695604e-02,  1.45812035e-02,  3.65775749e-02, ...,
#            1.80803966e-02,  2.51391493e-02,  2.78702821e-03],
#          [-1.96363050e-02, -2.79146731e-02,  1.34233059e-02, ...,
#           -1.44922985e-02, -5.91773633e-03, -2.29101516e-02]]],
#
#
#        [[[ 4.78993729e-03, -3.32641485e-03, -8.23813025e-03, ...,
#            1.14934091e-02, -3.81046557e-03, -6.28487673e-03],
#          [-1.09297140e-02, -1.66711900e-02, -3.64487059e-02, ...,
#           -1.62952561e-02,  8.13692249e-03, -4.60813986e-03],
#          [ 4.04736772e-03, -1.76442470e-02, -1.35058686e-02, ...,
#           -1.41079510e-02,  1.15054362e-02, -3.78094544e-03],
#          ...,
#          [-5.93363773e-03, -1.27262287e-02, -3.70740518e-02, ...,
#            1.37445433e-02, -1.66565329e-02, -2.13155504e-02],
#          [-8.08952376e-03, -2.63156518e-02, -5.66766411e-02, ...,
#           -1.31229404e-02, -1.13809039e-03, -4.16425843e-04],
#          [ 1.25111537e-02, -2.03394741e-02, -1.66753605e-02, ...,
#           -2.86522731e-02,  1.43261729e-02, -2.28249449e-02]],
#
#         [[ 1.22191253e-04, -8.88360385e-03,  1.76640544e-02, ...,
#            1.09796440e-02, -1.21634116e-03, -9.25765838e-03],
#          [-2.22946871e-02, -1.75322909e-02,  1.88037679e-02, ...,
#           -2.66405158e-02,  2.24998705e-02,  4.84044518e-04],
#          [ 1.51745658e-02, -1.23730619e-02,  1.24523062e-02, ...,
#           -1.67965069e-02,  1.28940605e-02, -3.07806116e-03],
#          ...,
#          [ 2.57339957e-03, -1.11177964e-02,  1.71853155e-02, ...,
#            1.92724913e-02,  6.68946141e-03, -2.46865302e-02],
#          [ 1.74602624e-02, -1.28743239e-02,  1.81597490e-02, ...,
#           -1.73393842e-02, -9.27272777e-04, -1.99185382e-03],
#          [-5.62135363e-03, -3.49921882e-02, -1.74759999e-02, ...,
#           -4.74102572e-02,  1.68576017e-02, -3.21782827e-02]],
#
#         [[-7.84610165e-05, -6.17309473e-03, -3.41527276e-02, ...,
#            7.25354906e-03, -2.59090355e-03, -5.91188949e-03],
#          [-9.55264829e-03,  6.25218207e-04,  2.03920752e-02, ...,
#            2.56778556e-04,  1.03505543e-02, -3.06898402e-03],
#          [ 4.56890184e-03, -1.05705543e-03, -7.97588844e-03, ...,
#           -6.07287372e-03,  3.90760135e-04,  3.35638900e-03],
#          ...,
#          [-8.61186709e-04, -1.36294691e-02, -4.62266356e-02, ...,
#            2.01846007e-02,  3.19837382e-05, -2.80583669e-02],
#          [ 1.41759068e-02,  5.92150399e-03, -1.47735700e-02, ...,
#            1.96373812e-03,  4.31650691e-03, -1.77868758e-03],
#          [-6.07298175e-03, -3.74877229e-02, -3.33595462e-02, ...,
#           -4.86976989e-02,  1.54620165e-03, -1.66047756e-02]]]],
#       dtype=float32)>, <tf.Variable 'block3_conv1/bias:0' shape=(256,) dtype=float32, numpy=
# array([-7.93213248e-02, -8.21631309e-03,  2.03247115e-01,  5.64933755e-02,
#         2.36660130e-02,  9.75459255e-03,  1.31514102e-01,  9.00079310e-02,
#         1.51464790e-01, -3.45348679e-02,  6.21168828e-03, -9.34300013e-03,
#        -2.80169654e-03, -1.01924956e-01, -5.46150133e-02,  1.35906423e-02,
#         1.06050156e-01,  1.76980309e-02, -9.30650905e-02,  1.00380167e-01,
#         1.40464231e-01, -1.98509060e-02,  1.86532941e-02, -1.18523249e-02,
#         5.01308404e-02,  4.89571244e-02,  1.46507934e-01,  8.53593927e-03,
#        -3.39395367e-02,  8.10638517e-02, -7.58666024e-02,  7.76200518e-02,
#         3.15791145e-02, -2.97404341e-02,  1.53191602e-02, -3.42327665e-04,
#        -8.67903754e-02, -1.02521136e-01, -4.05121818e-02, -5.99549003e-02,
#         1.17688000e-01,  2.12819874e-02, -1.90955177e-02,  3.44887152e-02,
#        -7.15621263e-02,  3.67439911e-02, -2.20509805e-03, -6.24161027e-02,
#        -2.16369499e-02, -3.01635601e-02, -5.31095825e-02, -2.68139597e-03,
#         1.85700152e-02,  6.16998635e-02, -6.03456050e-02,  7.91798607e-02,
#         1.21047804e-02,  8.09690952e-02, -5.65887941e-03,  1.05271578e-01,
#        -1.60005949e-02,  5.07473275e-02, -9.06753354e-04,  8.01072195e-02,
#        -4.43897396e-02,  7.94184729e-02, -2.14526244e-02, -4.70907101e-03,
#         6.03646375e-02,  4.62089330e-02,  4.85421754e-02, -6.41537607e-02,
#         1.21874750e-01,  6.53558671e-02,  4.11920734e-02,  1.61034897e-01,
#         3.79428342e-02, -3.77645828e-02,  2.64039338e-02,  1.54798198e-02,
#        -1.04157708e-03, -3.08956578e-02, -5.87691218e-02,  8.07505175e-02,
#         1.07278034e-01,  5.65979853e-02,  2.56549306e-02, -1.49488583e-01,
#        -4.76841554e-02, -3.07090450e-02, -2.73264069e-02,  1.73202790e-02,
#         3.83320707e-03,  4.30324897e-02, -1.02518983e-01, -4.00689198e-03,
#        -9.93057042e-02, -8.70537236e-02,  5.87489568e-02,  1.14278920e-01,
#         8.42501130e-03, -5.80360778e-02, -4.97608371e-02, -2.00736951e-02,
#        -2.59636417e-02,  8.38869363e-02,  5.48866913e-02,  1.37670934e-01,
#        -9.64344367e-02,  1.71045199e-01,  1.27429115e-02, -2.75170486e-02,
#         6.61932528e-02,  8.27703029e-02,  6.07028196e-04, -7.55775161e-03,
#         1.58154488e-01,  5.92716113e-02,  1.66490376e-02,  1.49956048e-01,
#        -1.09511549e-02, -2.44347919e-02,  5.96337812e-03,  7.49890059e-02,
#        -1.70861214e-01, -4.21941392e-02, -5.56732751e-02, -1.60133168e-01,
#        -6.99833930e-02, -7.10191801e-02,  4.53872941e-02, -3.27743962e-02,
#        -2.02744871e-01, -1.43218070e-01,  7.84429088e-02,  3.84847037e-02,
#        -8.21426231e-03, -3.28565650e-02, -2.31979648e-03,  9.21282917e-03,
#         3.66434939e-02, -1.14172772e-02,  7.91981742e-02,  2.59118974e-02,
#         4.19438407e-02,  1.19414762e-01,  7.39596412e-02,  3.29021295e-03,
#         9.66852531e-02,  2.16233507e-02,  1.04667321e-01, -7.02989940e-03,
#        -2.83758324e-02,  2.97975857e-02,  1.36733651e-02,  8.81210268e-02,
#        -7.89948702e-02,  2.22856998e-02,  1.68474883e-01, -5.01766391e-02,
#        -2.02108384e-03,  3.34535502e-02, -4.50422764e-02,  6.51121065e-02,
#        -3.15690823e-02,  9.22479853e-02, -2.89801732e-02,  2.60460172e-02,
#         1.24652556e-03, -3.65083329e-02,  6.08221851e-02, -5.20634949e-02,
#        -3.80245484e-02, -4.53786515e-02, -6.56914562e-02, -3.84358317e-02,
#        -2.48426199e-02, -5.98735698e-02,  5.53962141e-02,  1.78096932e-03,
#         1.30393267e-01, -5.63493744e-02, -3.57602648e-02,  3.77596952e-02,
#         1.14005528e-01,  4.14182208e-02,  6.56700730e-02, -4.99409661e-02,
#        -9.61304605e-02, -9.81812272e-03, -1.67041551e-02,  1.69844836e-01,
#        -2.22918950e-02, -1.56854298e-02,  9.73617658e-02,  4.96121459e-02,
#         7.79415518e-02,  6.14866754e-03, -1.00428395e-01,  4.77863587e-02,
#        -1.47357089e-02,  8.26974884e-02,  8.63980129e-03, -2.62080077e-02,
#         7.10248202e-02,  9.39730480e-02,  2.04874277e-01, -2.03633532e-02,
#        -4.33943048e-03,  3.20031978e-02, -1.73968691e-02,  6.84739128e-02,
#         9.68486741e-02,  1.37915000e-01,  3.39375529e-03,  4.93741594e-02,
#        -8.98517109e-03,  4.29058187e-02,  1.24592714e-01,  6.73753908e-03,
#         2.03776937e-02, -1.54243996e-02, -4.74331193e-02, -6.39853328e-02,
#        -4.94334176e-02, -9.09794308e-03,  7.50534609e-02,  1.18179381e-01,
#         4.06529643e-02, -3.73510011e-02,  6.10676259e-02, -5.49396649e-02,
#        -1.07748695e-02,  4.68476936e-02,  1.13467090e-01,  2.93977093e-03,
#        -6.78733662e-02, -3.37668904e-03, -3.26324776e-02,  3.45501393e-01,
#         1.33106261e-01,  7.50279054e-02,  9.55407880e-03, -2.09110463e-03,
#         2.05887984e-02, -3.72676663e-02,  5.39471768e-02,  2.84343045e-02,
#         5.18263376e-04,  6.82180077e-02,  7.78668374e-02, -3.10059786e-02,
#        -1.97301377e-02,  5.28548323e-02, -4.72076759e-02, -2.84009501e-02],
#       dtype=float32)>, <tf.Variable 'block3_conv2/kernel:0' shape=(3, 3, 256, 256) dtype=float32, numpy=
# array([[[[-1.11435726e-02, -1.70266640e-03, -8.12157989e-04, ...,
#           -2.06516916e-03, -1.14328787e-02, -1.11998792e-03],
#          [-1.21202385e-02, -3.92211415e-03, -1.06157211e-03, ...,
#           -9.23608337e-03, -7.62052508e-03,  2.96158623e-03],
#          [ 2.17472464e-02, -1.29315155e-02, -1.04958843e-02, ...,
#           -3.70667456e-03,  9.09961201e-03,  1.32897841e-02],
#          ...,
#          [-1.50911855e-02, -2.43773847e-03,  2.95614707e-03, ...,
#            3.89500521e-03, -1.78430136e-02, -1.58302318e-02],
#          [-4.23811289e-04, -5.07047353e-03, -4.38025035e-03, ...,
#           -6.04369631e-03, -1.54785616e-02,  8.30795895e-03],
#          [-4.29415231e-05, -1.10600367e-02,  5.74494386e-03, ...,
#           -1.12332019e-03, -3.28513794e-04, -2.76197982e-03]],
#
#         [[-6.34564506e-03, -4.15428169e-03,  1.13891682e-03, ...,
#           -1.05130179e-02, -7.18868803e-03, -1.21317087e-02],
#          [-4.70015453e-03,  2.17417674e-03, -3.81744863e-03, ...,
#           -1.05736600e-02, -9.76916589e-03,  4.58631106e-03],
#          [ 2.84250285e-02,  5.87686244e-03,  2.12673899e-02, ...,
#            1.98561959e-02,  1.73991583e-02,  2.38988753e-02],
#          ...,
#          [-8.06710403e-03,  6.76327012e-03, -1.34004466e-03, ...,
#            2.14981777e-03, -1.56503562e-02, -1.45934466e-02],
#          [ 8.66087154e-03, -1.76761136e-03, -9.24357027e-03, ...,
#           -6.02108659e-03, -1.86961237e-02,  6.99066417e-03],
#          [-1.35055371e-02,  1.81465894e-02,  2.01006522e-04, ...,
#           -6.46615960e-03, -3.90692148e-04, -2.93270685e-03]],
#
#         [[ 4.18140879e-03, -5.92748635e-03,  6.57994812e-03, ...,
#           -6.14378182e-03, -9.63555370e-03, -6.23131311e-03],
#          [-4.53548599e-03,  5.63492486e-03, -2.37680040e-03, ...,
#           -5.77742327e-03, -1.13952812e-02,  6.90623326e-03],
#          [ 2.65417360e-02, -3.42134200e-03,  5.80488797e-03, ...,
#           -1.08541334e-02,  7.69789284e-03,  6.69223024e-03],
#          ...,
#          [-9.89566464e-03,  6.76732324e-03, -5.62259695e-03, ...,
#            2.82197259e-03, -1.62062086e-02, -7.86770042e-03],
#          [ 1.10479817e-02, -7.65924167e-04, -1.10397744e-03, ...,
#           -2.31721031e-04, -1.87011212e-02,  4.31549968e-03],
#          [-1.64001770e-02,  1.21238399e-02, -3.80486762e-03, ...,
#           -2.89121899e-03,  2.65619322e-03, -3.79397476e-04]]],
#
#
#        [[[-1.43777961e-02,  2.85110390e-03,  3.31449625e-03, ...,
#            2.72272527e-03,  1.45834005e-02, -1.52417989e-02],
#          [-1.12352576e-02, -2.72977748e-03,  7.71685084e-03, ...,
#           -5.31732431e-03, -9.28753335e-03, -9.18577891e-03],
#          [ 2.21871845e-02, -2.27131275e-03,  2.00060215e-02, ...,
#            3.55837047e-02,  2.48894263e-02,  4.34188619e-02],
#          ...,
#          [-2.29472574e-03, -1.45328334e-02,  1.85790826e-02, ...,
#            4.48304880e-03,  6.75730361e-03, -1.56163601e-02],
#          [-9.58374795e-03,  6.72291080e-03, -1.15293115e-02, ...,
#            2.23939167e-03, -2.07802933e-02,  2.10309145e-03],
#          [ 8.48834310e-03, -4.37589269e-03,  3.97170382e-03, ...,
#            1.58507610e-03, -5.22472011e-03, -8.68397579e-03]],
#
#         [[-1.48943225e-02,  2.64406074e-02, -2.25890637e-03, ...,
#           -1.48696098e-02,  1.64683945e-02, -2.02863403e-02],
#          [-7.77757773e-03,  1.97094050e-03,  4.97275405e-03, ...,
#           -1.02139516e-02, -1.13415252e-02, -7.68850930e-03],
#          [ 2.89149247e-02,  1.55480094e-02,  4.95441630e-02, ...,
#            5.40932752e-02,  4.03804109e-02,  5.26255704e-02],
#          ...,
#          [ 5.53334784e-03, -1.68436449e-02,  1.50323994e-02, ...,
#            3.95629089e-03,  8.17418937e-03, -1.34887472e-02],
#          [ 6.28652237e-03, -1.91476324e-03, -1.65798515e-02, ...,
#            1.77463968e-04, -2.34716516e-02,  2.91665969e-03],
#          [-9.30191763e-03,  2.84068547e-02,  9.24761815e-04, ...,
#           -3.70967924e-03, -9.19431727e-03, -9.60640609e-03]],
#
#         [[-6.52077142e-03,  2.88627017e-03,  1.74141163e-03, ...,
#           -1.67244915e-02,  7.06929434e-03, -1.67142693e-02],
#          [-5.88409649e-03,  3.05549824e-03, -2.57375836e-03, ...,
#           -1.47038894e-02, -9.94889904e-03, -4.55538649e-03],
#          [ 2.40583252e-02,  7.09064258e-03,  3.62284295e-02, ...,
#            2.63208523e-02,  3.41987796e-02,  2.69653928e-02],
#          ...,
#          [ 3.75966658e-03, -9.47354175e-03, -3.94319417e-03, ...,
#            1.06325862e-03,  4.33184579e-03, -1.01846140e-02],
#          [ 9.25910287e-03, -7.94642884e-03, -7.31196860e-03, ...,
#            1.30404951e-03, -2.53308620e-02,  3.46252765e-03],
#          [-1.15333265e-02,  2.41118763e-02, -4.67259996e-03, ...,
#           -4.46627615e-03, -3.06305918e-03, -4.72291140e-03]]],
#
#
#        [[[-9.38195083e-03, -8.49913526e-03,  1.34752691e-02, ...,
# ...
#        -3.20654549e-03,  3.53370351e-03, -1.94085913e-03,  1.22321560e-03,
#         5.97611906e-05, -1.54812797e-03,  1.20902911e-03,  1.28770043e-04,
#         3.52104427e-03,  7.76933692e-03,  1.12630322e-03,  1.11065485e-04,
#        -2.25840625e-03,  4.69593750e-03, -3.24743125e-03,  4.99564037e-03,
#         5.47108939e-03,  5.24195551e-04, -7.53031170e-04, -6.22396357e-04,
#         1.17478345e-03,  1.15598342e-03,  9.72245994e-04,  5.84084634e-03,
#         6.65386254e-03,  1.39626733e-04,  7.99644738e-03, -5.08628739e-03,
#        -7.85690441e-04, -1.94102747e-03, -3.32740112e-03, -2.76447739e-03,
#        -4.54659719e-04,  2.43704394e-03, -1.73466266e-04,  2.42298047e-05,
#        -3.49090947e-03, -1.34570012e-03, -1.30280631e-03,  1.33009325e-03,
#        -2.50809007e-05,  9.21568717e-04,  1.25693728e-03, -1.49584410e-03,
#         1.82726013e-03, -1.90408761e-03, -1.05312944e-03,  4.35325783e-03,
#         6.35698764e-03,  2.46872706e-03, -5.59538952e-04, -8.73416255e-04,
#        -2.02654256e-03, -2.55326042e-04, -1.00195431e-03,  5.71377750e-05,
#         1.48904987e-03, -3.80348996e-03,  8.83419532e-03,  4.87570046e-03,
#        -4.34347568e-03,  2.54200585e-03, -2.38028285e-03,  1.00241909e-02,
#         1.05673308e-03,  8.78387783e-03,  1.38168619e-03,  6.31101604e-04,
#        -2.48102268e-04, -7.61902658e-04, -6.70281239e-04,  6.89436449e-04,
#        -2.38613633e-04,  1.45176053e-03,  1.45430875e-03, -1.81877549e-05,
#        -2.21862472e-04,  2.60319794e-03,  1.49452651e-03,  6.34427508e-03,
#        -2.21434282e-03,  4.14201757e-03,  1.58221298e-03, -4.82102996e-03,
#         4.80111549e-03,  2.34675314e-03,  1.00781304e-04,  6.09842420e-04,
#         1.57998572e-03, -8.17837019e-04, -2.56681786e-04, -2.25309748e-03,
#         1.33675407e-03, -5.93865807e-05, -3.58109456e-03,  2.74187094e-03,
#         5.49881894e-04,  3.29535990e-03,  1.49939704e-04,  3.94303165e-03,
#         1.78842165e-03,  3.35511006e-03, -1.45842053e-03, -1.54181535e-03,
#         4.09908447e-04,  6.30959682e-03,  2.20376882e-03, -1.40730711e-03,
#         5.02787577e-03, -1.92850956e-03,  5.48481755e-03,  9.20187216e-04,
#        -1.42911551e-04,  2.43601575e-03, -1.98866866e-04,  5.82957175e-04,
#         1.09531945e-02, -1.32205989e-03,  4.28831321e-04, -1.90686737e-03,
#         1.57976674e-03,  7.88745657e-03, -4.31017810e-03,  3.89901665e-03,
#        -2.16370635e-03,  3.75090260e-03, -4.48477047e-04, -3.41811450e-04,
#        -2.63590645e-03, -1.00420858e-03,  1.46926986e-03,  6.73797738e-04,
#        -8.43581569e-04, -3.16215702e-03, -3.40827368e-03, -1.47928076e-03,
#         3.85505194e-03,  3.35411751e-03, -1.47419935e-03, -1.18267979e-03,
#         5.16127655e-03,  4.02524741e-03,  2.64990004e-03,  9.78272292e-04,
#        -1.44755538e-03, -7.77667272e-04,  5.84562775e-04,  1.78326841e-03,
#         1.75790151e-03,  1.95691804e-03, -1.74628221e-04,  3.64321400e-03,
#         1.04424462e-03,  1.17852387e-03, -2.02927249e-03,  1.09933806e-03,
#        -4.52857232e-04,  2.64619640e-03,  2.47620628e-03, -1.96078862e-03,
#         5.55287022e-03,  2.10036710e-03,  1.94026984e-03,  2.93359277e-03,
#         1.02010217e-05,  8.93760193e-03, -6.72196737e-04, -3.58056655e-04,
#        -1.39798608e-03,  6.95423922e-04,  5.26118465e-03,  8.47278337e-04,
#        -1.41836691e-03, -5.81527478e-04,  4.05481027e-04, -4.62891720e-03,
#         4.87601338e-03, -1.96005683e-03,  2.63560191e-03, -2.22146441e-03,
#        -6.06080168e-04,  3.00102081e-04, -3.06651904e-03, -2.29611341e-03,
#         8.42035282e-03,  1.33626058e-03,  1.10274763e-03,  2.46129395e-03,
#         2.33362173e-03,  1.47868984e-03,  2.62154522e-03,  1.61015906e-03,
#         6.72046794e-03, -8.54018668e-04,  2.02879596e-06,  5.34371240e-03,
#         3.17535945e-03, -2.73208157e-03, -3.55389435e-03, -2.05822987e-03,
#        -4.81467752e-04, -1.04372820e-03,  6.16034213e-03, -1.22303690e-03,
#         1.22284540e-03,  7.14837806e-03, -1.34753354e-03,  2.44208961e-03,
#         3.65090091e-03, -2.84127775e-04,  3.40892980e-03, -3.44318477e-03,
#         4.22014901e-03,  3.16002220e-03, -2.19170540e-03, -1.64622150e-04,
#        -6.28211128e-04,  2.99390289e-03, -1.53795350e-03, -6.80702273e-04,
#         1.39095855e-03, -2.56930036e-03,  8.34014500e-04, -5.34901163e-04,
#         1.43779872e-03,  3.04747070e-03,  3.06929951e-03,  1.65726303e-03,
#         2.33488600e-03,  1.21605885e-03,  1.35360379e-03, -1.10296940e-03,
#        -1.69535540e-03,  4.20132326e-03, -3.08090309e-03, -5.93979319e-04,
#        -1.41764816e-03,  7.69111328e-04,  4.52247588e-03, -3.03087872e-04,
#         2.42266594e-03,  6.24956388e-04, -2.97833676e-03, -9.70433000e-04,
#        -2.18048203e-03,  3.09566688e-03,  3.82590410e-03, -2.30671559e-03,
#         5.42046095e-04, -1.04719489e-04, -1.80207926e-03, -5.81757049e-04,
#        -1.65032936e-04,  5.45308983e-04,  2.97088502e-03, -1.68542883e-05,
#        -2.06829305e-03,  2.96481024e-03,  1.44863629e-03,  1.24473928e-03,
#         4.68605245e-03, -1.34960841e-03, -2.25610143e-04,  1.46423629e-03,
#         1.24151295e-03,  7.61245086e-04, -6.22811145e-04,  2.85326806e-03,
#         9.07864608e-03,  1.68415322e-03,  1.39190082e-03,  1.51028787e-03,
#         3.74750257e-03,  5.17558819e-03,  3.27479444e-03, -9.76987067e-04,
#         6.69015804e-04,  7.63732009e-04, -7.68079015e-04,  6.70149038e-03,
#        -3.94244300e-04, -7.57402391e-04,  2.75489176e-03, -4.43678582e-04,
#         5.43380715e-03, -1.33770445e-04,  9.60412028e-04,  6.90982072e-03],
#       dtype=float32)>, <tf.Variable 'rpn_out_class/kernel:0' shape=(1, 1, 512, 9) dtype=float32, numpy=
# array([[[[-0.02432056, -0.03926463,  0.01898881, ..., -0.01799199,
#            0.04982049, -0.0420844 ],
#          [-0.0196853 , -0.02270358, -0.04453883, ..., -0.00103482,
#            0.03979156, -0.04867876],
#          [-0.00661491,  0.04189427, -0.00431982, ...,  0.00318839,
#            0.0470529 ,  0.01690198],
#          ...,
#          [-0.02016842,  0.04372603, -0.01540047, ...,  0.01879749,
#           -0.01288441, -0.03310465],
#          [ 0.04379545,  0.01327666,  0.01356485, ...,  0.03596047,
#            0.053953  , -0.01049559],
#          [-0.04870764, -0.01811245, -0.0035748 , ...,  0.00610417,
#            0.02707812, -0.024595  ]]]], dtype=float32)>, <tf.Variable 'rpn_out_class/bias:0' shape=(9,) dtype=float32, numpy=
# array([-0.00535222, -0.00278136, -0.01591314, -0.00315705, -0.00298567,
#        -0.00284177,  0.00350478,  0.0073391 , -0.00193741], dtype=float32)>, <tf.Variable 'rpn_out_regress/kernel:0' shape=(1, 1, 512, 36) dtype=float32, numpy=
# array([[[[-7.49204657e-04,  1.36453193e-04,  1.82689168e-03, ...,
#            4.08535969e-04, -3.63516412e-03,  1.27186489e-04],
#          [ 7.11800658e-06, -6.71410118e-04,  8.68159987e-04, ...,
#           -3.77969467e-04, -2.36881874e-03, -1.59748574e-03],
#          [-8.61943408e-04,  2.29345402e-03, -1.07698981e-03, ...,
#            3.58925972e-05, -5.39857021e-04,  7.20145181e-04],
#          ...,
#          [ 1.13019068e-03, -5.47752308e-04, -2.18324014e-03, ...,
#            1.14044255e-04, -4.75719193e-04, -1.82529708e-04],
#          [-2.94896006e-03,  1.69105874e-03,  2.47400836e-04, ...,
#           -1.05500815e-03, -4.93434607e-04, -1.31450046e-03],
#          [ 1.88765800e-04, -1.62900379e-03,  1.81807042e-03, ...,
#           -1.46300439e-03, -1.75245659e-04,  1.15551183e-03]]]],
#       dtype=float32)>, <tf.Variable 'rpn_out_regress/bias:0' shape=(36,) dtype=float32, numpy=
# array([ 8.2299841e-05,  1.4958311e-03,  2.1151614e-03,  4.1821385e-03,
#         5.0043524e-04, -1.3747116e-04,  4.2714360e-03,  4.9871830e-03,
#        -3.7920370e-05, -3.1942481e-04, -2.3416255e-04,  3.3877569e-03,
#         1.3175993e-03,  3.2464380e-03, -1.0393852e-03,  3.9296835e-03,
#         1.9248313e-04,  2.0008595e-03,  1.7557173e-03,  4.3945913e-03,
#         2.4185181e-04, -1.3981772e-03,  1.9091177e-03,  5.0346074e-03,
#        -8.1306801e-04,  4.0082741e-03, -2.8511628e-03,  1.7189990e-03,
#        -2.6203515e-03, -2.0899402e-03, -9.1138310e-05,  4.4759950e-03,
#        -1.0956383e-03, -1.3665274e-03, -1.0343437e-03,  2.2091751e-03],
#       dtype=float32)>]
# -------------------------------------------------------------------------------------------------------
# [<tf.Variable 'time_distributed_6/kernel:0' shape=(25088, 4096) dtype=float32, numpy=
# array([[-0.00274806,  0.00828356,  0.01066424, ..., -0.00014112,
#          0.00049863,  0.01134778],
#        [-0.00141506, -0.00981409,  0.00210597, ..., -0.00472298,
#         -0.00240813, -0.01320027],
#        [ 0.01269846,  0.00192092, -0.0041108 , ..., -0.00529026,
#          0.0142892 , -0.00482972],
#        ...,
#        [-0.0092372 , -0.00170937,  0.00798639, ...,  0.00064045,
#         -0.00814739,  0.01098875],
#        [ 0.00854177, -0.00254825,  0.01139445, ...,  0.01129309,
#          0.0097166 , -0.00377752],
#        [-0.01204202,  0.00810606, -0.00754169, ..., -0.01368092,
#         -0.00263113,  0.00442286]], dtype=float32)>, <tf.Variable 'time_distributed_6/bias:0' shape=(4096,) dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>, <tf.Variable 'time_distributed_8/kernel:0' shape=(4096, 4096) dtype=float32, numpy=
# array([[-0.00384461,  0.02501562,  0.00596854, ..., -0.00427788,
#         -0.00495927, -0.01982734],
#        [ 0.00443796, -0.02368859, -0.0099636 , ..., -0.00287028,
#          0.02225773,  0.02048602],
#        [-0.00504991,  0.00932305,  0.00695316, ..., -0.02030295,
#         -0.00654808, -0.02260651],
#        ...,
#        [ 0.01503181, -0.00291533,  0.01794217, ..., -0.02657812,
#          0.02551767, -0.02178141],
#        [ 0.01261861, -0.00579787, -0.02214319, ...,  0.02164985,
#         -0.0019113 ,  0.01200778],
#        [-0.01469873, -0.00871681,  0.00889385, ...,  0.01529616,
#         -0.01288721,  0.00086861]], dtype=float32)>, <tf.Variable 'time_distributed_8/bias:0' shape=(4096,) dtype=float32, numpy=array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)>, <tf.Variable 'dense_class_50/kernel:0' shape=(4096, 50) dtype=float32, numpy=
# array([[-1.0176034e-03, -7.1612750e-03, -4.1151540e-03, ...,
#         -4.1939146e-03, -2.2244740e-03, -4.8548210e-04],
#        [-1.2576835e-02, -9.3013868e-03, -9.9137258e-03, ...,
#         -1.4586372e-03, -5.7861842e-03, -1.2120093e-03],
#        [ 2.3401147e-03, -3.9383216e-04,  5.4691434e-05, ...,
#         -2.0688446e-03, -1.8659382e-03, -1.2461562e-03],
#        ...,
#        [-2.3014438e-03,  1.3022064e-04, -3.8144647e-03, ...,
#          3.6949723e-04,  2.6099132e-03, -2.4283302e-03],
#        [-1.0294464e-02, -5.6308839e-03, -9.9565703e-03, ...,
#         -5.9714937e-03, -1.0758126e-02, -1.2017860e-03],
#        [-5.6108073e-03, -7.7844043e-03, -4.3336819e-03, ...,
#         -6.3265655e-03, -1.0076362e-02, -2.1645383e-03]], dtype=float32)>, <tf.Variable 'dense_class_50/bias:0' shape=(50,) dtype=float32, numpy=
# array([ 0.00070135,  0.0054153 ,  0.00204495,  0.00550533, -0.00330425,
#        -0.00355837, -0.00087679, -0.00035626, -0.00123237,  0.00474082,
#        -0.00246732, -0.00380017, -0.0019414 , -0.00181404, -0.00298362,
#         0.00012826, -0.00191708,  0.00068822,  0.00296783,  0.00453015,
#        -0.00161219, -0.00067741,  0.00258187, -0.00236484,  0.00026909,
#         0.00334834,  0.00046001, -0.0026966 ,  0.00480983,  0.0009956 ,
#         0.00626469,  0.00388887, -0.00719479,  0.00336439,  0.00511244,
#         0.00333853,  0.00458878,  0.00316868,  0.00151366,  0.00415738,
#         0.00317942,  0.00493359,  0.00569128,  0.00611374,  0.00595397,
#         0.00418786, -0.00755334,  0.00040235,  0.00485696, -0.00947883],
#       dtype=float32)>, <tf.Variable 'dense_regress_50/kernel:0' shape=(4096, 196) dtype=float32, numpy=
# array([[-1.8740298e-03, -1.1669113e-03, -1.7159602e-03, ...,
#         -1.1444815e-03,  2.2309374e-03, -1.1038710e-03],
#        [ 3.0163879e-04,  5.0837506e-04,  1.2774444e-03, ...,
#          1.6540570e-04, -1.4626102e-03,  1.5333360e-03],
#        [-3.1510743e-04,  1.0504392e-03,  2.8518247e-03, ...,
#          1.1660602e-03, -1.9130268e-04,  7.7083026e-04],
#        ...,
#        [ 6.0649472e-04, -3.5836923e-04,  7.7364716e-04, ...,
#         -8.3059777e-04, -4.0868879e-05, -3.0190800e-04],
#        [-8.5180986e-04,  1.2383380e-03, -1.3619700e-03, ...,
#          2.5736694e-05, -2.1855725e-05,  6.0807925e-04],
#        [ 1.2005133e-03, -4.5851266e-04,  2.7906880e-04, ...,
#          2.6670829e-04, -2.6670826e-04, -2.6670896e-04]], dtype=float32)>, <tf.Variable 'dense_regress_50/bias:0' shape=(196,) dtype=float32, numpy=
# array([-4.9688423e-04,  3.4350971e-05,  7.2668196e-04,  1.3806843e-03,
#        -3.7694164e-04, -1.6212040e-04,  1.8306701e-04, -7.7428682e-05,
#        -2.0795518e-04, -1.6183945e-04,  2.2006768e-04,  3.5008095e-04,
#         5.1574857e-04, -3.4500539e-04, -4.1155546e-04,  9.4944279e-04,
#         3.4796898e-04,  7.2567392e-04, -1.6601229e-03,  2.0851321e-03,
#        -1.9960657e-04,  1.0985015e-03, -1.1271655e-03, -5.3895079e-04,
#         1.2210784e-03,  1.3638849e-03, -7.5777632e-04,  5.3374929e-04,
#        -4.6682413e-04,  7.8746316e-04, -3.4109241e-04,  6.4931269e-04,
#         7.7504851e-04,  2.3835762e-03, -1.4573961e-03,  5.1242264e-04,
#        -2.9994038e-04, -2.3703060e-04,  4.1382550e-04, -2.2229966e-04,
#        -2.1640083e-04,  1.5082187e-03, -1.0068137e-03,  9.5098617e-04,
#         2.3791037e-04, -1.4336788e-04, -1.6221623e-03,  1.3456587e-03,
#         4.0758014e-04,  2.1620146e-04, -4.0484022e-04,  2.7443459e-03,
#         6.0692616e-04,  1.7988172e-03, -1.7795338e-03, -1.2182011e-04,
#         5.4645888e-04,  3.9815166e-04, -8.2495576e-04,  1.7540165e-03,
#         5.9704046e-04,  1.0157555e-03,  8.0053887e-04,  1.0099264e-03,
#         1.3780990e-03,  1.7037672e-03, -5.8504543e-04,  1.0614732e-03,
#         3.5462005e-04,  1.2197945e-03,  1.9135499e-04,  1.5196072e-04,
#        -4.4962307e-04, -5.6933735e-05, -4.3421469e-04,  3.4470204e-04,
#         1.1248494e-04, -3.2092183e-04,  6.2270602e-04,  2.9727622e-04,
#        -7.2181789e-04, -9.3098053e-05, -1.2258110e-03,  9.3414373e-04,
#         2.9615912e-04,  2.1340270e-04,  4.7252956e-04,  1.1536761e-04,
#        -3.5950766e-04, -1.3116453e-04,  5.2114815e-04,  3.8991010e-04,
#         6.4068247e-04, -2.7649602e-04, -7.2210925e-05,  1.0066767e-03,
#         5.0102035e-04,  3.4947926e-04, -1.9210580e-04,  7.9374335e-04,
#         5.7190738e-04,  6.3901447e-04,  1.6254612e-04,  1.1490710e-03,
#        -3.1966646e-04,  7.7297242e-04, -7.8314549e-04, -8.2093390e-04,
#         5.4616766e-04,  3.9754502e-04, -1.4440581e-03,  1.3511667e-03,
#         2.9036595e-04, -7.4274495e-04, -3.7910859e-04,  5.4539472e-04,
#         2.8941035e-04,  7.3589152e-04,  5.6367682e-04,  8.0404046e-04,
#        -5.5565330e-04,  5.2710372e-04,  2.4622932e-04,  9.9270581e-04,
#         5.6285708e-04, -3.7679652e-04,  8.2967721e-04,  4.5040424e-04,
#         1.1997807e-03,  2.5683120e-04,  2.4546072e-04,  7.5119379e-04,
#         5.7055085e-04, -3.7160513e-04,  6.8249274e-04,  2.4400718e-04,
#         6.6479936e-04, -2.9921523e-04,  9.7642042e-04,  3.4237068e-04,
#        -6.3981785e-04, -4.4094911e-04, -1.7112005e-04,  2.5076282e-04,
#        -4.8158041e-04, -3.5392185e-04,  1.2046075e-04,  6.0172315e-04,
#        -5.2184513e-04, -3.4923962e-04, -2.5542008e-04,  8.0161751e-04,
#        -4.8200245e-04, -4.1980151e-04,  6.9045037e-04,  8.3828066e-04,
#        -2.8022088e-04, -2.3386480e-04, -1.3544041e-04,  1.5347408e-03,
#         5.8697048e-04,  5.0548284e-04,  6.3724857e-04, -2.3933219e-04,
#        -1.7162054e-04, -3.0007356e-04, -3.0668115e-04, -3.0310146e-04,
#        -1.7108902e-04,  2.6122911e-04,  3.1121125e-04,  5.5318355e-04,
#        -2.6098258e-04, -3.5274000e-04,  5.8249541e-05, -5.2360870e-04,
#        -7.1511953e-04, -5.4484542e-04, -1.6326923e-05,  7.3343521e-04,
#        -5.1216612e-06,  3.6280774e-04, -3.6909687e-04,  5.7189970e-04,
#        -7.4216509e-06,  7.4593067e-06, -6.2780135e-04, -7.4599916e-06,
#        -2.0096029e-04,  2.2786362e-04,  4.9584755e-04,  2.4460070e-04,
#        -4.1368894e-05,  2.0383614e-04,  4.2662784e-04,  5.6013255e-04],
#       dtype=float32)>]
# -------------------------------------------------------------------------------------------------------

# %%
# Switch key value for class mapping
class_mapping = C.class_mapping
class_mapping = {v: k for k, v in class_mapping.items()}
print(class_mapping)
class_to_color = {class_mapping[v]: np.random.randint(0, 255, 3) for v in class_mapping}
# Out:
# {0: 'M', 1: 'O', 2: 'V', 3: 'E', 4: 't', 5: 'o', 6: 's', 7: 'p', 8: 'r', 9: 'G', 10: 'a', 11: 'i', 12: 'l', 13: 'e', 14: 'f', 15: 'm', 16: 'n', 17: 'y', 18: 'v', 19: 'L', 20: 'b', 21: 'u', 22: 'P', 23: 'd', 24: 'g', 25: 'S', 26: 'c', 27: 'h', 28: 'F', 29: 'w', 30: 'j', 31: 'W', 32: 'x', 33: 'A', 34: 'N', 35: 'T', 36: 'k', 37: 'B', 38: 'H', 39: 'q', 40: 'R', 41: 'C', 42: 'D', 43: 'K', 44: 'U', 45: 'I', 46: '', 47: 'Y', 48: 'J', 49: 'bg'}

# %%
# print(model_rpn.weights)
# print ("Ssss")
# print(model_classifier)
# print ("Ssss")
# print(model_classifier_only)
# print ("Ssss")

# %%
test_imgs = os.listdir(test_base_path)

imgs_path = []
for i in range(12):
	idx = np.random.randint(len(test_imgs))
	imgs_path.append(test_imgs[idx])

all_imgs = []

classes = {}

# %%
# If the box classification value is less than this, we ignore this box
bbox_threshold = 0.7

for idx, img_name in enumerate(imgs_path):
    if not img_name.lower().endswith(('.bmp', '.jpeg', '.jpg', '.png', '.tif', '.tiff')):
        continue
    print(img_name)
    st = time.time()
    filepath = os.path.join(test_base_path, img_name)

    img = cv2.imread(filepath)

    X, ratio = format_img(img, C)
    
    X = np.transpose(X, (0, 2, 3, 1))

    # get output layer Y1, Y2 from the RPN and the feature maps F
    # Y1: y_rpn_cls
    # Y2: y_rpn_regr
    [Y1, Y2, F] = model_rpn.predict(X)

    # Get bboxes by applying NMS 
    # R.shape = (300, 4)
    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)

    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0]//C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois*jk:C.num_rois*(jk+1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0]//C.num_rois:
            #pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0],C.num_rois,curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate bboxes coordinates on resized image
        for ii in range(P_cls.shape[1]):
            # Ignore 'bg' class
            if np.max(P_cls[0, ii, :]) < bbox_threshold or np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4*cls_num:4*(cls_num+1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([C.rpn_stride*x, C.rpn_stride*y, C.rpn_stride*(x+w), C.rpn_stride*(y+h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.2)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk,:]

            # Calculate real coordinates on original image
            (real_x1, real_y1, real_x2, real_y2) = get_real_coordinates(ratio, x1, y1, x2, y2)

            cv2.rectangle(img,(real_x1, real_y1), (real_x2, real_y2), (int(class_to_color[key][0]), int(class_to_color[key][1]), int(class_to_color[key][2])),4)

            textLabel = '{}: {}'.format(key,int(100*new_probs[jk]))
            all_dets.append((key,100*new_probs[jk]))

            (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,1,1)
            textOrg = (real_x1, real_y1-0)

            cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 1)
            cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
            cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 0), 1)

    print('Elapsed time = {}'.format(time.time() - st))
    print(all_dets)
    plt.figure(figsize=(10,10))
    plt.grid()
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# a01-122-07-02_png.rf.5d669ad98b3e38983e3a187770ca0c6e.jpg
# Elapsed time = 11.900718688964844
# []
# a01-000x-01-00_png.rf.7c4ab311e47b58d6b0cfd1e431b5a3ca.jpg
# Elapsed time = 11.133062362670898
# []
# a01-117u-02-07_png.rf.a7c702d0d89c838e881581ab66f063e5.jpg
# Elapsed time = 11.365240335464478
# []
# a01-072u-03-00_png.rf.b679f85b5e73c90fed0c060abbf5235a.jpg
# Elapsed time = 11.181510925292969
# []
# a01-128u-10-06_png.rf.cb1bcaca69abb0d231c4da9af974455d.jpg
# Elapsed time = 11.11656403541565
# []
# a01-007x-04-03_png.rf.d3b41233e5f41e7ef506230f531ce1e1.jpg
# Elapsed time = 11.106805801391602
# []
# a01-087-08-01_png.rf.5724ed43fd09f4e6543d33e2cabd65cd.jpg

# %%
def get_map(pred, gt, f):
	T = {}
	P = {}
	fx, fy = f

	for bbox in gt:
		bbox['bbox_matched'] = False

	pred_probs = np.array([s['prob'] for s in pred])
	box_idx_sorted_by_prob = np.argsort(pred_probs)[::-1]

	for box_idx in box_idx_sorted_by_prob:
		pred_box = pred[box_idx]
		pred_class = pred_box['class']
		pred_x1 = pred_box['x1']
		pred_x2 = pred_box['x2']
		pred_y1 = pred_box['y1']
		pred_y2 = pred_box['y2']
		pred_prob = pred_box['prob']
		if pred_class not in P:
			P[pred_class] = []
			T[pred_class] = []
		P[pred_class].append(pred_prob)
		found_match = False

		for gt_box in gt:
			gt_class = gt_box['class']
			gt_x1 = gt_box['x1']/fx
			gt_x2 = gt_box['x2']/fx
			gt_y1 = gt_box['y1']/fy
			gt_y2 = gt_box['y2']/fy
			gt_seen = gt_box['bbox_matched']
			if gt_class != pred_class:
				continue
			if gt_seen:
				continue
			iou_map = iou((pred_x1, pred_y1, pred_x2, pred_y2), (gt_x1, gt_y1, gt_x2, gt_y2))
			if iou_map >= 0.5:
				found_match = True
				gt_box['bbox_matched'] = True
				break
			else:
				continue

		T[pred_class].append(int(found_match))

	for gt_box in gt:
		if not gt_box['bbox_matched']:# and not gt_box['difficult']:
			if gt_box['class'] not in P:
				P[gt_box['class']] = []
				T[gt_box['class']] = []

			T[gt_box['class']].append(1)
			P[gt_box['class']].append(0)

	#import pdb
	#pdb.set_trace()
	return T, P

# %%
def format_img_map(img, C):
	"""Format image for mAP. Resize original image to C.im_size (300 in here)

	Args:
		img: cv2 image
		C: config

	Returns:
		img: Scaled and normalized image with expanding dimension
		fx: ratio for width scaling
		fy: ratio for height scaling
	"""

	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
	
	if width <= height:
		f = img_min_side/width
		new_height = int(f * height)
		new_width = int(img_min_side)
	else:
		f = img_min_side/height
		new_width = int(f * width)
		new_height = int(img_min_side)
	fx = width/float(new_width)
	fy = height/float(new_height)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	# Change image channel from BGR to RGB
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	# Change img shape from (height, width, channel) to (channel, height, width)
	img = np.transpose(img, (2, 0, 1))
	# Expand one dimension at axis 0
	# img shape becames (1, channel, height, width)
	img = np.expand_dims(img, axis=0)
	return img, fx, fy

# %%
print(class_mapping)

# %%
st = time.time()

found_bg = False
all_imgs = {}
print(all_imgs)

classes_count = {}

class_mapping = {}
visualise = True

i = 1

with open(test_path,'r') as f:

	print('Parsing annotation files')

	for line in f:

		# Print process
		sys.stdout.write('\r'+'idx=' + str(i))
		i += 1

		line_split = line.strip().split(',')

		# Make sure the info saved in annotation file matching the format (path_filename, x1, y1, x2, y2, class_name)
		# Note:
		#	One path_filename might has several classes (class_name)
		#	x1, y1, x2, y2 are the pixel value of the origial image, not the ratio value
		#	(x1, y1) top left coordinates; (x2, y2) bottom right coordinates
		#   x1,y1-------------------
		#	|						|
		#	|						|
		#	|						|
		#	|						|
		#	---------------------x2,y2

		(filename,x1,y1,x2,y2,class_name) = line_split

		if class_name not in classes_count:
			classes_count[class_name] = 1
		else:
			classes_count[class_name] += 1

		if class_name not in class_mapping:
			if (class_name.isalpha() and len(class_name)!=1 and found_bg == False):
				print('Found class name with different flow.(this is usually for hard negative mining).')
				found_bg = True
			class_mapping[class_name] = len(class_mapping)
  
		if filename not in all_imgs:
			all_imgs[filename] = {}
			# %cd /content/drive/MyDrive/GraduationProject/test/
			img = cv2.imread(filename)
			print(filename)
			if hasattr(img, 'shape'):
				(rows,cols,_) = img.shape
				all_imgs[filename]['filepath'] = filename
				all_imgs[filename]['width'] = cols
				all_imgs[filename]['height'] = rows
				all_imgs[filename]['bboxes'] = []
			# if np.random.randint(0,6) > 0:
			# 	all_imgs[filename]['imageset'] = 'trainval'
			# else:
			# 	all_imgs[filename]['imageset'] = 'test'
		#print({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})
		all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})
		print(all_imgs[filename]['bboxes'])



	all_data = []
	for key in all_imgs:
		all_data.append(all_imgs[key])
	
	# # make sure the bg class is last in the list
	# if found_bg:
	# 	if class_mapping['bg'] != len(class_mapping) - 1:
	# 		key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
	# 		val_to_switch = class_mapping['bg']
	# 		class_mapping['bg'] = len(class_mapping) - 1
	# 		class_mapping[key_to_switch] = val_to_switch
	
	test_imgs=all_data
print()
print('Spend %0.2f mins to load the data' % ((time.time()-st)/60) )

# %%
T = {}
P = {}
mAPs = []
for idx, img_data in enumerate(test_imgs):
    print('{}/{}'.format(idx,len(test_imgs)))
    st = time.time()
    filepath = img_data['filepath']

    img = cv2.imread(filepath)

    X, fx, fy = format_img_map(img, C)

    # Change X (img) shape from (1, channel, height, width) to (1, height, width, channel)
    X = np.transpose(X, (0, 2, 3, 1))

    # get the feature maps and output from the RPN
    [Y1, Y2, F] = model_rpn.predict(X)


    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)

    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0] // C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois * jk:C.num_rois * (jk + 1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0] // C.num_rois:
            # pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0], C.num_rois, curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate all classes' bboxes coordinates on resized image (300, 400)
        # Drop 'bg' classes bboxes
        for ii in range(P_cls.shape[1]):

            # If class name is 'bg', continue
            if np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            # Get class name
            print("--------------------------------------------")
            import operator
            print(max(class_mapping.items(), key=operator.itemgetter(1))[0])
            cls_name = max(class_mapping.items(), key=operator.itemgetter(1))[0]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4 * cls_num:4 * (cls_num + 1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = roi_helpers.apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([16 * x, 16 * y, 16 * (x + w), 16 * (y + h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        # Apply non-max-suppression on final bboxes to get the output bounding boxe
        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.5)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk, :]
            det = {'x1': x1, 'x2': x2, 'y1': y1, 'y2': y2, 'class': key, 'prob': new_probs[jk]}
            all_dets.append(det)


    print('Elapsed time = {}'.format(time.time() - st))
    t, p = get_map(all_dets, img_data['bboxes'], (fx, fy))
    for key in t.keys():
        if key not in T:
            T[key] = []
            P[key] = []
        T[key].extend(t[key])
        P[key].extend(p[key])
    all_aps = []
    for key in T.keys():
        ap = average_precision_score(T[key], P[key])
        print('{} AP: {}'.format(key, ap))
        all_aps.append(ap)
    print('mAP = {}'.format(np.mean(np.array(all_aps))))
    mAPs.append(np.mean(np.array(all_aps)))
    #print(T)
    #print(P)
    
print()
print('mean average precision:', np.mean(np.array(mAPs)))

# %%
mAP = [mAP for mAP in mAPs if str(mAP)!='nan']
mean_average_prec = round(np.mean(np.array(mAP)), 3)
print('After training %dk batches, the mean average precision is %0.3f'%(len(record_df), mean_average_prec))

# record_df.loc[len(record_df)-1, 'mAP'] = mean_average_prec
# record_df.to_csv(C.record_path, index=0)
# print('Save mAP to {}'.format(C.record_path))
